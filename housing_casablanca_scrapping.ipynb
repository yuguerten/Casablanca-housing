# %% [markdown]
# <a href="https://colab.research.google.com/github/yuguerten/Casablanca-housing/blob/main/housing_casablanca_scrapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *Installing libraries*

# %%
# !pip install beautifulsoup4
# !pip install requests
# Out:
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2023.7.22)

# %% [markdown]
# *Improting libraries*

# %%
from bs4 import BeautifulSoup
import requests
import matplotlib.pyplot as plt

# %% [markdown]
# *Define the url and use the GET html method to extract the web page*

# %%
url = "https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:o:d"
res = requests.get(url)

# %%
print(res)
# Out:
# <Response [200]>

# %% [markdown]
# *Using BeautifulSoup to parse the response variable*

# %%
soup = BeautifulSoup(res.text)
soup
# Out:
# /usr/local/lib/python3.10/dist-packages/bs4/builder/__init__.py:545: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   warnings.warn(
# <?xml version="1.0" encoding="utf-8"?><!DOCTYPE html>
# <html dir="ltr" lang="fr" xml:lang="fr" xmlns="http://www.w3.org/1999/xhtml"><head id="j_idt2"><script type="text/javascript">if(window.PrimeFaces){PrimeFaces.settings.locale='fr';}</script><link href="/cssJawrPath/gzip_615969399/desktop/web/common/common.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="/cssJawrPath/gzip_984756807/desktop/web/public/font-awesome.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="/cssJawrPath/gzip_N288451888/desktop/components/popup.css" media="screen" rel="stylesheet" type="text/css"/>
# <!-- Google Tag Manager -->
# <script type="text/javascript">
# 		(function(w,d,s,l,i){
# 			w[l]=w[l]||[];
# 			w[l].push({'criteoId': '36172'});
# 			w[l].push({'device': 'd'});
# 			w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});
# 			var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';
# 			j.async=true;
# 			j.src='https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# 		})(window,document,'script','dataLayer','GTM-WMS6GRX');
# 	</script>
# <title>Appartement à Vendre Casablanca-Settat - vente appartement - Mubawab</title>
# <meta content="Votre future logement est ici. Nous vous aidons à trouver un appartement à vendre  - Région Casablanca-Settat sur Mubawab parmi plus de 120.000 annonces" name="description"/>
# <meta content="appartement à vendre Casablanca-Settat, achat &amp; vente appartement" name="keywords"/>
# <meta content="noindex,follow" name="robots"/>
# <meta content="Appartement à Vendre Casablanca-Settat - vente appartement - Mubawab" property="og:title"/>
# <meta content="Votre future logement est ici. Nous vous aidons à trouver un appartement à vendre  - Région Casablanca-Settat sur Mubawab parmi plus de 120.000 annonces" property="og:description"/>
# <meta content="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:o:d" property="og:url"/>
# <meta content="fr" property="og:locale"/>
# <meta content="Mubawab Maroc" property="og:site_name"/>
# <meta content="https://www.mubawab-media.com/assets/logos/favicon.ico" property="og:image"/>
# <link href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre" rel="canonical"/>
# <link href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:o:d" hreflang="FR"/>
# <link href="https://www.mubawab.ma/ar/scr/%D8%A7%D9%84%D8%AF%D8%A7%D8%B1-%D8%A7%D9%84%D8%A8%D9%8A%D8%B6%D8%A7%D8%A1-%D8%B3%D8%B7%D8%A7%D8%AA/%D8%B4%D9%82%D9%82-%D9%84%D9%84%D8%A8%D9%8A%D8%B9:o:d" hreflang="AR" rel="alternate"/>
# <link href="https://www.mubawab.ma/en/scr/casablanca-settat/apartments-for-sale:o:d" hreflang="EN" rel="alternate"/>
# <link href="https://www.mubawab.ma/it/scr/casablanca-settat/appartamenti-in-vendita:o:d" hreflang="IT" rel="alternate"/>
# <link href="https://www.mubawab.ma/es/scr/casablanca-settat/pisos-en-venta:o:d" hreflang="ES" rel="alternate"/>
# <link href="https://www.mubawab.ma/nl/scr/casablanca-settat/appartementen-te-koop:o:d" hreflang="NL" rel="alternate"/><link href="/cssJawrPath/gzip_1400509915/desktop/web/public/listing.css" media="screen" rel="stylesheet" type="text/css"/>
# <script src="/jsJawrPath/gzip_N372466075/web/common/unique-id.js" type="text/javascript"></script>
# <!-- Criteo -->
# <script type="text/javascript">
# 				window.dataLayer.push({
# 		   			'visitorId': getRemarketingSessionId("d"),
# 		   			'viewList': ["7713734","7485272","7679122"]
# 		   		});
# 			</script>
# <link href="https://www.mubawab-media.com/assets/logos/favicon.ico" rel="shortcut icon"/>
# <script async="async" src="https://www.googletagservices.com/tag/js/gpt.js"></script>
# <script type="text/javascript">
# 		var googletag = googletag || {};
# 		googletag.cmd = googletag.cmd || [];
#
#         googletag.cmd.push(function() {
# 	        if(false) {
# 	        	googletag.pubads().setTargeting('Keyword', '');
# 	        }
#
# 	        googletag.pubads().setTargeting('District', 'null');
# 	        googletag.pubads().setTargeting('City', 'null');
# 	        googletag.pubads().setTargeting('Country', 'MA');
# 	        googletag.pubads().setTargeting('Category', 'sale');
# 	        googletag.pubads().setTargeting('SubCat', 'apartment-sale');
# 	        googletag.pubads().setTargeting('Language', 'FR');
# 	        googletag.pubads().setTargeting('Region', 'MA.casablanca-settat');
# 	        googletag.pubads().setTargeting('MinPrice', '');
# 	        googletag.pubads().setTargeting('MaxPrice', '');
#
# 	        googletag.pubads().collapseEmptyDivs();
# 	        googletag.pubads().enableSingleRequest();
# 	        googletag.enableServices();
#         });
#     </script></head><body class="ltr mubaWeb mubaMA listingPage">
# <input id="confirmText" type="hidden" value="Êtes-vous sûr?"/>
# <noscript>
# <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-WMS6GRX" style="display: none; visibility: hidden" width="0"></iframe>
# </noscript>
# <input id="pushSubscribeHidden" type="hidden" value="https://www.mubawab.ma/fr/ajax/common/subscribe-push-web"/>
# <input id="pushWebOpenHidden" type="hidden" value="https://www.mubawab.ma/fr/ajax/common/push-web-open"/>
# <input id="bannerClickUrl" type="hidden" value="https://www.mubawab.ma/fr/ajax/common/banner-click"/>
# <input id="bannerPrintUrl" type="hidden" value="https://www.mubawab.ma/fr/ajax/common/banner-print"/>
# <input id="chromeBrowser" type="hidden" value="false"/>
# <input id="htc" type="hidden" value="false"/>
# <input id="u" type="hidden"/>
# <input id="countryCode" type="hidden" value="MA"/>
# <input id="language" type="hidden" value="FR"/>
# <div class="centered" id="homebannerTop">
# </div>
# <div id="homehabillageleft">
# </div>
# <div id="homehabillageright">
# </div>
# <header>
# <input id="changeLanguageUserUrl" type="hidden" value="https://www.mubawab.ma/fr/ajax/common/change-language-user"/>
# <input id="loggedUserIdHidden" type="hidden"/>
# <nav class="main-nav">
# <h2 class="main-logo centered floatR">
# <a class="tagline centered" href="https://www.mubawab.ma" title="Mubawab">
# <img alt="Mubawab Le 1er site immobilier du Maroc" class="logoImg" src="https://www.mubawab-media.com/assets/logos/mubawab.png" title="Mubawab Le 1er site immobilier du Maroc"/>
# <span class="taglineText">Le 1er site immobilier du Maroc</span>
# </a>
# </h2>
# <ul class="ulNav float-right floatL">
# <li class="float-left">
# <a class="mainItem" href="https://www.mubawab.ma/fr/listing-promotion" rel="nofollow" title="Immobilier neuf">Immobilier neuf</a>
# </li>
# <li class="float-left">
# <a class="mainItem" href="https://transaction.mubawab.ma/" rel="nofollow" title="Transaction">Transaction</a>
# </li>
# <li class="float-left">
# <a class="mainItem" href="https://blog.mubawab.ma" rel="nofollow" title="Blog">Blog</a>
# </li>
# <li class="float-left dropdownHead">
# <a class="mainItem" title="Français">
# 								Fr
# 								<i class="icon-down-dir fSize14"></i>
# </a>
# <div class="dropdown-content">
# <a class="dropdownItem selectLanguage" href="https://www.mubawab.ma/ar/scr/%D8%A7%D9%84%D8%AF%D8%A7%D8%B1-%D8%A7%D9%84%D8%A8%D9%8A%D8%B6%D8%A7%D8%A1-%D8%B3%D8%B7%D8%A7%D8%AA/%D8%B4%D9%82%D9%82-%D9%84%D9%84%D8%A8%D9%8A%D8%B9:o:d" lang="ar" onclick="changeLanguageUser('AR')" rel="nofollow" title="العربية">
# 										العربية</a>
# <a class="dropdownItem selectLanguage" href="https://www.mubawab.ma/en/scr/casablanca-settat/apartments-for-sale:o:d" lang="en" onclick="changeLanguageUser('EN')" rel="nofollow" title="English">
# 										English</a>
# <a class="dropdownItem selectLanguage" href="https://www.mubawab.ma/es/scr/casablanca-settat/pisos-en-venta:o:d" lang="es" onclick="changeLanguageUser('ES')" rel="nofollow" title="Español">
# 										Español</a>
# <a class="dropdownItem selectLanguage" href="https://www.mubawab.ma/nl/scr/casablanca-settat/appartementen-te-koop:o:d" lang="nl" onclick="changeLanguageUser('NL')" rel="nofollow" title="Nederlands">
# 										Nederlands</a>
# <a class="dropdownItem selectLanguage" href="https://www.mubawab.ma/it/scr/casablanca-settat/appartamenti-in-vendita:o:d" lang="it" onclick="changeLanguageUser('IT')" rel="nofollow" title="Italiano">
# 										Italiano</a>
# </div>
# </li>
# <li class="float-left">
# <a class="darkblue" href="https://www.mubawab.ma/fr/cms/my-content" rel="nofollow" title="Se connecter">
# <i class="icon-user-circle-o"></i>
# 									Se connecter
#
# 								<span class="capitalize userNameHeader">
# </span>
# </a>
# </li>
# <a class="float-left btn btn-head centered" href="https://www.mubawab.ma/fr/posting" rel="follow" title="Publier une annonce">Publier une annonce</a>
# </ul>
# </nav>
# <div class="adv-outside-right-listing" id="outsideBanner">
# </div>
# <link as="image" href="https://www.mubawab-media.com/ad/7/713/734F/m/WhatsApp%20Image%202023-06-08%20at%2012.39.39%20%281%29_48876874.jpeg" rel="preload" type="image/jpeg"/>
# </header>
# <div class="loading" closable="false" data-role="popup" id="loadingPopup" style="display: none;">
# <div class="centered">
# <img src="https://www.mubawab-media.com/assets/common/loading.gif"/>
# </div>
# <p>Traitement en cours...</p>
# </div><link href="/cssJawrPath/gzip_459883989/destkop/components/pagination.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="/cssJawrPath/gzip_1500672583/components/slider.css" media="screen" rel="stylesheet" type="text/css"/>
# <input id="indexedSearchPage" type="hidden" value="false"/>
# <input id="loggedUser" name="loggedUser" type="hidden" value="0"/>
# <input id="favUrl" type="hidden" value="https://www.mubawab.ma/fr/ajax/common/favourites-mng"/>
# <input id="listingItemPrintedUrl" type="hidden" value="https://www.mubawab.ma/fr/ajax/common/listing-item-printed"/>
# <input id="adType" type="hidden" value="ad"/>
# <input id="listingPageHidden" type="hidden" value="1"/>
# <input id="urlCodeHidden" type="hidden" value="SCR"/>
# <input id="nextPreviousAdsHidden" type="hidden" value="[7713734, 7485272, 7679122, 7708719, 7686974, 7790754, 7592644, 7506744, 7756453, 7685238, 7634217, 7706636, 7700540, 7707505, 7705409, 7764244, 7765734, 7740759, 7598246, 7726298, 7705866, 7703517, 7726114, 7679947, 7761875, 7791976, 7425570, 7819301, 7598387, 7687272, 7768315, 7737449, 7751952]"/>
# <input name="device" type="hidden" value="DESKTOP"/>
# <!-- SECTION START -->
# <section class="listingPage">
# <!-- Breadcrumb and title -->
# <div class="breadBlock greyBlock">
# <div class="row contnr1100">
# <div class="col-8 vAlignM">
# <a class="darkblue" href="https://www.mubawab.ma" title="Immobilier Maroc"> Immobilier Maroc
# 		</a>
# <i class="icon-right-open rotate180 miniIcon"></i>
# <span> Appartements à vendre
# 				</span><br/>
# <h1 class="searchTitle inBlock floatR">Appartement à vendre  - Région Casablanca-Settat</h1>
# <span class="resultNum floatR">(7013 résultats)</span>
# </div>
# <div class="col-4">
# <div class="searchKeys float-right floatL" id="searchKeys">
# <a class="darkblue" href="https://www.mubawab.ma/fr/is/appartement-for-sale_casablanca_salle-de-bain" title="Appartement à Vendre Casablanca Salle-de-bain"> Appartement à Vendre Casablanca Salle-de-bain </a>
# <i>/</i>
# <a class="darkblue" href="https://www.mubawab.ma/fr/is/appartement-for-sale_casablanca_pas-cher" title="Appartement à Vendre Casablanca Pas Cher"> Appartement à Vendre Casablanca Pas Cher </a>
# </div>
# </div>
# </div>
# </div>
# <!-- end Breadcrumb -->
# <!-- MAIN CONTAINER -->
# <div class="contnr1100 mainContnr">
# <!-- Transaction type nav -->
# <div class="centered filterBar sMargTop">
# <div class="groupBtn inBlock">
# <span class="btn btnFlatSmall active">Vente
# 					</span>
# <span class="btn btnFlatSmall" onclick="showLoading(); window.location = 'https://www.mubawab.ma/fr/cr/casablanca-settat/immobilier-a-louer'">Location
# 					</span>
# <span class="btn btnFlatSmall" onclick="showLoading(); window.location = 'https://www.mubawab.ma/fr/listing-promotion'">Immobilier neuf
# 					</span>
# <span class="btn btnFlatSmall" onclick="showLoading(); window.location = 'https://www.mubawab.ma/fr/cr/casablanca-settat/immobilier-vacational'">Loc. vacances
# 						</span>
# </div>
# <!-- Order Filter -->
# <div class="orderBar textLeft cPointer">
# <i class="icon-sort-alt-up iconPadR darkblue floatR"></i>
# <p class="inBlock floatR">Trier:</p>
# <p class="blueText inBlock floatR">Prix maximum</p>
# <i class="icon-angle-down darkblue float-right fSize14"></i>
# </div>
# </div>
# <!-- Aside -->
# <div class="col-3 emptyCol">
# <aside class="asideL floatR">
# <!-- Filters -->
# <div id="stickyDiv">
# <div class="sideFilterWrap asideMarg">
# <!-- R&eacute;gions -->
# <div>
# <label class="selectLabel">Régions</label>
# <div class="dropdown dropdownSelect bigSelect w100">
# <div class="select">
# <span class="blueText">Casablanca-Settat
# 								</span>
# <i class="icon-down-dir float-right floatL"></i>
# </div>
# <ul class="selectUl">
# <li class="alignR">
# <a href="https://www.mubawab.ma/fr/scr/b%C3%A9ni-mellal-kh%C3%A9nifra/appartements-a-vendre:o:d">Béni Mellal-Khénifra
# 												</a>
# </li>
# <li class="alignR">
# <a href="#">Casablanca-Settat
# 												</a>
# </li>
# <li class="alignR">
# <a href="https://www.mubawab.ma/fr/scr/dakhla-oued-eddahab/appartements-a-vendre:o:d">Dakhla-Oued Eddahab
# 												</a>
# </li>
# <li class="alignR">
# <a href="https://www.mubawab.ma/fr/scr/dar%C3%A2a-tafilalet/appartements-a-vendre:o:d">Darâa-Tafilalet
# 												</a>
# </li>
# <li class="alignR">
# <a href="https://www.mubawab.ma/fr/scr/f%C3%A8s-mekn%C3%A8s/appartements-a-vendre:o:d">Fès-Meknès
# 												</a>
# </li>
# <li class="alignR">
# <a href="https://www.mubawab.ma/fr/scr/guelmim-oued-noun/appartements-a-vendre:o:d">Guelmim-Oued Noun
# 												</a>
# </li>
# <li class="alignR">
# <a href="https://www.mubawab.ma/fr/scr/l'oriental/appartements-a-vendre:o:d">L'Oriental
# 												</a>
# </li>
# <li class="alignR">
# <a href="https://www.mubawab.ma/fr/scr/la%C3%A2youne-sakia-el-hamra/appartements-a-vendre:o:d">Laâyoune-Sakia El Hamra
# 												</a>
# </li>
# <li class="alignR">
# <a href="https://www.mubawab.ma/fr/scr/marrakech-safi/appartements-a-vendre:o:d">Marrakech-Safi
# 												</a>
# </li>
# <li class="alignR">
# <a href="https://www.mubawab.ma/fr/scr/rabat-sal%C3%A9-zemmour-za%C3%ABr/appartements-a-vendre:o:d">Rabat-Salé-Zemmour-Zaër
# 												</a>
# </li>
# <li class="alignR">
# <a href="https://www.mubawab.ma/fr/scr/souss-massaa/appartements-a-vendre:o:d">Souss-Massaa
# 												</a>
# </li>
# <li class="alignR">
# <a href="https://www.mubawab.ma/fr/scr/tanger-t%C3%A9touan-al-hoceima/appartements-a-vendre:o:d">Tanger-Tétouan-Al Hoceima
# 												</a>
# </li>
# </ul>
# </div>
# </div>
# <!-- Provinces/Pr&eacute;fectures -->
# <div>
# <label class="selectLabel">Provinces/Préfectures</label>
# <div class="dropdown dropdownSelect bigSelect w100">
# <div class="select">
# <span class="blueText">Choisir une province/préfec.
# 								</span>
# <i class="icon-down-dir float-right floatL"></i>
# </div>
# <ul class="selectUl">
# <li class="alignR">
# <a href="https://www.mubawab.ma/fr/scrp/casablanca-settat/province-d'el-jadida/appartements-a-vendre:o:d">Province d'El Jadida
# 												</a>
# </li>
# <li class="alignR">
# <a href="https://www.mubawab.ma/fr/scrp/casablanca-settat/province-de-benslimane/appartements-a-vendre:o:d">Province de Benslimane
# 												</a>
# </li>
# <li class="alignR">
# <a href="https://www.mubawab.ma/fr/scrp/casablanca-settat/province-de-berrechid/appartements-a-vendre:o:d">Province de Berrechid
# 												</a>
# </li>
# <li class="alignR">
# <a href="https://www.mubawab.ma/fr/scrp/casablanca-settat/province-de-m%C3%A9diouna/appartements-a-vendre:o:d">Province de Médiouna
# 												</a>
# </li>
# <li class="alignR">
# <a href="https://www.mubawab.ma/fr/scrp/casablanca-settat/province-de-nouaceur/appartements-a-vendre:o:d">Province de Nouaceur
# 												</a>
# </li>
# <li class="alignR">
# <a href="https://www.mubawab.ma/fr/scrp/casablanca-settat/province-de-settat/appartements-a-vendre:o:d">Province de Settat
# 												</a>
# </li>
# <li class="alignR">
# <a href="https://www.mubawab.ma/fr/scrp/casablanca-settat/province-de-sidi-bennour/appartements-a-vendre:o:d">Province de Sidi Bennour
# 												</a>
# </li>
# <li class="alignR">
# <a href="https://www.mubawab.ma/fr/st/casablanca/appartements-a-vendre:o:d">Préfecture de Casablanca
# 												</a>
# </li>
# <li class="alignR">
# <a href="https://www.mubawab.ma/fr/scrp/casablanca-settat/pr%C3%A9fecture-de-mohamm%C3%A9dia/appartements-a-vendre:o:d">Préfecture de Mohammédia
# 												</a>
# </li>
# </ul>
# </div>
# </div>
# <!-- Cities -->
# <form>
# <input id="cityId" name="cityId" type="hidden"/>
# <input id="transactionId" name="transactionId" type="hidden" value="sale"/>
# <input id="adTypeId" name="adTypeId" type="hidden" value="apartment-sale"/>
# <!-- Districts -->
# <!-- Towns -->
# </form>
# <!-- Type de bien	-->
# <label class="selectLabel">Type de bien</label>
# <div class="catNav">
# <a href="https://www.mubawab.ma/fr/cr/casablanca-settat/immobilier-a-vendre-all:o:d">
# <button class="btn btnFlatSmall active" onclick="showLoading();" type="button">Appartements</button>
# </a>
# <a href="https://www.mubawab.ma/fr/cr/casablanca-settat/immobilier-a-vendre-all:o:d:sc:apartment-sale,house-sale">
# <button class="btn btnFlatSmall" onclick="showLoading();" type="button">Maisons</button>
# </a>
# <a href="https://www.mubawab.ma/fr/cr/casablanca-settat/immobilier-a-vendre-all:o:d:sc:apartment-sale,villa-sale">
# <button class="btn btnFlatSmall" onclick="showLoading();" type="button">Villas</button>
# </a>
# <a href="https://www.mubawab.ma/fr/cr/casablanca-settat/immobilier-a-vendre-all:o:d:sc:apartment-sale,riad-sale">
# <button class="btn btnFlatSmall" onclick="showLoading();" type="button">Riads</button>
# </a>
# <a href="https://www.mubawab.ma/fr/cr/casablanca-settat/immobilier-a-vendre-all:o:d:sc:apartment-sale,commercial-sale">
# <button class="btn btnFlatSmall" onclick="showLoading();" type="button">Locaux commerciaux</button>
# </a>
# <a href="https://www.mubawab.ma/fr/cr/casablanca-settat/immobilier-a-vendre-all:o:d:sc:apartment-sale,office-sale">
# <button class="btn btnFlatSmall" onclick="showLoading();" type="button">Bureaux</button>
# </a>
# <a href="https://www.mubawab.ma/fr/cr/casablanca-settat/immobilier-a-vendre-all:o:d:sc:apartment-sale,land-sale">
# <button class="btn btnFlatSmall" onclick="showLoading();" type="button">Terrains</button>
# </a>
# <a href="https://www.mubawab.ma/fr/cr/casablanca-settat/immobilier-a-vendre-all:o:d:sc:apartment-sale,farm-sale">
# <button class="btn btnFlatSmall" onclick="showLoading();" type="button">Fermes</button>
# </a>
# </div>
# <!-- Budget -->
# <div class="selectBox w100">
# <label class="selectLabel">Budget</label>
# <div class="dropdown dropdownSelect bigSelect col-6 first st-filter-price-min">
# <div class="select w100">
# <span class="blueText">
# 						Minimum
#
# 				</span>
# <i class="icon-down-dir float-right floatL"></i>
# </div>
# <ul class="selectUl">
# <li>
# <a id="selected-item-combo">
# 						Indifférent </a>
# </li>
# <li>
# <a href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:prmn:200000:o:d" onclick="showLoading()">200.000
# 						</a>
# </li>
# <li>
# <a href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:prmn:250000:o:d" onclick="showLoading()">250.000
# 						</a>
# </li>
# <li>
# <a href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:prmn:300000:o:d" onclick="showLoading()">300.000
# 						</a>
# </li>
# <li>
# <a href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:prmn:400000:o:d" onclick="showLoading()">400.000
# 						</a>
# </li>
# <li>
# <a href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:prmn:500000:o:d" onclick="showLoading()">500.000
# 						</a>
# </li>
# <li>
# <a href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:prmn:750000:o:d" onclick="showLoading()">750.000
# 						</a>
# </li>
# <li>
# <a href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:prmn:1000000:o:d" onclick="showLoading()">1.000.000
# 						</a>
# </li>
# <li>
# <a href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:prmn:1500000:o:d" onclick="showLoading()">1.500.000
# 						</a>
# </li>
# <li>
# <a href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:prmn:2000000:o:d" onclick="showLoading()">2.000.000
# 						</a>
# </li>
# <li>
# <a href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:prmn:3000000:o:d" onclick="showLoading()">3.000.000
# 						</a>
# </li>
# <li>
# <a href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:prmn:5000000:o:d" onclick="showLoading()">5.000.000
# 						</a>
# </li>
# <li>
# <a href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:prmn:7000000:o:d" onclick="showLoading()">7.000.000
# 						</a>
# </li>
# <li>
# <a href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:prmn:10000000:o:d" onclick="showLoading()">10.000.000
# 						</a>
# </li>
# <li>
# <a href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:prmn:15000000:o:d" onclick="showLoading()">15.000.000
# 						</a>
# </li>
# <li>
# <a href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:prmn:20000000:o:d" onclick="showLoading()">20.000.000
# 						</a>
# </li>
# </ul>
# </div>
# <div class="dropdown dropdownSelect bigSelect col-6 second st-filter-price-max">
# <div class="select w100">
# <span class="blueText">
# 						Maximum
#
# 				</span>
# <i class="icon-down-dir float-right floatL"></i>
# </div>
# <ul class="selectUl">
# <li>
# <a id="selected-item-combo">
# 						Indifférent </a>
# </li>
# <li>
# <a href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:prmx:200000:o:d" onclick="showLoading()">200.000
# 						</a>
# </li>
# <li>
# <a href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:prmx:250000:o:d" onclick="showLoading()">250.000
# 						</a>
# </li>
# <li>
# <a href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:prmx:300000:o:d" onclick="showLoading()">300.000
# 						</a>
# </li>
# <li>
# <a href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:prmx:400000:o:d" onclick="showLoading()">400.000
# 						</a>
# </li>
# <li>
# <a href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:prmx:500000:o:d" onclick="showLoading()">500.000
# 						</a>
# </li>
# <li>
# <a href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:prmx:750000:o:d" onclick="showLoading()">750.000
# 						</a>
# </li>
# <li>
# <a href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:prmx:1000000:o:d" onclick="showLoading()">1.000.000
# 						</a>
# </li>
# <li>
# <a href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:prmx:1500000:o:d" onclick="showLoading()">1.500.000
# 						</a>
# </li>
# <li>
# <a href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:prmx:2000000:o:d" onclick="showLoading()">2.000.000
# 						</a>
# </li>
# <li>
# <a href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:prmx:3000000:o:d" onclick="showLoading()">3.000.000
# 						</a>
# </li>
# <li>
# <a href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:prmx:5000000:o:d" onclick="showLoading()">5.000.000
# 						</a>
# </li>
# <li>
# <a href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:prmx:7000000:o:d" onclick="showLoading()">7.000.000
# 						</a>
# </li>
# <li>
# <a href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:prmx:10000000:o:d" onclick="showLoading()">10.000.000
# 						</a>
# </li>
# <li>
# <a href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:prmx:15000000:o:d" onclick="showLoading()">15.000.000
# 						</a>
# </li>
# <li>
# <a href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:prmx:20000000:o:d" onclick="showLoading()">20.000.000
# 						</a>
# </li>
# </ul>
# </div>
# </div>
# <!-- Surface -->
# <div class="selectBox w100">
# <label class="selectLabel">Surface</label>
# <div class="dropdown dropdownSelect bigSelect col-6 first st-filter-surface-min">
# <div class="select w100">
# <span class="blueText">
# 						Minimum
#
# 				</span>
# <i class="icon-down-dir float-right floatL"></i>
# </div>
# <ul class="selectUl">
# <li>
# <a id="selected-item-combo">
# 						Indifférent </a>
# </li>
# <li>
# <a href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:o:d:esmn:40" onclick="showLoading()">40
# 						</a>
# </li>
# <li>
# <a href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:o:d:esmn:60" onclick="showLoading()">60
# 						</a>
# </li>
# <li>
# <a href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:o:d:esmn:80" onclick="showLoading()">80
# 						</a>
# </li>
# <li>
# <a href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:o:d:esmn:100" onclick="showLoading()">100
# 						</a>
# </li>
# <li>
# <a href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:o:d:esmn:130" onclick="showLoading()">130
# 						</a>
# </li>
# <li>
# <a href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:o:d:esmn:160" onclick="showLoading()">160
# 						</a>
# </li>
# <li>
# <a href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:o:d:esmn:200" onclick="showLoading()">200
# 						</a>
# </li>
# <li>
# <a href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:o:d:esmn:300" onclick="showLoading()">300
# 						</a>
# </li>
# <li>
# <a href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:o:d:esmn:500" onclick="showLoading()">500
# 						</a>
# </li>
# <li>
# <a href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:o:d:esmn:700" onclick="showLoading()">700
# 						</a>
# </li>
# </ul>
# </div>
# <div class="dropdown dropdownSelect bigSelect col-6 second st-filter-surface-max">
# <div class="select w100">
# <span class="blueText">
# 						Maximum
#
# 				</span>
# <i class="icon-down-dir float-right floatL"></i>
# </div>
# <ul class="selectUl">
# <li>
# <a id="selected-item-combo">
# 						Indifférent </a>
# </li>
# <li>
# <a href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:o:d:esmx:40" onclick="showLoading()">40
# 						</a>
# </li>
# <li>
# <a href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:o:d:esmx:60" onclick="showLoading()">60
# 						</a>
# </li>
# <li>
# <a href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:o:d:esmx:80" onclick="showLoading()">80
# 						</a>
# </li>
# <li>
# <a href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:o:d:esmx:100" onclick="showLoading()">100
# 						</a>
# </li>
# <li>
# <a href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:o:d:esmx:130" onclick="showLoading()">130
# 						</a>
# </li>
# <li>
# <a href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:o:d:esmx:160" onclick="showLoading()">160
# 						</a>
# </li>
# <li>
# <a href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:o:d:esmx:200" onclick="showLoading()">200
# 						</a>
# </li>
# <li>
# <a href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:o:d:esmx:300" onclick="showLoading()">300
# 						</a>
# </li>
# <li>
# <a href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:o:d:esmx:500" onclick="showLoading()">500
# 						</a>
# </li>
# <li>
# <a href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:o:d:esmx:700" onclick="showLoading()">700
# 						</a>
# </li>
# </ul>
# </div>
# </div>
# <!-- Chambres -->
# <div class="selectBox w100">
# <label class="selectLabel">Chambres</label>
# <div class="centered numberBar">
# <div class="groupBtn inBlock">
# <!--  IMPORTANTE NO FORMATEAR O SE SEPARAN LAS CAJAS. ES MAGIA NEGRA, MALIGNA, PRETENCIOSA Y MACHISTA --><a href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:o:d:er:1" onclick="showLoading()"><button class="btn btnFlatSmall" type="button">1</button></a><a href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:o:d:er:2,3,4,5,6,7" onclick="showLoading()"><button class="btn btnFlatSmall" type="button">2</button></a><a href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:o:d:er:3,4,5,6,7" onclick="showLoading()"><button class="btn btnFlatSmall" type="button">3</button></a><a href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:o:d:er:4,5,6,7" onclick="showLoading()"><button class="btn btnFlatSmall" type="button">4</button></a><a href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:o:d:er:5,6,7" onclick="showLoading()"><button class="btn btnFlatSmall" type="button">5</button></a><a href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:o:d:er:6,7" onclick="showLoading()"><button class="btn btnFlatSmall" type="button">6</button></a><a href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:o:d:er:7" onclick="showLoading()"><button class="btn btnFlatSmall" type="button">7+</button></a>
# </div>
# </div>
# </div>
# <!-- Caract&eacute;ristiques -->
# <label class="selectLabel">Caractéristiques</label>
# <div class="centered">
# <div class="catNav">
# <a href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:pm:y:o:d">
# <button class="btn btnFlatSmall" onclick="showLoading();" type="button">
# 											Immobilier Neuf
# 											<span class="newTag arial noRtl inBlock">New!</span>
# </button>
# </a>
# <a href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:o:d:ev:y">
# <button class="btn btnFlatSmall" onclick="showLoading();" type="button">
# 											Ascenseur
#
# 									</button>
# </a>
# <a href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:o:d:eg:y">
# <button class="btn btnFlatSmall" onclick="showLoading();" type="button">
# 											Garage
#
# 									</button>
# </a>
# <a href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:o:d:ed:y">
# <button class="btn btnFlatSmall" onclick="showLoading();" type="button">
# 											Jardin
#
# 									</button>
# </a>
# <a href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:o:d:et:y">
# <button class="btn btnFlatSmall" onclick="showLoading();" type="button">
# 											Terrasse
#
# 									</button>
# </a>
# </div>
# </div>
# </div>
# </div>
# </aside>
# </div>
# <!-- end Aside -->
# <!-- START MAIN COL -->
# <div class="col-9" id="mainListing">
# <div class="float-right disFlex col-12">
# <div class="col-7">
# <p class="completionStatusButton float-right">Complétion status:</p>
# </div>
# <div class="disFlex col-5 completionStatusNav">
# <a class="col-4 completionStatusButton centered cPointer uppercase active" href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:o:d" name="all" onclick="showLoading();">
# <p>Tout</p>
# </a>
# <a class="col-4 completionStatusButton centered cPointer uppercase" href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:pm:y:o:d" name="new" onclick="showLoading();">
# <p>neuf</p>
# </a>
# <a class="col-4 completionStatusButton centered cPointer uppercase" href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:o:d:seh:y" name="second" onclick="showLoading();">
# <p>2ème main</p>
# </a>
# </div>
# </div>
# <div class="minDivider"></div>
# <!-- Listing -->
# <ul class="ulListing">
# <li class="listingBox w100" linkref="https://www.mubawab.ma/fr/a/7713734/duplex-deux-facades-sud-est-bien-ensoleille">
# <input class="adId" type="hidden" value="7713734"/>
# <div class="photoBox col-5 floatR emptyCol" data-url="https://www.mubawab-media.com/ad/7/713/734F/m/WhatsApp%20Image%202023-06-08%20at%2012.39.39%20%281%29_48876874.jpeg">
# <div class="priceBar positionAb w100 favDivPickId" id="7713734">
# <i adid="7713734" class="favHolder icon-heart-empty heartIcon heartIconBasic"></i>
# <span class="priceTag hardShadow float-right floatL">980 000 000 DH
# 					</span>
# </div>
# <div class="w100">
# <div class="sliderArrows priceBar positionAb w100" id="sliderArrows"></div>
# <div class="adSlider">
# <div class="photoMask firstMask">
# <img alt="Duplex deux facades sud/est bien ensoleille" class="w100 sliderImage firstPicture" data-url="https://www.mubawab-media.com/ad/7/713/734F/m/WhatsApp%20Image%202023-06-08%20at%2012.39.39%20%281%29_48876874.jpeg"/>
# </div>
# <div class="photoMask">
# <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/713/734F/m/WhatsApp%20Image%202019-09-05%20at%2009.34.35%20%281%29_48876876.jpeg"/>
# </div>
# <div class="photoMask last-item">
# <div class="btnBox">
# <div class="btn-voir centered bShadow" rel="follow">
# <i class="icon-eye orange fSize22"></i>
# <span>Voir l'annonce</span>
# </div>
# </div>
# <img class="w100" data-lazy="https://www.mubawab-media.com/ad/7/713/734F/m/WhatsApp%20Image%202023-06-08%20at%2012.39.39%20%281%29_48876874.jpeg"/>
# </div>
# </div>
# </div>
# </div>
# <div class="col-7 contentBox">
# <h2 class="listingTit">
# <a href="https://www.mubawab.ma/fr/a/7713734/duplex-deux-facades-sud-est-bien-ensoleille">Duplex deux facades sud/est bien ensoleil...
# 					</a>
# </h2>
# <div class="inBlock w100">
# <p class="listingH4 floatR">3 chambres, 116 m²
# 					</p>
# </div>
# <h3 class="listingH3">Oulfa à
#    					Casablanca
# 				</h3>
# <p class="listingP descLi">duplex de 116 m comprent 3 chambres deux sallons une grande cuisine renouve recament donne sur  un grand sejour  dex salles de bains
# appartement bien amenagee
# 				</p>
# <div class="controlBar sMargTop">
# <span class="listingDetails iconPadR">
# <i class="icon-calendar-plus-o iconPadR greyIcon"></i>Publié il y a 4 mois
# 					</span>
# <button class="btnContact cPointer uppercase float-right floatL" data-adid="7713734" href="#contactPopup" onclick="openContactPopup(this);" type="button">Contacter</button>
# </div>
# </div>
# </li>
# <!-- SerpTop -->
# <li class="listingBox w100" linkref="https://www.mubawab.ma/fr/a/7485272/appartement-marina-vue-mer-mosqu%C3%A9e-hassan-2">
# <input class="adId" type="hidden" value="7485272"/>
# <div class="photoBox col-5 floatR emptyCol" data-url="https://www.mubawab-media.com/ad/7/485/272F/m/212121_27956127.jpg">
# <div class="priceBar positionAb w100 favDivPickId" id="7485272">
# <i adid="7485272" class="favHolder icon-heart-empty heartIcon heartIconBasic"></i>
# <span class="priceTag hardShadow float-right floatL">530 000 000 DH
# 					</span>
# </div>
# <div class="w100">
# <div class="sliderArrows priceBar positionAb w100" id="sliderArrows"></div>
# <div class="adSlider">
# <div class="photoMask firstMask">
# <img alt="Appartement marina vue mer mosquée hassan 2" class="w100 sliderImage firstPicture" data-url="https://www.mubawab-media.com/ad/7/485/272F/m/212121_27956127.jpg"/>
# </div>
# <div class="photoMask last-item">
# <div class="btnBox">
# <div class="btn-voir centered bShadow" rel="follow">
# <i class="icon-eye orange fSize22"></i>
# <span>Voir l'annonce</span>
# </div>
# </div>
# <img class="w100" data-lazy="https://www.mubawab-media.com/ad/7/485/272F/m/212121_27956127.jpg"/>
# </div>
# </div>
# </div>
# </div>
# <div class="col-7 contentBox">
# <h2 class="listingTit">
# <a href="https://www.mubawab.ma/fr/a/7485272/appartement-marina-vue-mer-mosqu%C3%A9e-hassan-2">Appartement marina vue mer mosquée hassan...
# 					</a>
# </h2>
# <div class="inBlock w100">
# <p class="listingH4 floatR">2 chambres, 142 m²
# 					</p>
# </div>
# <h3 class="listingH3">Casablanca Marina à
#    					Casablanca
# 				</h3>
# <p class="listingP descLi">tres bel appartement de 1'ém2 dont 142m2 de garage a vendre au11 eme etage a la marina avec une magnifique sur mer mosquee hassan2 et jardin equipee de domotique et clim centralisee reversible se composant
# 						...<a class="blueText arial" href="https://www.mubawab.ma/fr/a/7485272/appartement-marina-vue-mer-mosqu%C3%A9e-hassan-2">
# 							En savoir plus
# 							<i class="icon-right-small blueIcon rotate180 inBlock"></i>
# </a>
# </p>
# <div class="controlBar sMargTop">
# <span class="listingDetails iconPadR">
# <i class="icon-calendar-plus-o iconPadR greyIcon"></i>Publié il y a 2 semaines
# 					</span>
# <button class="btnContact cPointer uppercase float-right floatL" data-adid="7485272" href="#contactPopup" onclick="openContactPopup(this);" type="button">Contacter</button>
# </div>
# </div>
# </li>
# <!-- SerpTop -->
# <li class="listingBox w100" linkref="https://www.mubawab.ma/fr/a/7679122/appartement-%C3%A0-vendre-%C3%A0-ain-diab-5-grandes-pi%C3%A8ces-ascenseur-et-terrasse">
# <input class="adId" type="hidden" value="7679122"/>
# <div class="photoBox col-5 floatR emptyCol" data-url="https://www.mubawab-media.com/ad/7/679/122F/m/photo_0_45043373.jpg">
# <div class="priceBar positionAb w100 favDivPickId" id="7679122">
# <i adid="7679122" class="favHolder icon-heart-empty heartIcon heartIconBasic"></i>
# <span class="priceTag hardShadow float-right floatL">450 000 000 DH
# 					</span>
# </div>
# <div class="w100">
# <div class="sliderArrows priceBar positionAb w100" id="sliderArrows"></div>
# <div class="adSlider">
# <div class="photoMask firstMask">
# <img alt="Appartement à vendre à Ain Diab. 5 grandes pièces. Ascenseur et terrasse" class="w100 sliderImage firstPicture" data-url="https://www.mubawab-media.com/ad/7/679/122F/m/photo_0_45043373.jpg"/>
# </div>
# <div class="photoMask last-item">
# <div class="btnBox">
# <div class="btn-voir centered bShadow" rel="follow">
# <i class="icon-eye orange fSize22"></i>
# <span>Voir l'annonce</span>
# </div>
# </div>
# <img class="w100" data-lazy="https://www.mubawab-media.com/ad/7/679/122F/m/photo_0_45043373.jpg"/>
# </div>
# </div>
# </div>
# </div>
# <div class="col-7 contentBox">
# <h2 class="listingTit">
# <a href="https://www.mubawab.ma/fr/a/7679122/appartement-%C3%A0-vendre-%C3%A0-ain-diab-5-grandes-pi%C3%A8ces-ascenseur-et-terrasse">Appartement à vendre à Ain Diab. 5 grande...
# 					</a>
# </h2>
# <div class="inBlock w100">
# <p class="listingH4 floatR">3 chambres, 280 m²
# 					</p>
# </div>
# <h3 class="listingH3">Ain Diab à
#    					Casablanca
# 				</h3>
# <p class="listingP descLi">affaire à saisir pour cet appartement à vendre. prix 450 000 000 dh. 5 pièces, 2 salles de bains privatives, 280 m². 3 chambres. 4ème étage. moins de 20 ans. type de sol: marbre. nombreux équipements dont
# 						...<a class="blueText arial" href="https://www.mubawab.ma/fr/a/7679122/appartement-%C3%A0-vendre-%C3%A0-ain-diab-5-grandes-pi%C3%A8ces-ascenseur-et-terrasse">
# 							En savoir plus
# 							<i class="icon-right-small blueIcon rotate180 inBlock"></i>
# </a>
# </p>
# <div class="controlBar sMargTop">
# <span class="listingDetails iconPadR">
# <i class="icon-calendar-plus-o iconPadR greyIcon"></i>Publié il y a plus de 6 mois
# 					</span>
# <button class="btnContact cPointer uppercase float-right floatL" data-adid="7679122" href="#contactPopup" onclick="openContactPopup(this);" type="button">Contacter</button>
# </div>
# </div>
# </li>
# <!-- SerpTop -->
# <li class="listingBox w100" linkref="https://www.mubawab.ma/fr/a/7708719/opportunit%C3%A9-%C3%A0-saisir">
# <input class="adId" type="hidden" value="7708719"/>
# <div class="photoBox col-5 floatR emptyCol" data-url="https://www.mubawab-media.com/ad/7/708/719F/m/IMG_7838%5B1%5D_48375470.JPG">
# <div class="priceBar positionAb w100 favDivPickId" id="7708719">
# <i adid="7708719" class="favHolder icon-heart-empty heartIcon heartIconBasic"></i>
# <span class="priceTag hardShadow float-right floatL">165 000 000 DH
# 					</span>
# </div>
# <div class="w100">
# <div class="sliderArrows priceBar positionAb w100" id="sliderArrows"></div>
# <div class="adSlider">
# <div class="photoMask firstMask">
# <img alt="Opportunité à saisir" class="w100 sliderImage firstPicture" data-url="https://www.mubawab-media.com/ad/7/708/719F/m/IMG_7838%5B1%5D_48375470.JPG"/>
# </div>
# <div class="photoMask">
# <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/708/719F/m/IMG_7840%5B1%5D_48375473.JPG"/>
# </div>
# <div class="photoMask">
# <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/708/719F/m/IMG_7841%5B1%5D_48375474.JPG"/>
# </div>
# <div class="photoMask">
# <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/708/719F/m/IMG_7842%5B1%5D_48375475.JPG"/>
# </div>
# <div class="photoMask">
# <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/708/719F/m/IMG_7843%5B1%5D_48375476.JPG"/>
# </div>
# <div class="photoMask">
# <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/708/719F/m/IMG_7850%5B1%5D_48375477.JPG"/>
# </div>
# <div class="photoMask">
# <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/708/719F/m/IMG_7854%5B1%5D_48375478.JPG"/>
# </div>
# <div class="photoMask">
# <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/708/719F/m/IMG_7847%5B1%5D_48375479.JPG"/>
# </div>
# <div class="photoMask">
# <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/708/719F/m/IMG_7845%5B1%5D_48375480.JPG"/>
# </div>
# <div class="photoMask last-item">
# <div class="btnBox">
# <div class="btn-voir centered bShadow" rel="follow">
# <i class="icon-eye orange fSize22"></i>
# <span>Voir l'annonce</span>
# </div>
# </div>
# <img class="w100" data-lazy="https://www.mubawab-media.com/ad/7/708/719F/m/IMG_7838%5B1%5D_48375470.JPG"/>
# </div>
# </div>
# </div>
# </div>
# <div class="col-7 contentBox">
# <h2 class="listingTit">
# <a href="https://www.mubawab.ma/fr/a/7708719/opportunit%C3%A9-%C3%A0-saisir">Opportunité à saisir
# 					</a>
# </h2>
# <div class="inBlock w100">
# <p class="listingH4 floatR">3 chambres, 110 m²
# 					</p>
# </div>
# <h3 class="listingH3">Anfa Supérieur à
#    					Casablanca
# 				</h3>
# <p class="listingP descLi">jolie appartement à vendre, bien ensoleillé, d’une superficie de 110m2 avec deux façades, dans un immeuble moderne de 5 étages avec ascenseur sur une ruelle calme du boulevard 2 mars, proche de toutes les
# 						...<a class="blueText arial" href="https://www.mubawab.ma/fr/a/7708719/opportunit%C3%A9-%C3%A0-saisir">
# 							En savoir plus
# 							<i class="icon-right-small blueIcon rotate180 inBlock"></i>
# </a>
# </p>
# <div class="controlBar sMargTop">
# <span class="listingDetails iconPadR">
# <i class="icon-calendar-plus-o iconPadR greyIcon"></i>Publié il y a 5 mois
# 					</span>
# <button class="btnContact cPointer uppercase float-right floatL" data-adid="7708719" href="#contactPopup" onclick="openContactPopup(this);" type="button">Contacter</button>
# </div>
# </div>
# </li>
# <!-- SerpTop -->
# <li class="listingBox w100" linkref="https://www.mubawab.ma/fr/a/7686974/appartement-%C3%A0-vendre-%C3%A0-les-h%C3%B4pitaux-surface-totale-113-m%C2%B2-chemin%C3%A9e-et-service-de-conciergerie">
# <input class="adId" type="hidden" value="7686974"/>
# <div class="photoBox col-5 floatR emptyCol" data-url="https://www.mubawab-media.com/ad/7/686/974F/m/photo_00_45977401.jpg">
# <div class="priceBar positionAb w100 favDivPickId" id="7686974">
# <i adid="7686974" class="favHolder icon-heart-empty heartIcon heartIconBasic"></i>
# <span class="priceTag hardShadow float-right floatL">156 000 000 DH
# 					</span>
# </div>
# <div class="w100">
# <div class="sliderArrows priceBar positionAb w100" id="sliderArrows"></div>
# <div class="adSlider">
# <div class="photoMask firstMask">
# <img alt="Appartement à vendre à Les Hôpitaux. Surface totale 113 m². Cheminée et service de conciergerie" class="w100 sliderImage firstPicture" data-url="https://www.mubawab-media.com/ad/7/686/974F/m/photo_00_45977401.jpg"/>
# </div>
# <div class="photoMask">
# <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/686/974F/m/photo_01_45977402.jpg"/>
# </div>
# <div class="photoMask">
# <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/686/974F/m/photo_02_45977403.jpg"/>
# </div>
# <div class="photoMask">
# <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/686/974F/m/photo_03_45977404.jpg"/>
# </div>
# <div class="photoMask">
# <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/686/974F/m/photo_04_45977405.jpg"/>
# </div>
# <div class="photoMask">
# <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/686/974F/m/photo_05_45977406.jpg"/>
# </div>
# <div class="photoMask">
# <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/686/974F/m/photo_06_45977407.jpg"/>
# </div>
# <div class="photoMask">
# <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/686/974F/m/photo_07_45977408.jpg"/>
# </div>
# <div class="photoMask">
# <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/686/974F/m/photo_08_45977409.jpg"/>
# </div>
# <div class="photoMask">
# <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/686/974F/m/photo_09_45977410.jpg"/>
# </div>
# <div class="photoMask">
# <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/686/974F/m/photo_010_45977411.jpg"/>
# </div>
# <div class="photoMask last-item">
# <div class="btnBox">
# <div class="btn-voir centered bShadow" rel="follow">
# <i class="icon-eye orange fSize22"></i>
# <span>Voir l'annonce</span>
# </div>
# </div>
# <img class="w100" data-lazy="https://www.mubawab-media.com/ad/7/686/974F/m/photo_00_45977401.jpg"/>
# </div>
# </div>
# </div>
# </div>
# <div class="col-7 contentBox">
# <h2 class="listingTit">
# <a href="https://www.mubawab.ma/fr/a/7686974/appartement-%C3%A0-vendre-%C3%A0-les-h%C3%B4pitaux-surface-totale-113-m%C2%B2-chemin%C3%A9e-et-service-de-conciergerie">Appartement à vendre à Les Hôpitaux. Surf...
# 					</a>
# </h2>
# <div class="inBlock w100">
# <p class="listingH4 floatR">2 chambres, 113 m²
# 					</p>
# </div>
# <h3 class="listingH3">Les Hôpitaux à
#    					Casablanca
# 				</h3>
# <p class="listingP descLi">très belle opportunité !
#
# vente directe d’un appartement moyen standing de 104 m2 au 3ème étage avec façade bien ensoleillé et bien entretenu.
#
# l'appartement se compose de :
# - 1 grand salon bien
# 						...<a class="blueText arial" href="https://www.mubawab.ma/fr/a/7686974/appartement-%C3%A0-vendre-%C3%A0-les-h%C3%B4pitaux-surface-totale-113-m%C2%B2-chemin%C3%A9e-et-service-de-conciergerie">
# 							En savoir plus
# 							<i class="icon-right-small blueIcon rotate180 inBlock"></i>
# </a>
# </p>
# <div class="controlBar sMargTop">
# <span class="listingDetails iconPadR">
# <i class="icon-calendar-plus-o iconPadR greyIcon"></i>Publié il y a plus de 6 mois
# 					</span>
# <button class="btnContact cPointer uppercase float-right floatL" data-adid="7686974" href="#contactPopup" onclick="openContactPopup(this);" type="button">Contacter</button>
# </div>
# </div>
# </li>
# <!-- SerpTop -->
# <div class="relatPromoAdTitle blueText">
# <h4 class="col-10">Immobilier neuf</h4>
# <a class="col-2 float-right" href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:pm:y:o:d">Voir tous</a>
# </div>
# <div class="w100">
# <div class="sliderArrows" id="sliderArrows"></div>
# <div class="col-11">
# <div class="promotionAdsSlider">
# <div class="relatPromoAdImgBox col-2_5">
# <div class="relatPromoAdMarg">
# <a href="https://www.mubawab.ma/fr/pa/7443168/appartement-de-99-m%C2%B2-en-vente-eden-island-bouznika">
# <div class="relatImg boxShadow">
# <img class="w100 borderRadius" src="https://www.mubawab-media.com/ad/7/443/168F/m/9Q5A1754_58679532.jpg"/>
# </div>
# <div class="dataRelat relatPromoAd boxShadow centered">
# <div>
# <span class="orangeText bold">2 425 000 DH
# 												</span>
# <p class="fSize10 w100 disBlock">2 Pièces, 1 Chambres</p>
# <p class="fSize10 promoAdLocation">Plage Oued Cherrat à
# 															Bouznika</p>
# </div>
# </div>
# <div class="relatPromoAdBtn">
# <p>EN SAVOIR PLUS</p>
# </div>
# </a>
# </div>
# </div>
# <div class="relatPromoAdImgBox col-2_5">
# <div class="relatPromoAdMarg">
# <a href="https://www.mubawab.ma/fr/pa/7794563/appartement-en-vente-%C3%A0-californie-surface-totale-175-m%C2%B2">
# <div class="relatImg boxShadow">
# <img class="w100 borderRadius" src="https://www.mubawab-media.com/ad/7/794/563F/m/1_12017488_12056120_58294585.jpg"/>
# </div>
# <div class="dataRelat relatPromoAd boxShadow centered">
# <div>
# <span class="orangeText bold">2 138 440 DH
# 												</span>
# <p class="fSize10 w100 disBlock">3 Pièces, 3 Chambres</p>
# ...
# <img alt="Young Associates Maroc" class="relatedImg" src="https://www.mubawab-media.com/business/5/145F/s/ya-logo-instagram.jpg"/>
# </a>
# </div>
# <a href="https://www.mubawab.ma/fr/b/5145/young-associates-maroc">
# <div class="relatedPhotoBox">
# <img class="relatedPhoto w100" src="https://www.mubawab-media.com/ad/7/811/900F/m/54379886a_60719428.jpg"/>
# </div>
# </a>
# <a href="https://www.mubawab.ma/fr/b/5145/young-associates-maroc">
# <div class="relatedText">
# <h5 class="relatedTit">Young Associates Maroc
# 														</h5>
# <p class="relatedSubTit">Tanger
# 														</p>
# </div>
# </a>
# </div>
# </div>
# <div class="col-3">
# <div class="relatedBox">
# <div class="relatedLogo bShadow centered">
# <a class="relatedImgLink" href="https://www.mubawab.ma/fr/b/6845/casa-immo-store">
# <img alt="Casa Immo Store" class="relatedImg" src="https://www.mubawab-media.com/business/6/845F/s/WhatsApp%20Image%202019-07-31%20at%2012.20.34.jpeg"/>
# </a>
# </div>
# <a href="https://www.mubawab.ma/fr/b/6845/casa-immo-store">
# <div class="relatedPhotoBox">
# <img class="relatedPhoto w100" src="https://www.mubawab-media.com/ad/7/820/195F/m/WhatsApp%20Image%202023-11-27%20at%2016.55.38%20%283%29_61409874.jpeg"/>
# </div>
# </a>
# <a href="https://www.mubawab.ma/fr/b/6845/casa-immo-store">
# <div class="relatedText">
# <h5 class="relatedTit">Casa Immo Store
# 														</h5>
# <p class="relatedSubTit">Casablanca
# 														</p>
# </div>
# </a>
# </div>
# </div>
# <div class="col-3">
# <div class="relatedBox">
# <div class="relatedLogo bShadow centered">
# <a class="relatedImgLink" href="https://www.mubawab.ma/fr/b/4819/lasry-consulting">
# <img alt="LASRY CONSULTING" class="relatedImg" src="https://www.mubawab-media.com/business/4/819F/s/LOGO%20LASRY%20CONSULTING_11152421.jpeg"/>
# </a>
# </div>
# <a href="https://www.mubawab.ma/fr/b/4819/lasry-consulting">
# <div class="relatedPhotoBox">
# <img class="relatedPhoto w100" src="https://www.mubawab-media.com/ad/7/821/614F/m/20231129_111358_61579599.jpg"/>
# </div>
# </a>
# <a href="https://www.mubawab.ma/fr/b/4819/lasry-consulting">
# <div class="relatedText">
# <h5 class="relatedTit">LASRY CONSULTING
# 														</h5>
# <p class="relatedSubTit">Casablanca
# 														</p>
# </div>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- Related Agencies - END -->
# <!-- divider -->
# <div class="divider"></div>
# </div>
# <!-- end col-9 -->
# </div>
# <!-- end main container -->
# <!-- prefooter -->
# <div class="preFoot greyBlock" style="display: none;">
# <div class="contnr1100" id="footerListingLinks"></div>
# </div>
# <!-- end prefooter -->
# </section>
# <!-- end section -->
# <!-- Popup: Save search - INI -->
# <div class="popupBox popupMed centered" data-role="popup" id="saveSearchPopup" style="display: none;">
# <div class="centered">
# <img class="floatingImg" src="https://www.mubawab-media.com/assets/desktop/public/bell-yellow.png"/>
# </div>
# <div id="logoPop">
# <h2 class="fSize20 darkgrey">Recevez en exclusivité les nouvelles propriétés </h2>
# <p class="sMargTop">Selon vos critères de recherche</p>
# </div>
# <div class="innerBoxPop">
# <div class="catNav mouseNone">
# <div class="btn btnFlatSmall">Appartements à vendre</div>
# </div>
# <form action="https://www.mubawab.ma/fr/ajax/desktop/web/public/create-alert" class="popupForm" id="alertForm">
# <input name="transaction" type="hidden" value="sale"/>
# <input name="adType" type="hidden" value="apartment-sale"/>
# <input name="city" type="hidden"/>
# <input name="district" type="hidden"/>
# <input name="town" type="hidden"/>
# <input name="minPrice" type="hidden"/>
# <input name="maxPrice" type="hidden"/>
# <input name="minSurface" type="hidden"/>
# <input name="maxSurface" type="hidden"/>
# <input name="features" type="hidden" value="[]"/>
# <input name="rooms" type="hidden"/>
# <input name="zoneCreated" type="hidden" value="listing"/>
# <input name="url" type="hidden" value="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:o:d"/>
# <input name="groupAdType" type="hidden"/>
# <input id="alertLeadId" name="leadId" type="hidden"/>
# <input id="alertEmail" name="email" placeholder="Votre adresse email *" type="text"/>
# <div class="action-btn sMargTop">
# <button class="btn yellowBtn centered white saveButton" onclick="window.dataLayer.push({'event' : 'createAlert'});" type="submit">Me notifier par email</button>
# </div>
# </form>
# <div class="" id="saveAlertResult" style="display: none"></div>
# <span class="legalNote w100">
# 					En cliquant sur "Me notifier par email", j'accepte la
# 					<a class="underline" href="https://www.mubawab.ma/fr/privacy#anchorText" target="_blank">politique de protection des données</a>
# </span>
# </div>
# <div class="fancybox-close" data-rel="close" title="Fermer"></div>
# </div>
# <!-- Popup: Save search - END -->
# <!-- Popup: Contact - INI -->
# <div class="popupBox centered popupMed" data-role="popup" id="contactPopup" style="display: none;">
# <div class="centered">
# <img class="floatingImg" src="https://www.mubawab-media.com/assets/desktop/public/house-orange.png"/>
# </div>
# <div id="logoPop">
# <h2 class="fSize16 leadPictureFormTitle">Contacter l'annonceur</h2>
# <p class="sMargTop greyIcon">Veuillez nous laisser vos coordonnées sur lesquels vous souhaitez être rappelé.</p>
# </div>
# <div class="innerBoxPop">
# <form action="https://www.mubawab.ma/fr/ajax/common/create-lead-request" class="popupForm leadForm" id="leadForm" name="leadForm">
# <input id="sourceHiddenBox" name="source" type="hidden"/>
# <input id="landingHiddenBox" name="landing" type="hidden"/>
# <input id="id" name="id" type="hidden"/>
# <input id="type" name="type" type="hidden" value="DIRECT"/>
# <input id="zoneCreatedId" name="zoneCreated" type="hidden" value="listing"/>
# <input name="htmlResponse" type="hidden" value="true"/>
# <input class="name _chkRequired" name="name" placeholder="Votre nom" type="text"/>
# <input autocapitalize="none" class="email _chkRequired _chkEmail" name="email" placeholder="Votre adresse email" type="text"/>
# <input class="phone _chkRequired" name="phone" placeholder="Votre Téléphone" type="text"/>
# <input id="adType" name="adType" type="hidden" value="promotion"/>
# <input name="device" type="hidden" value="DESKTOP"/>
# <div class="action-btn">
# <button class="btn btnFlatMed uppercase centered" type="submit">Contacter</button>
# </div>
# </form>
# <span class="legalNote">
# 				En cliquant sur "Contacter", j'accepte la
# 				<a class="underline" href="https://www.mubawab.ma/fr/privacy#anchorText" target="_blank">politique de protection des données</a>
# </span>
# </div>
# <div class="fancybox-close" data-rel="close" title="Fermer"></div>
# </div>
# <!-- Popup: Contact - END -->
# <!-- Popup: Related ads - INI -->
# <div class="popupBox popupBig leadPopBox" data-role="popup" id="relatedPropsPopup" style="display: none;"></div>
# <!-- Popup: Related ads - END -->
# <!-- Popup: Favourites - INI -->
# <div class="popupBox centered" data-role="popup" id="favouritesPopup" style="display: none;">
# <div class="centered">
# <img class="floatingImg" src="https://www.mubawab-media.com/assets/desktop/public/heart-red.png"/>
# </div>
# <div id="logoPop">
# <h2 class="fSize20">Ajouter à vos favoris</h2>
# <p class="sMargTop greyIcon">Ajoutez cette annonce à votre liste de favoris pour l'avoir toujours à portée de main.</p>
# </div>
# <div class="innerBoxPop">
# <form class="popupForm" id="favouritesForm">
# <input id="adIdFav" name="adIdFav" type="hidden"/>
# <input id="actionFav" name="actionFav" type="hidden"/>
# <input autocapitalize="none" class="email whiteBg" id="emailFieldFav" name="email" placeholder="Votre adresse email" type="text"/>
# <div class="action-btn">
# <button class="btn btnFlatMed centered" id="favButton" type="submit">Ajouter à vos favoris</button>
# </div>
# </form>
# <span class="legalNote">
# 					En cliquant sur "Ajouter à vos favoris", j'accepte la
# 					<a class="underline" href="https://www.mubawab.ma/fr/privacy#anchorText" target="_blank">politique de protection des données</a>
# </span>
# </div>
# <div class="fancybox-close" data-rel="close" title="Fermer"></div>
# </div>
# <!-- Popup: Favourites - END -->
# <!-- Popup: Order - INI -->
# <div class="popSmall" data-role="popup" id="orderPopup" style="display: none;">
# <div class="popupBox popSelect" style="margin-left: 50%; left: -150px; top: 200px; z-index: 1011;">
# <div class="titPopBox centered">
# <div class="inBlock darkblue">
# <i class="icon-sort-alt-up floatR iconPadR"></i>
# <h3 class="popupTitle inBlock">Trier par</h3>
# </div>
# </div>
# <a href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre" onclick="showLoading();">
# <span class="popOption">Pertinence</span>
# </a>
# <a href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:o:n" onclick="showLoading();">
# <span class="popOption">Date</span>
# </a>
# <a href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:o:a" onclick="showLoading();">
# <span class="popOption">Prix minimum</span>
# </a>
# <a href="https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:o:d" onclick="showLoading();">
# <span class="popOption">Prix maximum</span>
# </a>
# <div class="fancybox-close" data-rel="close" title="Fermer"></div>
# </div>
# </div>
# <!-- Popup: Order - END -->
# <!-- FOOTER -->
# <footer class="w100" id="footer">
# <div class="row foot-nav">
# <div class="col-3">
# <h3 class="main-logo centered floatR">
# <a href="https://www.mubawab.ma/fr/app-mobile">
# <p class="logoDownloadText">Télécharger</p>
# <img alt="Mubawab Le 1er site immobilier du Maroc" class="footer-logo logoNeg" src="https://www.mubawab-media.com/assets/logos/mubawab.png" title="Mubawab Le 1er site immobilier du Maroc"/>
# </a>
# <a class="inBlock" href="https://play.google.com/store/apps/details?id=com.mubawab.iosmubawab&amp;hl=en_US">
# <img alt="Mubawab Le 1er site immobilier du Maroc" class="inBlock playStore" src="https://www.mubawab-media.com/assets/common/app-store/google-play-small.png" title="Mubawab Le 1er site immobilier du Maroc"/>
# </a>
# <a class="inBlock" href="https://apps.apple.com/es/app/mubawab-immobilier-au-maroc/id1036167735">
# <img alt="Mubawab Le 1er site immobilier du Maroc" class="inBlock appStore" src="https://www.mubawab-media.com/assets/common/app-store/app-store-small.png" title="Mubawab Le 1er site immobilier du Maroc"/>
# </a>
# </h3>
# </div>
# <div class="col-3">
# <div class="main-nav">
# <ul class="footerUl">
# <li>
# <a href="https://www.mubawab.ma/fr/posting" rel="follow" title="Publier une annonce">Publier une annonce</a>
# </li>
# <li>
# <a href="https://www.mubawab.ma/fr/create-business" rel="nofollow" title="Inscrivez votre entreprise">Inscrivez votre entreprise</a>
# </li>
# <li>
# <a href="https://blog.mubawab.ma" rel="nofollow" title="Blog">Blog</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="col-3">
# <div class="main-nav">
# <ul class="footerUl">
# <li>
# <a href="https://www.mubawab.ma/fr/about" rel="nofollow" title="Qui sommes nous?">Qui sommes nous?</a>
# </li>
# <li>
# <a href="https://www.mubawab.ma/fr/contact" rel="nofollow" title="Contactez-nous">Contactez-nous</a>
# </li>
# <li>
# <a href="https://www.mubawab.ma/fr/faqs" rel="nofollow" title="FAQ's">FAQ's</a>
# </li>
# <li>
# <a href="https://www.mubawab.ma/fr/privacy" rel="nofollow" title="Conditions d'utilisation">Conditions d'utilisation</a>
# </li>
# <li>
# <a href="https://www.mubawab.ma/fr/privacy#anchorText" rel="nofollow" title="Protection des données">Protection des données</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="col-3">
# <div class="main-nav">
# <ul class="footerUl">
# <li>
# <a href="http://mubawab.listglobally.com/" rel="nofollow" title="International">International</a>
# </li>
# </ul>
# </div>
# <!-- COUNTRY SELECT -->
# <div class="dropdown dropdownSelect">
# <div class="select">
# <span>Changer de pays  </span>
# <i class="icon-down-dir float-right floatL"></i>
# </div>
# <ul class="selectUl">
# <li class="alignR disabled">
# <a href="https://www.mubawab.ma">Maroc</a>
# </li>
# <li class="alignR">
# <a href="https://www.mubawab.tn">Tunisie</a>
# </li>
# <li class="alignR">
# <a href="https://www.bayut.com">EAU</a>
# </li>
# <li class="alignR">
# <a href="https://www.zameen.com">Pakistan</a>
# </li>
# <li class="alignR">
# <a href="https://www.bproperty.com">Bangladesh</a>
# </li>
# </ul>
# </div>
# <!-- SOCIAL ICONS -->
# <div class="socialFoot">
# <a class="icon-fb float-left floatR" href="https://business.facebook.com/Mubawab.ma" rel="nofollow" target="_blank" title="Facebook">
# <i class="icon-facebook"></i>
# </a>
# <a class="icon-tw float-left floatR" href="https://twitter.com/Mubawab_ma" rel="nofollow" target="_blank" title="Twitter">
# <i class="icon-twitter"></i>
# </a>
# <a class="icon-bl float-left floatR" href="https://blog.mubawab.ma" rel="nofollow" target="_blank" title="Blog">
# <i class="icon-box"></i>
# </a>
# <a class="icon-yt float-left floatR" href="https://www.youtube.com/@MubawabMaroc" rel="nofollow" target="_blank" title="Youtube">
# <i class="icon-youtube-play"></i>
# </a>
# <a class="icon-ig float-left floatR" href="https://www.instagram.com/mubawab_maroc" rel="nofollow" target="_blank" title="Instagram">
# <i class="icon-instagram"></i>
# </a>
# </div>
# </div>
# </div>
# <div class="row">
# <div class="socket col-12 centered">
# <p id="copyright">© {year} Mubawab SL. Tous droits réservés.
# 					–
# 					<span class="centered">Le 1er site immobilier du Maroc</span>
# </p>
# </div>
# </div>
# </footer>
# <!-- COOKIE WARNING -->
# <div class="cookieWarning" style="display: none">
# <div class="row">
# <div class="col-9">
# <p class="cookieText">
# <i class="icon-info-circled blueText"></i> Nous utilisons nos propres cookies et ceux de tiers à des fins d'analyse et pour vous montrer des publicités personnalisées en fonction d'un profil basé sur vos habitudes de navigation (par exemple, les pages visitées). <a href="https://www.mubawab.ma/fr/cookies">Cliquez ICI</a>
# 					pour plus d'informations
# 				</p>
# </div>
# <div class="col-3">
# <div class="action-btn centered">
# <button class="btn btnFlatMed uppercase centered" name="leadFormButton" onclick="setAcceptCookies(true);">Accepter</button>
# </div>
# </div>
# </div>
# </div>
# <!-- end COOKIE WARNING -->
# <script src="https://www.gstatic.com/firebasejs/7.2.3/firebase-app.js"></script>
# <script src="https://www.gstatic.com/firebasejs/7.2.3/firebase-messaging.js"></script><script src="/jsJawrPath/gzip_N266420987/components/firebase.js" type="text/javascript"></script>
# <script src="/jsJawrPath/gzip_N721185790/desktop/web/common/common.js" type="text/javascript"></script>
# <script src="/jsJawrPath/gzip_N539449040/components/popup.js" type="text/javascript"></script>
# <script>
# 		const HTTPD_HOSTNAME = 'https://www.mubawab-media.com/';
# 	</script><script src="/jsJawrPath/gzip_2143521641/components/encrypt.js" type="text/javascript"></script>
# <script src="/jsJawrPath/gzip_1583819148/components/subscribePush.js" type="text/javascript"></script>
# <script src="/jsJawrPath/gzip_274374308/components/slider.js" type="text/javascript"></script>
# <script src="/jsJawrPath/gzip_N1769579374/components/validator.js" type="text/javascript"></script>
# <script src="/jsJawrPath/gzip_N1162026970/desktop/web/public/listing.js" type="text/javascript"></script>
# <script>
# 			window.dataLayer.push({
# 				'listingId' : 'apartment-sale'
# 				});
# 		</script>
# <script type="text/javascript">
# 		initHeader('listing');
# 		hideScripts();
# 	</script>
# <input id="loadFooterListingLinksUrl" type="hidden" value="https://www.mubawab.ma/fr/ajax/desktop/web/public/load-footer-listing-links"/>
# <input id="transactionHidden" type="hidden" value="sale"/>
# <input id="adTypeHidden" type="hidden" value="apartment-sale"/>
# <input id="regionHidden" type="hidden" value="5"/>
# <input id="provinceHidden" type="hidden"/>
# <input id="cityHidden" type="hidden"/>
# <input id="districtHidden" type="hidden"/>
# <input id="townHidden" type="hidden"/>
# <input id="languageHidden" type="hidden" value="FR"/>
# <input id="viewNameHidden" type="hidden" value="listing"/>
# <input id="transactionIndexedSearchHidden" type="hidden"/>
# <input id="cityIndexedSearchHidden" type="hidden"/>
# <input id="townIndexedSearchHidden" type="hidden"/>
# <input id="excludedSearchs" type="hidden" value="42671;35647"/>
# <div id="footerListingLinks"></div>
# <script>
# 			loadFooterLinks();
# 		</script></body>
# </html>

# %% [markdown]
# *Use BeautifulSoup's select function to scrape the desired content*

# %%
housing = soup.select(".listingH3 , #mainListing .floatR , .listingTit a , .hardShadow")
housing
# Out:
# [<div class="photoBox col-5 floatR emptyCol" data-url="https://www.mubawab-media.com/ad/7/713/734F/m/WhatsApp%20Image%202023-06-08%20at%2012.39.39%20%281%29_48876874.jpeg">
#  <div class="priceBar positionAb w100 favDivPickId" id="7713734">
#  <i adid="7713734" class="favHolder icon-heart-empty heartIcon heartIconBasic"></i>
#  <span class="priceTag hardShadow float-right floatL">980 000 000 DH
#  					</span>
#  </div>
#  <div class="w100">
#  <div class="sliderArrows priceBar positionAb w100" id="sliderArrows"></div>
#  <div class="adSlider">
#  <div class="photoMask firstMask">
#  <img alt="Duplex deux facades sud/est bien ensoleille" class="w100 sliderImage firstPicture" data-url="https://www.mubawab-media.com/ad/7/713/734F/m/WhatsApp%20Image%202023-06-08%20at%2012.39.39%20%281%29_48876874.jpeg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/713/734F/m/WhatsApp%20Image%202019-09-05%20at%2009.34.35%20%281%29_48876876.jpeg"/>
#  </div>
#  <div class="photoMask last-item">
#  <div class="btnBox">
#  <div class="btn-voir centered bShadow" rel="follow">
#  <i class="icon-eye orange fSize22"></i>
#  <span>Voir l'annonce</span>
#  </div>
#  </div>
#  <img class="w100" data-lazy="https://www.mubawab-media.com/ad/7/713/734F/m/WhatsApp%20Image%202023-06-08%20at%2012.39.39%20%281%29_48876874.jpeg"/>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <span class="priceTag hardShadow float-right floatL">980 000 000 DH
#  					</span>,
#  <a href="https://www.mubawab.ma/fr/a/7713734/duplex-deux-facades-sud-est-bien-ensoleille">Duplex deux facades sud/est bien ensoleil...
#  					</a>,
#  <p class="listingH4 floatR">3 chambres, 116 m²
#  					</p>,
#  <h3 class="listingH3">Oulfa à
#     					Casablanca
#  				</h3>,
#  <div class="photoBox col-5 floatR emptyCol" data-url="https://www.mubawab-media.com/ad/7/485/272F/m/212121_27956127.jpg">
#  <div class="priceBar positionAb w100 favDivPickId" id="7485272">
#  <i adid="7485272" class="favHolder icon-heart-empty heartIcon heartIconBasic"></i>
#  <span class="priceTag hardShadow float-right floatL">530 000 000 DH
#  					</span>
#  </div>
#  <div class="w100">
#  <div class="sliderArrows priceBar positionAb w100" id="sliderArrows"></div>
#  <div class="adSlider">
#  <div class="photoMask firstMask">
#  <img alt="Appartement marina vue mer mosquée hassan 2" class="w100 sliderImage firstPicture" data-url="https://www.mubawab-media.com/ad/7/485/272F/m/212121_27956127.jpg"/>
#  </div>
#  <div class="photoMask last-item">
#  <div class="btnBox">
#  <div class="btn-voir centered bShadow" rel="follow">
#  <i class="icon-eye orange fSize22"></i>
#  <span>Voir l'annonce</span>
#  </div>
#  </div>
#  <img class="w100" data-lazy="https://www.mubawab-media.com/ad/7/485/272F/m/212121_27956127.jpg"/>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <span class="priceTag hardShadow float-right floatL">530 000 000 DH
#  					</span>,
#  <a href="https://www.mubawab.ma/fr/a/7485272/appartement-marina-vue-mer-mosqu%C3%A9e-hassan-2">Appartement marina vue mer mosquée hassan...
#  					</a>,
#  <p class="listingH4 floatR">2 chambres, 142 m²
#  					</p>,
#  <h3 class="listingH3">Casablanca Marina à
#     					Casablanca
#  				</h3>,
#  <div class="photoBox col-5 floatR emptyCol" data-url="https://www.mubawab-media.com/ad/7/679/122F/m/photo_0_45043373.jpg">
#  <div class="priceBar positionAb w100 favDivPickId" id="7679122">
#  <i adid="7679122" class="favHolder icon-heart-empty heartIcon heartIconBasic"></i>
#  <span class="priceTag hardShadow float-right floatL">450 000 000 DH
#  					</span>
#  </div>
#  <div class="w100">
#  <div class="sliderArrows priceBar positionAb w100" id="sliderArrows"></div>
#  <div class="adSlider">
#  <div class="photoMask firstMask">
#  <img alt="Appartement à vendre à Ain Diab. 5 grandes pièces. Ascenseur et terrasse" class="w100 sliderImage firstPicture" data-url="https://www.mubawab-media.com/ad/7/679/122F/m/photo_0_45043373.jpg"/>
#  </div>
#  <div class="photoMask last-item">
#  <div class="btnBox">
#  <div class="btn-voir centered bShadow" rel="follow">
#  <i class="icon-eye orange fSize22"></i>
#  <span>Voir l'annonce</span>
#  </div>
#  </div>
#  <img class="w100" data-lazy="https://www.mubawab-media.com/ad/7/679/122F/m/photo_0_45043373.jpg"/>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <span class="priceTag hardShadow float-right floatL">450 000 000 DH
#  					</span>,
#  <a href="https://www.mubawab.ma/fr/a/7679122/appartement-%C3%A0-vendre-%C3%A0-ain-diab-5-grandes-pi%C3%A8ces-ascenseur-et-terrasse">Appartement à vendre à Ain Diab. 5 grande...
#  					</a>,
#  <p class="listingH4 floatR">3 chambres, 280 m²
#  					</p>,
#  <h3 class="listingH3">Ain Diab à
#     					Casablanca
#  				</h3>,
#  <div class="photoBox col-5 floatR emptyCol" data-url="https://www.mubawab-media.com/ad/7/708/719F/m/IMG_7838%5B1%5D_48375470.JPG">
#  <div class="priceBar positionAb w100 favDivPickId" id="7708719">
#  <i adid="7708719" class="favHolder icon-heart-empty heartIcon heartIconBasic"></i>
#  <span class="priceTag hardShadow float-right floatL">165 000 000 DH
#  					</span>
#  </div>
#  <div class="w100">
#  <div class="sliderArrows priceBar positionAb w100" id="sliderArrows"></div>
#  <div class="adSlider">
#  <div class="photoMask firstMask">
#  <img alt="Opportunité à saisir" class="w100 sliderImage firstPicture" data-url="https://www.mubawab-media.com/ad/7/708/719F/m/IMG_7838%5B1%5D_48375470.JPG"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/708/719F/m/IMG_7840%5B1%5D_48375473.JPG"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/708/719F/m/IMG_7841%5B1%5D_48375474.JPG"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/708/719F/m/IMG_7842%5B1%5D_48375475.JPG"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/708/719F/m/IMG_7843%5B1%5D_48375476.JPG"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/708/719F/m/IMG_7850%5B1%5D_48375477.JPG"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/708/719F/m/IMG_7854%5B1%5D_48375478.JPG"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/708/719F/m/IMG_7847%5B1%5D_48375479.JPG"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/708/719F/m/IMG_7845%5B1%5D_48375480.JPG"/>
#  </div>
#  <div class="photoMask last-item">
#  <div class="btnBox">
#  <div class="btn-voir centered bShadow" rel="follow">
#  <i class="icon-eye orange fSize22"></i>
#  <span>Voir l'annonce</span>
#  </div>
#  </div>
#  <img class="w100" data-lazy="https://www.mubawab-media.com/ad/7/708/719F/m/IMG_7838%5B1%5D_48375470.JPG"/>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <span class="priceTag hardShadow float-right floatL">165 000 000 DH
#  					</span>,
#  <a href="https://www.mubawab.ma/fr/a/7708719/opportunit%C3%A9-%C3%A0-saisir">Opportunité à saisir
#  					</a>,
#  <p class="listingH4 floatR">3 chambres, 110 m²
#  					</p>,
#  <h3 class="listingH3">Anfa Supérieur à
#     					Casablanca
#  				</h3>,
#  <div class="photoBox col-5 floatR emptyCol" data-url="https://www.mubawab-media.com/ad/7/686/974F/m/photo_00_45977401.jpg">
#  <div class="priceBar positionAb w100 favDivPickId" id="7686974">
#  <i adid="7686974" class="favHolder icon-heart-empty heartIcon heartIconBasic"></i>
#  <span class="priceTag hardShadow float-right floatL">156 000 000 DH
#  					</span>
#  </div>
#  <div class="w100">
#  <div class="sliderArrows priceBar positionAb w100" id="sliderArrows"></div>
#  <div class="adSlider">
#  <div class="photoMask firstMask">
#  <img alt="Appartement à vendre à Les Hôpitaux. Surface totale 113 m². Cheminée et service de conciergerie" class="w100 sliderImage firstPicture" data-url="https://www.mubawab-media.com/ad/7/686/974F/m/photo_00_45977401.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/686/974F/m/photo_01_45977402.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/686/974F/m/photo_02_45977403.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/686/974F/m/photo_03_45977404.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/686/974F/m/photo_04_45977405.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/686/974F/m/photo_05_45977406.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/686/974F/m/photo_06_45977407.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/686/974F/m/photo_07_45977408.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/686/974F/m/photo_08_45977409.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/686/974F/m/photo_09_45977410.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/686/974F/m/photo_010_45977411.jpg"/>
#  </div>
#  <div class="photoMask last-item">
#  <div class="btnBox">
#  <div class="btn-voir centered bShadow" rel="follow">
#  <i class="icon-eye orange fSize22"></i>
#  <span>Voir l'annonce</span>
#  </div>
#  </div>
#  <img class="w100" data-lazy="https://www.mubawab-media.com/ad/7/686/974F/m/photo_00_45977401.jpg"/>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <span class="priceTag hardShadow float-right floatL">156 000 000 DH
#  					</span>,
#  <a href="https://www.mubawab.ma/fr/a/7686974/appartement-%C3%A0-vendre-%C3%A0-les-h%C3%B4pitaux-surface-totale-113-m%C2%B2-chemin%C3%A9e-et-service-de-conciergerie">Appartement à vendre à Les Hôpitaux. Surf...
#  					</a>,
#  <p class="listingH4 floatR">2 chambres, 113 m²
#  					</p>,
#  <h3 class="listingH3">Les Hôpitaux à
#     					Casablanca
#  				</h3>,
#  <div class="photoBox col-5 floatR emptyCol" data-url="https://www.mubawab-media.com/ad/7/790/754F/m/photo_00_57876727.png">
#  <div class="priceBar positionAb w100 favDivPickId" id="7790754">
#  <i adid="7790754" class="favHolder icon-heart-empty heartIcon heartIconBasic"></i>
#  <span class="priceTag hardShadow float-right floatL">140 000 000 DH
#  					</span>
#  </div>
#  <div class="w100">
#  <div class="sliderArrows priceBar positionAb w100" id="sliderArrows"></div>
#  <div class="adSlider">
#  <div class="photoMask firstMask">
#  <img alt="Vente d'un bel appartement à Les Hôpitaux. Surface de 109 m². Bien meublé. " class="w100 sliderImage firstPicture" data-url="https://www.mubawab-media.com/ad/7/790/754F/m/photo_00_57876727.png"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/790/754F/m/photo_01_57876729.png"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/790/754F/m/photo_02_57876730.png"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/790/754F/m/photo_03_57876731.png"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/790/754F/m/photo_04_57876732.png"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/790/754F/m/photo_05_57876733.png"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/790/754F/m/photo_06_57876734.png"/>
#  </div>
#  <div class="photoMask last-item">
#  <div class="btnBox">
#  <div class="btn-voir centered bShadow" rel="follow">
#  <i class="icon-eye orange fSize22"></i>
#  <span>Voir l'annonce</span>
#  </div>
#  </div>
#  <img class="w100" data-lazy="https://www.mubawab-media.com/ad/7/790/754F/m/photo_00_57876727.png"/>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <span class="priceTag hardShadow float-right floatL">140 000 000 DH
#  					</span>,
#  <a href="https://www.mubawab.ma/fr/a/7790754/vente-d-un-bel-appartement-%C3%A0-les-h%C3%B4pitaux-surface-de-109-m%C2%B2-bien-meubl%C3%A9-">Vente d'un bel appartement à Les Hôpitaux...
#  					</a>,
#  <p class="listingH4 floatR">2 chambres, 109 m²
#  					</p>,
#  <h3 class="listingH3">Les Hôpitaux à
#     					Casablanca
#  				</h3>,
#  <div class="photoBox col-5 floatR emptyCol" data-url="https://www.mubawab-media.com/ad/7/592/644F/m/IMG-20221124-WA0009_36481203.jpg">
#  <div class="priceBar positionAb w100 favDivPickId" id="7592644">
#  <i adid="7592644" class="favHolder icon-heart-empty heartIcon heartIconBasic"></i>
#  <span class="priceTag hardShadow float-right floatL">125 000 000 DH
#  					</span>
#  </div>
#  <div class="w100">
#  <div class="sliderArrows priceBar positionAb w100" id="sliderArrows"></div>
#  <div class="adSlider">
#  <div class="photoMask firstMask">
#  <img alt="Studio meublé" class="w100 sliderImage firstPicture" data-url="https://www.mubawab-media.com/ad/7/592/644F/m/IMG-20221124-WA0009_36481203.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/592/644F/m/IMG-20221124-WA0010_36481204.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/592/644F/m/IMG-20221124-WA0005_36481205.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/592/644F/m/IMG-20221124-WA0007_36481206.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/592/644F/m/IMG-20221124-WA0001_36481207.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/592/644F/m/IMG-20221124-WA0003_36481208.jpg"/>
#  </div>
#  <div class="photoMask last-item">
#  <div class="btnBox">
#  <div class="btn-voir centered bShadow" rel="follow">
#  <i class="icon-eye orange fSize22"></i>
#  <span>Voir l'annonce</span>
#  </div>
#  </div>
#  <img class="w100" data-lazy="https://www.mubawab-media.com/ad/7/592/644F/m/IMG-20221124-WA0009_36481203.jpg"/>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <span class="priceTag hardShadow float-right floatL">125 000 000 DH
#  					</span>,
#  <a href="https://www.mubawab.ma/fr/a/7592644/studio-meubl%C3%A9">Studio meublé
#  					</a>,
#  <p class="listingH4 floatR">1 chambre, 55 m²
#  					</p>,
#  <h3 class="listingH3">Les princesses à
#     					Casablanca
#  				</h3>,
#  <div class="photoBox col-5 floatR emptyCol" data-url="https://www.mubawab-media.com/ad/7/506/744F/m/WhatsApp%20Image%202022-08-13%20at%2015.39.09_29758338.jpeg">
#  <div class="priceBar positionAb w100 favDivPickId" id="7506744">
#  <i adid="7506744" class="favHolder icon-heart-empty heartIcon heartIconBasic"></i>
#  <span class="priceTag hardShadow float-right floatL">120 000 000 DH
#  					</span>
#  </div>
#  <div class="w100">
#  <div class="sliderArrows priceBar positionAb w100" id="sliderArrows"></div>
#  <div class="adSlider">
#  <div class="photoMask firstMask">
#  <img alt="Apparte de haute standing situé au cœur de casa" class="w100 sliderImage firstPicture" data-url="https://www.mubawab-media.com/ad/7/506/744F/m/WhatsApp%20Image%202022-08-13%20at%2015.39.09_29758338.jpeg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/506/744F/m/WhatsApp%20Image%202022-08-13%20at%2015.39.19_29758336.jpeg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/506/744F/m/WhatsApp%20Image%202022-08-13%20at%2015.39.21_29758337.jpeg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/506/744F/m/WhatsApp%20Image%202022-08-13%20at%2015.39.39_29758339.jpeg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/506/744F/m/WhatsApp%20Image%202022-08-13%20at%2015.39.25_29758340.jpeg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/506/744F/m/WhatsApp%20Image%202022-08-13%20at%2015.39.41_29758342.jpeg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/506/744F/m/WhatsApp%20Image%202022-08-13%20at%2015.38.22_29758343.jpeg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/506/744F/m/WhatsApp%20Image%202022-08-13%20at%2015.38.19_29758344.jpeg"/>
#  </div>
#  <div class="photoMask last-item">
#  <div class="btnBox">
#  <div class="btn-voir centered bShadow" rel="follow">
#  <i class="icon-eye orange fSize22"></i>
#  <span>Voir l'annonce</span>
#  </div>
#  </div>
#  <img class="w100" data-lazy="https://www.mubawab-media.com/ad/7/506/744F/m/WhatsApp%20Image%202022-08-13%20at%2015.39.09_29758338.jpeg"/>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <span class="priceTag hardShadow float-right floatL">120 000 000 DH
#  					</span>,
#  <a href="https://www.mubawab.ma/fr/a/7506744/apparte-de-haute-standing-situ%C3%A9-au-c%C5%93ur-de-casa">Apparte de haute standing situé au cœur d...
#  					</a>,
#  <p class="listingH4 floatR">3 chambres, 120 m²
#  					</p>,
#  <h3 class="listingH3">Mers Sultan à
#     					Casablanca
#  				</h3>,
#  <div class="photoBox col-5 floatR emptyCol" data-url="https://www.mubawab-media.com/ad/7/756/453F/m/WhatsApp%20Image%202023-08-05%20at%2010.25.03_53460422.jpeg">
#  <div class="priceBar positionAb w100 favDivPickId" id="7756453">
#  <i adid="7756453" class="favHolder icon-heart-empty heartIcon heartIconBasic"></i>
#  <span class="priceTag hardShadow float-right floatL">116 500 000 DH
#  					</span>
#  </div>
#  <div class="w100">
#  <div class="sliderArrows priceBar positionAb w100" id="sliderArrows"></div>
#  <div class="adSlider">
#  <div class="photoMask firstMask">
#  <img alt="Appartement a al fidae mesure 173 m2 semi fini" class="w100 sliderImage firstPicture" data-url="https://www.mubawab-media.com/ad/7/756/453F/m/WhatsApp%20Image%202023-08-05%20at%2010.25.03_53460422.jpeg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/756/453F/m/WhatsApp%20Image%202023-08-05%20at%2021.54.55_53460423.jpeg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/756/453F/m/WhatsApp%20Image%202023-08-07%20at%2010.51.35_53460424.jpeg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/756/453F/m/WhatsApp%20Image%202023-08-07%20at%2010.51.35%20%281%29_53460425.jpeg"/>
#  </div>
#  <div class="photoMask last-item">
#  <div class="btnBox">
#  <div class="btn-voir centered bShadow" rel="follow">
#  <i class="icon-eye orange fSize22"></i>
#  <span>Voir l'annonce</span>
#  </div>
#  </div>
#  <img class="w100" data-lazy="https://www.mubawab-media.com/ad/7/756/453F/m/WhatsApp%20Image%202023-08-05%20at%2010.25.03_53460422.jpeg"/>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <span class="priceTag hardShadow float-right floatL">116 500 000 DH
#  					</span>,
#  <a href="https://www.mubawab.ma/fr/a/7756453/appartement-a-al-fidae-mesure-173-m2-semi-fini">Appartement a al fidae mesure 173 m2 semi...
#  					</a>,
#  <p class="listingH4 floatR">3 chambres, 173 m²
#  					</p>,
#  <h3 class="listingH3"> à
#     					Oulad Salah
#  				</h3>,
#  <div class="photoBox col-5 floatR emptyCol" data-url="https://www.mubawab-media.com/ad/7/685/238F/m/WhatsApp%20Image%202023-04-27%20at%2015.11.30_45775395.jpeg">
#  <div class="priceBar positionAb w100 favDivPickId" id="7685238">
#  <i adid="7685238" class="favHolder icon-heart-empty heartIcon heartIconBasic"></i>
#  <span class="priceTag hardShadow float-right floatL">115 440 000 DH
#  					</span>
#  </div>
#  <div class="w100">
#  <div class="sliderArrows priceBar positionAb w100" id="sliderArrows"></div>
#  <div class="adSlider">
#  <div class="photoMask firstMask">
#  <img alt="Bel appartement à vendre à Aïn Sebaâ. Surface totale 222 m². Porte blindée, salon marocain. " class="w100 sliderImage firstPicture" data-url="https://www.mubawab-media.com/ad/7/685/238F/m/WhatsApp%20Image%202023-04-27%20at%2015.11.30_45775395.jpeg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/685/238F/m/WhatsApp%20Image%202023-04-27%20at%2015.11.30%20%284%29_45775397.jpeg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/685/238F/m/WhatsApp%20Image%202023-04-27%20at%2015.11.30%20%283%29_45775398.jpeg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/685/238F/m/WhatsApp%20Image%202023-04-27%20at%2015.11.30%20%282%29_45775399.jpeg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/685/238F/m/WhatsApp%20Image%202023-04-27%20at%2015.11.30%20%281%29_45775400.jpeg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/685/238F/m/WhatsApp%20Image%202023-04-27%20at%2015.11.29_45775401.jpeg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/685/238F/m/WhatsApp%20Image%202023-04-27%20at%2015.11.29%20%281%29_45775402.jpeg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/685/238F/m/WhatsApp%20Image%202023-04-27%20at%2015.11.30%20%285%29_45775403.jpeg"/>
#  </div>
#  <div class="photoMask last-item">
#  <div class="btnBox">
#  <div class="btn-voir centered bShadow" rel="follow">
#  <i class="icon-eye orange fSize22"></i>
#  <span>Voir l'annonce</span>
#  </div>
#  </div>
#  <img class="w100" data-lazy="https://www.mubawab-media.com/ad/7/685/238F/m/WhatsApp%20Image%202023-04-27%20at%2015.11.30_45775395.jpeg"/>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <span class="priceTag hardShadow float-right floatL">115 440 000 DH
#  					</span>,
#  <a href="https://www.mubawab.ma/fr/a/7685238/bel-appartement-%C3%A0-vendre-%C3%A0-a%C3%AFn-seba%C3%A2-surface-totale-222-m%C2%B2-porte-blind%C3%A9e-salon-marocain-">Bel appartement à vendre à Aïn Sebaâ. Sur...
#  					</a>,
#  <p class="listingH4 floatR">3 chambres, 222 m²
#  					</p>,
#  <h3 class="listingH3">Aïn Sebaâ à
#     					Casablanca
#  				</h3>,
#  <div class="photoBox col-5 floatR emptyCol" data-url="https://www.mubawab-media.com/ad/7/634/217F/m/photo_0_40774031.jpg">
#  <div class="priceBar positionAb w100 favDivPickId" id="7634217">
#  <i adid="7634217" class="favHolder icon-heart-empty heartIcon heartIconBasic"></i>
#  <span class="priceTag hardShadow float-right floatL">110 000 000 DH
#  					</span>
#  </div>
#  <div class="w100">
#  <div class="sliderArrows priceBar positionAb w100" id="sliderArrows"></div>
#  <div class="adSlider">
#  <div class="photoMask firstMask">
#  <img alt="Vente d'un bel appartement à Errahma. 2 belles chambres. Jardin et ascenseur" class="w100 sliderImage firstPicture" data-url="https://www.mubawab-media.com/ad/7/634/217F/m/photo_0_40774031.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/634/217F/m/photo_1_40774033.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/634/217F/m/photo_2_40774032.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/634/217F/m/photo_3_40774028.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/634/217F/m/photo_4_40774034.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/634/217F/m/photo_5_40774035.jpg"/>
#  </div>
#  <div class="photoMask last-item">
#  <div class="btnBox">
#  <div class="btn-voir centered bShadow" rel="follow">
#  <i class="icon-eye orange fSize22"></i>
#  <span>Voir l'annonce</span>
#  </div>
#  </div>
#  <img class="w100" data-lazy="https://www.mubawab-media.com/ad/7/634/217F/m/photo_0_40774031.jpg"/>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <span class="priceTag hardShadow float-right floatL">110 000 000 DH
#  					</span>,
#  <a href="https://www.mubawab.ma/fr/a/7634217/vente-d-un-bel-appartement-%C3%A0-errahma-2-belles-chambres-jardin-et-ascenseur">Vente d'un bel appartement à Errahma. 2 b...
#  					</a>,
#  <p class="listingH4 floatR">2 chambres, 79 m²
#  					</p>,
#  <h3 class="listingH3"> à
#     					Errahma
#  				</h3>,
#  <div class="photoBox col-5 floatR emptyCol" data-url="https://www.mubawab-media.com/ad/7/706/636F/m/photo_0_48165529.jpeg">
#  <div class="priceBar positionAb w100 favDivPickId" id="7706636">
#  <i adid="7706636" class="favHolder icon-heart-empty heartIcon heartIconBasic"></i>
#  <span class="priceTag hardShadow float-right floatL">109 000 000 DH
#  					</span>
#  </div>
#  <div class="w100">
#  <div class="sliderArrows priceBar positionAb w100" id="sliderArrows"></div>
#  <div class="adSlider">
#  <div class="photoMask firstMask">
#  <img alt="Vente d'un bel appartement à Mers Sultan. 4 pièces confortables. Salon traditionnel et système d'antenne parabolique." class="w100 sliderImage firstPicture" data-url="https://www.mubawab-media.com/ad/7/706/636F/m/photo_0_48165529.jpeg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/706/636F/m/photo_1_48165520.jpeg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/706/636F/m/photo_2_48165523.jpeg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/706/636F/m/photo_3_48165524.jpeg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/706/636F/m/photo_4_48165525.jpeg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/706/636F/m/photo_5_48165526.jpeg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/706/636F/m/photo_6_48165527.jpeg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/706/636F/m/photo_7_48165528.jpeg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/706/636F/m/photo_8_48165530.jpeg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/706/636F/m/photo_9_48165531.jpeg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/706/636F/m/photo_10_48165532.jpeg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/706/636F/m/photo_11_48165533.jpeg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/706/636F/m/photo_12_48165534.jpeg"/>
#  </div>
#  <div class="photoMask last-item">
#  <div class="btnBox">
#  <div class="btn-voir centered bShadow" rel="follow">
#  <i class="icon-eye orange fSize22"></i>
#  <span>Voir l'annonce</span>
#  </div>
#  </div>
#  <img class="w100" data-lazy="https://www.mubawab-media.com/ad/7/706/636F/m/photo_0_48165529.jpeg"/>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <span class="priceTag hardShadow float-right floatL">109 000 000 DH
#  					</span>,
#  <a href="https://www.mubawab.ma/fr/a/7706636/vente-d-un-bel-appartement-%C3%A0-mers-sultan-4-pi%C3%A8ces-confortables-salon-traditionnel-et-syst%C3%A8me-d-antenne-parabolique-">Vente d'un bel appartement à Mers Sultan...
#  					</a>,
#  <p class="listingH4 floatR">2 chambres, 128 m²
#  					</p>,
#  <h3 class="listingH3">Mers Sultan à
#     					Casablanca
#  				</h3>,
#  <div class="photoBox col-5 floatR emptyCol" data-url="https://www.mubawab-media.com/ad/7/700/540F/m/photo_0_47506986.jpg">
#  <div class="priceBar positionAb w100 favDivPickId" id="7700540">
#  <i adid="7700540" class="favHolder icon-heart-empty heartIcon heartIconBasic"></i>
#  <span class="priceTag hardShadow float-right floatL">109 000 000 DH
#  					</span>
#  </div>
#  <div class="w100">
#  <div class="sliderArrows priceBar positionAb w100" id="sliderArrows"></div>
#  <div class="adSlider">
#  <div class="photoMask firstMask">
#  <img alt="Appartement à vendre à Mers Sultan. 2 grandes pièces. Salon traditionnel et système d'antenne parabolique." class="w100 sliderImage firstPicture" data-url="https://www.mubawab-media.com/ad/7/700/540F/m/photo_0_47506986.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/700/540F/m/photo_1_47506977.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/700/540F/m/photo_2_47506984.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/700/540F/m/photo_3_47506985.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/700/540F/m/photo_4_47506987.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/700/540F/m/photo_5_47506988.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/700/540F/m/photo_6_47506989.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/700/540F/m/photo_7_47506990.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/700/540F/m/photo_8_47506991.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/700/540F/m/photo_9_47506992.jpg"/>
#  </div>
#  <div class="photoMask last-item">
#  <div class="btnBox">
#  <div class="btn-voir centered bShadow" rel="follow">
#  <i class="icon-eye orange fSize22"></i>
#  <span>Voir l'annonce</span>
#  </div>
#  </div>
#  <img class="w100" data-lazy="https://www.mubawab-media.com/ad/7/700/540F/m/photo_0_47506986.jpg"/>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <span class="priceTag hardShadow float-right floatL">109 000 000 DH
#  					</span>,
#  <a href="https://www.mubawab.ma/fr/a/7700540/appartement-%C3%A0-vendre-%C3%A0-mers-sultan-2-grandes-pi%C3%A8ces-salon-traditionnel-et-syst%C3%A8me-d-antenne-parabolique-">Appartement à vendre à Mers Sultan. 2 gra...
#  					</a>,
#  <p class="listingH4 floatR">2 chambres, 128 m²
#  					</p>,
#  <h3 class="listingH3">Mers Sultan à
#     					Casablanca
#  				</h3>,
#  <div class="photoBox col-5 floatR emptyCol" data-url="https://www.mubawab-media.com/ad/7/707/505F/m/IMG-20230529-WA0032_48237750.jpg">
#  <div class="priceBar positionAb w100 favDivPickId" id="7707505">
#  <i adid="7707505" class="favHolder icon-heart-empty heartIcon heartIconBasic"></i>
#  <span class="priceTag hardShadow float-right floatL">105 000 000 DH
#  					</span>
#  </div>
#  <div class="w100">
#  <div class="sliderArrows priceBar positionAb w100" id="sliderArrows"></div>
#  <div class="adSlider">
#  <div class="photoMask firstMask">
#  <img alt="Vente appart Maarif ex" class="w100 sliderImage firstPicture" data-url="https://www.mubawab-media.com/ad/7/707/505F/m/IMG-20230529-WA0032_48237750.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/707/505F/m/IMG-20230529-WA0034_48237751.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/707/505F/m/IMG-20230529-WA0041_48237752.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/707/505F/m/IMG-20230529-WA0036_48237753.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/707/505F/m/IMG-20230529-WA0035_48237754.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/707/505F/m/IMG-20230529-WA0040_48237755.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/707/505F/m/IMG-20230529-WA0037_48237756.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/707/505F/m/IMG-20230529-WA0033_48237757.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/707/505F/m/IMG-20230529-WA0019_48237758.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/707/505F/m/IMG-20230529-WA0015_48237759.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/707/505F/m/IMG-20230529-WA0021_48237760.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/707/505F/m/IMG-20230529-WA0011_48237761.jpg"/>
#  </div>
#  <div class="photoMask last-item">
#  <div class="btnBox">
#  <div class="btn-voir centered bShadow" rel="follow">
#  <i class="icon-eye orange fSize22"></i>
#  <span>Voir l'annonce</span>
#  </div>
#  </div>
#  <img class="w100" data-lazy="https://www.mubawab-media.com/ad/7/707/505F/m/IMG-20230529-WA0032_48237750.jpg"/>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <span class="priceTag hardShadow float-right floatL">105 000 000 DH
#  					</span>,
#  <a href="https://www.mubawab.ma/fr/a/7707505/vente-appart-maarif-ex">Vente appart Maarif ex
#  					</a>,
#  <p class="listingH4 floatR">3 chambres, 92 m²
#  					</p>,
#  <h3 class="listingH3">Maârif Extension à
#     					Casablanca
#  				</h3>,
#  <div class="photoBox col-5 floatR emptyCol" data-url="https://www.mubawab-media.com/ad/7/705/409F/m/653879-e3cc2o_48035060.jpg">
#  <div class="priceBar positionAb w100 favDivPickId" id="7705409">
#  <i adid="7705409" class="favHolder icon-heart-empty heartIcon heartIconBasic"></i>
#  <span class="priceTag hardShadow float-right floatL">100 000 000 DH
#  					</span>
#  </div>
#  <div class="w100">
#  <div class="sliderArrows priceBar positionAb w100" id="sliderArrows"></div>
#  <div class="adSlider">
#  <div class="photoMask firstMask">
#  <img alt="Appartement a vendre quarthier gautier" class="w100 sliderImage firstPicture" data-url="https://www.mubawab-media.com/ad/7/705/409F/m/653879-e3cc2o_48035060.jpg"/>
#  </div>
#  <div class="photoMask last-item">
#  <div class="btnBox">
#  <div class="btn-voir centered bShadow" rel="follow">
#  <i class="icon-eye orange fSize22"></i>
#  <span>Voir l'annonce</span>
#  </div>
#  </div>
#  <img class="w100" data-lazy="https://www.mubawab-media.com/ad/7/705/409F/m/653879-e3cc2o_48035060.jpg"/>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <span class="priceTag hardShadow float-right floatL">100 000 000 DH
#  					</span>,
#  <a href="https://www.mubawab.ma/fr/a/7705409/appartement-a-vendre-quarthier-gautier">Appartement a vendre quarthier gautier
#  					</a>,
#  <p class="listingH4 floatR">2 chambres, 80 m²
#  					</p>,
#  <h3 class="listingH3">Maârif à
#     					Casablanca
#  				</h3>,
#  <div class="photoBox col-5 floatR emptyCol" data-url="https://www.mubawab-media.com/ad/7/764/244F/m/photo_0_54489650.jpg">
#  <div class="priceBar positionAb w100 favDivPickId" id="7764244">
#  <i adid="7764244" class="favHolder icon-heart-empty heartIcon heartIconBasic"></i>
#  <span class="priceTag hardShadow float-right floatL">98 000 000 DH
#  					</span>
#  </div>
#  <div class="w100">
#  <div class="sliderArrows priceBar positionAb w100" id="sliderArrows"></div>
#  <div class="adSlider">
#  <div class="photoMask firstMask">
#  <img alt="Appartement à vendre à Nouaceur. Superficie 101 m². Climatisation et piscine" class="w100 sliderImage firstPicture" data-url="https://www.mubawab-media.com/ad/7/764/244F/m/photo_0_54489650.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/764/244F/m/photo_1_54489651.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/764/244F/m/photo_2_54489652.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/764/244F/m/photo_3_54489653.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/764/244F/m/photo_4_54489654.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/764/244F/m/photo_5_54489655.jpg"/>
#  </div>
#  <div class="photoMask last-item">
#  <div class="btnBox">
#  <div class="btn-voir centered bShadow" rel="follow">
#  <i class="icon-eye orange fSize22"></i>
#  <span>Voir l'annonce</span>
#  </div>
#  </div>
#  <img class="w100" data-lazy="https://www.mubawab-media.com/ad/7/764/244F/m/photo_0_54489650.jpg"/>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <span class="priceTag hardShadow float-right floatL">98 000 000 DH
#  					</span>,
#  <a href="https://www.mubawab.ma/fr/a/7764244/appartement-%C3%A0-vendre-%C3%A0-nouaceur-superficie-101-m%C2%B2-climatisation-et-piscine">Appartement à vendre à Nouaceur. Superfic...
#  					</a>,
#  <p class="listingH4 floatR">3 chambres, 101 m²
#  					</p>,
#  <h3 class="listingH3"> à
#     					Nouaceur
#  				</h3>,
#  <div class="photoBox col-5 floatR emptyCol" data-url="https://www.mubawab-media.com/ad/7/765/734F/m/photo_0_54685311.jpg">
#  <div class="priceBar positionAb w100 favDivPickId" id="7765734">
#  <i adid="7765734" class="favHolder icon-heart-empty heartIcon heartIconBasic"></i>
#  <span class="priceTag hardShadow float-right floatL">95 000 000 DH
#  					</span>
#  </div>
#  <div class="w100">
#  <div class="sliderArrows priceBar positionAb w100" id="sliderArrows"></div>
#  <div class="adSlider">
#  <div class="photoMask firstMask">
#  <img alt="Appartement à vendre à Bourgogne Ouest. Superficie 63 m². Ascenseur et terrasse. " class="w100 sliderImage firstPicture" data-url="https://www.mubawab-media.com/ad/7/765/734F/m/photo_0_54685311.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/765/734F/m/photo_1_54685315.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/765/734F/m/photo_2_54685317.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/765/734F/m/photo_3_54685318.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/765/734F/m/photo_4_54685319.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/765/734F/m/photo_5_54685320.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/765/734F/m/photo_6_54685321.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/765/734F/m/photo_7_54685322.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/765/734F/m/photo_8_54685323.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/765/734F/m/photo_9_54685324.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/765/734F/m/photo_10_54685325.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/765/734F/m/photo_11_54685326.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/765/734F/m/photo_12_54685327.jpg"/>
#  </div>
#  <div class="photoMask last-item">
#  <div class="btnBox">
#  <div class="btn-voir centered bShadow" rel="follow">
#  <i class="icon-eye orange fSize22"></i>
#  <span>Voir l'annonce</span>
#  </div>
#  </div>
#  <img class="w100" data-lazy="https://www.mubawab-media.com/ad/7/765/734F/m/photo_0_54685311.jpg"/>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <span class="priceTag hardShadow float-right floatL">95 000 000 DH
#  					</span>,
#  <a href="https://www.mubawab.ma/fr/a/7765734/appartement-%C3%A0-vendre-%C3%A0-bourgogne-ouest-superficie-63-m%C2%B2-ascenseur-et-terrasse-">Appartement à vendre à Bourgogne Ouest. S...
#  					</a>,
#  <p class="listingH4 floatR">1 chambre, 63 m²
#  					</p>,
#  <h3 class="listingH3">Bourgogne Ouest à
#     					Casablanca
#  				</h3>,
#  <div class="photoBox col-5 floatR emptyCol" data-url="https://www.mubawab-media.com/ad/7/740/759F/m/WhatsApp%20Image%202023-07-18%20at%2022.03.50%20%281%29_52012436.jpeg">
#  <div class="priceBar positionAb w100 favDivPickId" id="7740759">
#  <i adid="7740759" class="favHolder icon-heart-empty heartIcon heartIconBasic"></i>
#  <span class="priceTag hardShadow float-right floatL">72 000 000 DH
#  					</span>
#  </div>
#  <div class="w100">
#  <div class="sliderArrows priceBar positionAb w100" id="sliderArrows"></div>
#  <div class="adSlider">
#  <div class="photoMask firstMask">
#  <img alt="Appartement a vendre" class="w100 sliderImage firstPicture" data-url="https://www.mubawab-media.com/ad/7/740/759F/m/WhatsApp%20Image%202023-07-18%20at%2022.03.50%20%281%29_52012436.jpeg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/740/759F/m/WhatsApp%20Image%202023-07-18%20at%2000.31.52_52012437.jpeg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/740/759F/m/WhatsApp%20Image%202023-07-18%20at%2000.31.52%20%281%29_52012438.jpeg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/740/759F/m/WhatsApp%20Image%202023-07-18%20at%2000.31.56%20%282%29_52012439.jpeg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/740/759F/m/WhatsApp%20Image%202023-07-18%20at%2000.31.53_52012440.jpeg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/740/759F/m/WhatsApp%20Image%202023-07-18%20at%2000.31.56%20%283%29_52012441.jpeg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/740/759F/m/WhatsApp%20Image%202023-07-18%20at%2000.31.56%20%281%29_52012442.jpeg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/740/759F/m/WhatsApp%20Image%202023-07-18%20at%2000.31.56%20%285%29_52012443.jpeg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/740/759F/m/WhatsApp%20Image%202023-07-18%20at%2022.03.50_52012444.jpeg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/740/759F/m/WhatsApp%20Image%202023-07-18%20at%2000.31.56%20%284%29_52012445.jpeg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/740/759F/m/WhatsApp%20Image%202023-07-18%20at%2000.31.56%20%286%29_52012446.jpeg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/740/759F/m/WhatsApp%20Image%202023-07-18%20at%2000.31.56%20%288%29_52012447.jpeg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/740/759F/m/WhatsApp%20Image%202023-07-18%20at%2000.31.56%20%287%29_52012448.jpeg"/>
#  </div>
#  <div class="photoMask last-item">
#  <div class="btnBox">
#  <div class="btn-voir centered bShadow" rel="follow">
#  <i class="icon-eye orange fSize22"></i>
#  <span>Voir l'annonce</span>
#  </div>
#  </div>
#  <img class="w100" data-lazy="https://www.mubawab-media.com/ad/7/740/759F/m/WhatsApp%20Image%202023-07-18%20at%2022.03.50%20%281%29_52012436.jpeg"/>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <span class="priceTag hardShadow float-right floatL">72 000 000 DH
#  					</span>,
#  <a href="https://www.mubawab.ma/fr/a/7740759/appartement-a-vendre">Appartement a vendre
#  					</a>,
#  <p class="listingH4 floatR">2 chambres, 115 m²
#  					</p>,
#  <h3 class="listingH3">Quartier Industriel à
#     					Bouznika
#  				</h3>,
#  <div class="photoBox col-5 floatR emptyCol" data-url="https://www.mubawab-media.com/ad/7/598/246F/m/photo_0_37078913_20221206103906791.jpg">
#  <div class="priceBar positionAb w100 favDivPickId" id="7598246">
#  <i adid="7598246" class="favHolder icon-heart-empty heartIcon heartIconBasic"></i>
#  <span class="priceTag hardShadow float-right floatL">70 000 000 DH
#  					</span>
#  </div>
#  <div class="w100">
#  <div class="sliderArrows priceBar positionAb w100" id="sliderArrows"></div>
#  <div class="adSlider">
#  <div class="photoMask firstMask">
#  <img alt="Appartement à vendre à rue Abdelkader sahraoui devant les villa de hay rahma. 2 chambres agréables. Système de parabole et salon marocain" class="w100 sliderImage firstPicture" data-url="https://www.mubawab-media.com/ad/7/598/246F/m/photo_0_37078913_20221206103906791.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/598/246F/m/photo_1_37078915_20221206103909113.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/598/246F/m/photo_2_37078916_20221206103909657.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/598/246F/m/photo_3_37078917_20221206103910146.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/598/246F/m/photo_4_37078918_20221206103910689.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/598/246F/m/photo_5_37078919_20221206103911301.jpg"/>
#  </div>
#  <div class="photoMask last-item">
#  <div class="btnBox">
#  <div class="btn-voir centered bShadow" rel="follow">
#  <i class="icon-eye orange fSize22"></i>
#  <span>Voir l'annonce</span>
#  </div>
#  </div>
#  <img class="w100" data-lazy="https://www.mubawab-media.com/ad/7/598/246F/m/photo_0_37078913_20221206103906791.jpg"/>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <span class="priceTag hardShadow float-right floatL">70 000 000 DH
#  					</span>,
#  <a href="https://www.mubawab.ma/fr/a/7598246/appartement-%C3%A0-vendre-%C3%A0-rue-abdelkader-sahraoui-devant-les-villa-de-hay-rahma-2-chambres-agr%C3%A9ables-syst%C3%A8me-de-parabole-et-salon-marocain">Appartement à vendre à rue Abdelkader sah...
#  					</a>,
#  <p class="listingH4 floatR">2 chambres, 75 m²
#  					</p>,
#  <h3 class="listingH3">Sidi Othmane à
#     					Casablanca
#  				</h3>,
#  <div class="photoBox col-5 floatR emptyCol" data-url="https://www.mubawab-media.com/ad/7/726/298F/m/photo%20q7_50559436.jpg">
#  <div class="priceBar positionAb w100 favDivPickId" id="7726298">
#  <i adid="7726298" class="favHolder icon-heart-empty heartIcon heartIconBasic"></i>
#  <span class="priceTag hardShadow float-right floatL">60 000 000 DH
#  					</span>
#  </div>
#  <div class="w100">
#  <div class="sliderArrows priceBar positionAb w100" id="sliderArrows"></div>
#  <div class="adSlider">
#  <div class="photoMask firstMask">
#  <img alt="Appartement à vendre à Oasis. 78 pièces. Meublé. " class="w100 sliderImage firstPicture" data-url="https://www.mubawab-media.com/ad/7/726/298F/m/photo%20q7_50559436.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/726/298F/m/photo%20q4_50559441.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/726/298F/m/photo%20q6_50559442.jpg"/>
#  </div>
# ...
#  					</a>,
#  <p class="listingH4 floatR">4 chambres, 187 m²
#  					</p>,
#  <h3 class="listingH3">Al Kodia à
#     					El Jadida
#  				</h3>,
#  <div class="photoBox col-5 floatR emptyCol" data-url="https://www.mubawab-media.com/ad/7/687/272F/m/photo_00_46021196.jpg">
#  <div class="priceBar positionAb w100 favDivPickId" id="7687272">
#  <i adid="7687272" class="favHolder icon-heart-empty heartIcon heartIconBasic"></i>
#  <span class="priceTag hardShadow float-right floatL">15 000 000 DH
#  					</span>
#  </div>
#  <div class="w100">
#  <div class="sliderArrows priceBar positionAb w100" id="sliderArrows"></div>
#  <div class="adSlider">
#  <div class="photoMask firstMask">
#  <img alt="Bel appartement à vendre à Bourgogne Ouest. 2 pièces confortables" class="w100 sliderImage firstPicture" data-url="https://www.mubawab-media.com/ad/7/687/272F/m/photo_00_46021196.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/687/272F/m/photo_01_46021197.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/687/272F/m/photo_02_46021198.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/687/272F/m/photo_03_46021199.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/687/272F/m/photo_04_46021200.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/687/272F/m/photo_05_46021201.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/687/272F/m/photo_06_46021202.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/687/272F/m/photo_07_46021203.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/687/272F/m/photo_08_46021204.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/687/272F/m/photo_09_46021205.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/687/272F/m/photo_010_46021206.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/687/272F/m/photo_011_46021207.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/687/272F/m/photo_012_46021208.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/687/272F/m/photo_013_46021209.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/687/272F/m/photo_140_46021210.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/687/272F/m/photo_150_46021211.jpg"/>
#  </div>
#  <div class="photoMask last-item">
#  <div class="btnBox">
#  <div class="btn-voir centered bShadow" rel="follow">
#  <i class="icon-eye orange fSize22"></i>
#  <span>Voir l'annonce</span>
#  </div>
#  </div>
#  <img class="w100" data-lazy="https://www.mubawab-media.com/ad/7/687/272F/m/photo_00_46021196.jpg"/>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <span class="priceTag hardShadow float-right floatL">15 000 000 DH
#  					</span>,
#  <a href="https://www.mubawab.ma/fr/a/7687272/bel-appartement-%C3%A0-vendre-%C3%A0-bourgogne-ouest-2-pi%C3%A8ces-confortables">Bel appartement à vendre à Bourgogne Oues...
#  					</a>,
#  <p class="listingH4 floatR">2 chambres, 110 m²
#  					</p>,
#  <h3 class="listingH3">Bourgogne Ouest à
#     					Casablanca
#  				</h3>,
#  <div class="photoBox col-5 floatR emptyCol" data-url="https://www.mubawab-media.com/ad/7/768/315F/m/PHOTO-2023-09-05-12-49-33%2020_55265382.jpg">
#  <div class="priceBar positionAb w100 favDivPickId" id="7768315">
#  <i adid="7768315" class="favHolder icon-heart-empty heartIcon heartIconBasic"></i>
#  <span class="priceTag hardShadow float-right floatL">15 000 000 DH
#  					</span>
#  </div>
#  <div class="w100">
#  <div class="sliderArrows priceBar positionAb w100" id="sliderArrows"></div>
#  <div class="adSlider">
#  <div class="photoMask firstMask">
#  <img alt="Villa moderne 4 chambres piscine au cil" class="w100 sliderImage firstPicture" data-url="https://www.mubawab-media.com/ad/7/768/315F/m/PHOTO-2023-09-05-12-49-33%2020_55265382.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/768/315F/m/PHOTO-2023-09-05-12-49-33%202_55265383.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/768/315F/m/PHOTO-2023-09-05-12-49-33%203_55265384.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/768/315F/m/PHOTO-2023-09-05-12-49-33%204_55265385.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/768/315F/m/PHOTO-2023-09-05-12-49-33%205_55265386.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/768/315F/m/PHOTO-2023-09-05-12-49-33%206_55265387.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/768/315F/m/PHOTO-2023-09-05-12-49-33%207_55265388.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/768/315F/m/PHOTO-2023-09-05-12-49-33%208_55265389.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/768/315F/m/PHOTO-2023-09-05-12-49-33%209_55265390.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/768/315F/m/PHOTO-2023-09-05-12-49-33%2010_55265391.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/768/315F/m/PHOTO-2023-09-05-12-49-33%2011_55265392.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/768/315F/m/PHOTO-2023-09-05-12-49-33%2012_55265393.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/768/315F/m/PHOTO-2023-09-05-12-49-33%2013_55265394.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/768/315F/m/PHOTO-2023-09-05-12-49-33%2014_55265395.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/768/315F/m/PHOTO-2023-09-05-12-49-33%2015_55265396.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/768/315F/m/PHOTO-2023-09-05-12-49-33%2016_55265397.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/768/315F/m/PHOTO-2023-09-05-12-49-33%2017_55265398.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/768/315F/m/PHOTO-2023-09-05-12-49-33%2018_55265399.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/768/315F/m/PHOTO-2023-09-05-12-49-33%2019_55265400.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/768/315F/m/PHOTO-2023-09-05-12-49-33%2021_55265401.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/768/315F/m/PHOTO-2023-09-05-12-49-33_55265402.jpg"/>
#  </div>
#  <div class="photoMask last-item">
#  <div class="btnBox">
#  <div class="btn-voir centered bShadow" rel="follow">
#  <i class="icon-eye orange fSize22"></i>
#  <span>Voir l'annonce</span>
#  </div>
#  </div>
#  <img class="w100" data-lazy="https://www.mubawab-media.com/ad/7/768/315F/m/PHOTO-2023-09-05-12-49-33%2020_55265382.jpg"/>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <span class="priceTag hardShadow float-right floatL">15 000 000 DH
#  					</span>,
#  <a href="https://www.mubawab.ma/fr/a/7768315/villa-moderne-4-chambres-piscine-au-cil">Villa moderne 4 chambres piscine au cil
#  					</a>,
#  <p class="listingH4 floatR">4 chambres, 700 m²
#  					</p>,
#  <h3 class="listingH3">CIL (Hay Salam) à
#     					Casablanca
#  				</h3>,
#  <div class="photoBox col-5 floatR emptyCol" data-url="https://www.mubawab-media.com/ad/7/737/449F/m/20230718_141348_51710077.jpg">
#  <div class="priceBar positionAb w100 favDivPickId" id="7737449">
#  <i adid="7737449" class="favHolder icon-heart-empty heartIcon heartIconBasic"></i>
#  <span class="priceTag hardShadow float-right floatL">14 805 000 DH
#  					</span>
#  </div>
#  <div class="w100">
#  <div class="sliderArrows priceBar positionAb w100" id="sliderArrows"></div>
#  <div class="adSlider">
#  <div class="photoMask firstMask">
#  <img alt="Bel appartement à vendre à Plateau (Al Batha). 4 pièces confortables. " class="w100 sliderImage firstPicture" data-url="https://www.mubawab-media.com/ad/7/737/449F/m/20230718_141348_51710077.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/737/449F/m/CitePlateau_51710078.png"/>
#  </div>
#  <div class="photoMask last-item">
#  <div class="btnBox">
#  <div class="btn-voir centered bShadow" rel="follow">
#  <i class="icon-eye orange fSize22"></i>
#  <span>Voir l'annonce</span>
#  </div>
#  </div>
#  <img class="w100" data-lazy="https://www.mubawab-media.com/ad/7/737/449F/m/20230718_141348_51710077.jpg"/>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <span class="priceTag hardShadow float-right floatL">14 805 000 DH
#  					</span>,
#  <a href="https://www.mubawab.ma/fr/a/7737449/bel-appartement-%C3%A0-vendre-%C3%A0-plateau-al-batha-4-pi%C3%A8ces-confortables-">Bel appartement à vendre à Plateau (Al Ba...
#  					</a>,
#  <p class="listingH4 floatR">4 chambres, 423 m²
#  					</p>,
#  <h3 class="listingH3">Plateau (Al Batha) à
#     					Casablanca
#  				</h3>,
#  <div class="photoBox col-5 floatR emptyCol" data-url="https://www.mubawab-media.com/ad/7/751/952F/m/3873aaa1-6c88-4c18-ab5b-403454340066-835x467_52919101.jpg">
#  <div class="priceBar positionAb w100 favDivPickId" id="7751952">
#  <i adid="7751952" class="favHolder icon-heart-empty heartIcon heartIconBasic"></i>
#  <span class="priceTag hardShadow float-right floatL">13 000 000 DH
#  					</span>
#  </div>
#  <div class="w100">
#  <div class="sliderArrows priceBar positionAb w100" id="sliderArrows"></div>
#  <div class="adSlider">
#  <div class="photoMask firstMask">
#  <img alt="Vente Penthouse Casablanca Racine" class="w100 sliderImage firstPicture" data-url="https://www.mubawab-media.com/ad/7/751/952F/m/3873aaa1-6c88-4c18-ab5b-403454340066-835x467_52919101.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/751/952F/m/d33beff6-d1f9-44ea-ace6-6b812c72872a-835x467_52919102.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/751/952F/m/0eada54b-ce49-4b17-9dc6-0e7299288f40-835x467_52919103.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/751/952F/m/76179d20-0eb2-43ec-bb91-77927166df37-835x467_52919104.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/751/952F/m/748d464d-ee87-49b9-9861-b0fa2ad97be3-835x467_52919105.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/751/952F/m/8a2a281f-ebfe-48b1-8442-c3dfa21b3e8c-835x467_52919106.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/751/952F/m/1a19e4d3-71ec-4afb-89bf-7884341c4671-835x467_52919107.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/751/952F/m/2b6fda9e-0230-4966-9a9a-3b657f0c02d3-835x467_52919108.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/751/952F/m/2b79f265-d8eb-4c5a-bc3c-14ebb6430f3b-835x467_52919109.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/751/952F/m/3bd34554-92ba-4011-b425-71e928533004-835x467_52919111.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/751/952F/m/3c1f4585-aa45-4896-8667-d43d9f0dddc6-835x467_52919112.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/751/952F/m/5c7c0184-725a-4568-af86-d28fbb30e3ed-835x467_52919113.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/751/952F/m/6c1fc63a-fc63-4aa9-a9d9-b39303206469-835x467_52919114.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/751/952F/m/7f49d74f-b725-4ca0-9aba-1d433b8358f2-835x467_52919115.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/751/952F/m/8e7f2fc8-be20-448c-9382-7529b0c92831-835x467_52919116.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/751/952F/m/29a8ddf4-6b03-440c-a366-ecaf6c9d9cda-835x467_52919117.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/751/952F/m/189e8a65-6c61-40e5-af5a-d48773496ed6-835x467_52919118.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/751/952F/m/adfd26e2-0da0-4dc8-af39-acb7b160cf09-835x467_52919119.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/751/952F/m/af2cdde0-1087-4abd-aded-17e3d7d57741-835x467_52919120.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/751/952F/m/f9dba1c8-af82-44d1-b3c3-9fdccd485a0f-835x467_52919121.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/751/952F/m/f1049458-9187-4c81-b68e-5fc52561d757-835x467_52919122.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/751/952F/m/ff121fe7-4e18-431c-aa5f-028b1229732c-835x467_52919123.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/751/952F/m/1f839362-1cfc-4a0b-8eef-ac2ba95a189a-835x467_52919124.jpg"/>
#  </div>
#  <div class="photoMask">
#  <img class="w100 sliderImage" data-lazy="https://www.mubawab-media.com/ad/7/751/952F/m/7a48d34c-b86a-4847-8368-23ed444e9b3b-835x467_52919125.jpg"/>
#  </div>
#  <div class="photoMask last-item">
#  <div class="btnBox">
#  <div class="btn-voir centered bShadow" rel="follow">
#  <i class="icon-eye orange fSize22"></i>
#  <span>Voir l'annonce</span>
#  </div>
#  </div>
#  <img class="w100" data-lazy="https://www.mubawab-media.com/ad/7/751/952F/m/3873aaa1-6c88-4c18-ab5b-403454340066-835x467_52919101.jpg"/>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <span class="priceTag hardShadow float-right floatL">13 000 000 DH
#  					</span>,
#  <a href="https://www.mubawab.ma/fr/a/7751952/vente-penthouse-casablanca-racine">Vente Penthouse Casablanca Racine
#  					</a>,
#  <p class="listingH4 floatR">5 chambres, 509 m²
#  					</p>,
#  <h3 class="listingH3">Racine à
#     					Casablanca
#  				</h3>]

# %% [markdown]
# *Scrapping the data of the 1st page*

# %%
# Initialize lists to store data
location = []
total_rooms= []
description = []
prices = []

for i in range(0, len(housing), 5):
    location.append(housing[i+4].get_text(strip=True))
    total_rooms.append(housing[i + 3].get_text(strip=True))
    description.append(housing[i + 2].get_text(strip=True))
    prices.append(housing[i + 1].get_text(strip=True))

for i in range(len(location)):
    print(f"Location: {location[i]}")
    print(f"Total Rooms: {total_rooms[i]}")
    print(f"Description: {description[i]}")
    print(f"Price: {prices[i]}")
    print("\n")
# Out:
# Location: Oulfa à
#    					Casablanca
# Total Rooms: 3 chambres, 116 m²
# Description: Duplex deux facades sud/est bien ensoleil...
# Price: 980 000 000 DH
#
#
# Location: Casablanca Marina à
#    					Casablanca
# Total Rooms: 2 chambres, 142 m²
# Description: Appartement marina vue mer mosquée hassan...
# Price: 530 000 000 DH
#
#
# Location: Ain Diab à
#    					Casablanca
# Total Rooms: 3 chambres, 280 m²
# Description: Appartement à vendre à Ain Diab. 5 grande...
# Price: 450 000 000 DH
#
#
# Location: Anfa Supérieur à
#    					Casablanca
# Total Rooms: 3 chambres, 110 m²
# Description: Opportunité à saisir
# Price: 165 000 000 DH
#
#
# Location: Les Hôpitaux à
#    					Casablanca
# Total Rooms: 2 chambres, 113 m²
# Description: Appartement à vendre à Les Hôpitaux. Surf...
# Price: 156 000 000 DH
#
#
# Location: Les Hôpitaux à
#    					Casablanca
# Total Rooms: 2 chambres, 109 m²
# Description: Vente d'un bel appartement à Les Hôpitaux...
# Price: 140 000 000 DH
#
#
# Location: Les princesses à
#    					Casablanca
# Total Rooms: 1 chambre, 55 m²
# Description: Studio meublé
# Price: 125 000 000 DH
#
#
# Location: Mers Sultan à
#    					Casablanca
# Total Rooms: 3 chambres, 120 m²
# Description: Apparte de haute standing situé au cœur d...
# Price: 120 000 000 DH
#
#
# Location: à
#    					Oulad Salah
# Total Rooms: 3 chambres, 173 m²
# Description: Appartement a al fidae mesure 173 m2 semi...
# Price: 116 500 000 DH
#
#
# Location: Aïn Sebaâ à
#    					Casablanca
# Total Rooms: 3 chambres, 222 m²
# Description: Bel appartement à vendre à Aïn Sebaâ. Sur...
# Price: 115 440 000 DH
#
#
# Location: à
#    					Errahma
# Total Rooms: 2 chambres, 79 m²
# Description: Vente d'un bel appartement à Errahma. 2 b...
# Price: 110 000 000 DH
#
#
# Location: Mers Sultan à
#    					Casablanca
# Total Rooms: 2 chambres, 128 m²
# Description: Vente d'un bel appartement à Mers Sultan...
# Price: 109 000 000 DH
#
#
# Location: Mers Sultan à
#    					Casablanca
# Total Rooms: 2 chambres, 128 m²
# Description: Appartement à vendre à Mers Sultan. 2 gra...
# Price: 109 000 000 DH
#
#
# Location: Maârif Extension à
#    					Casablanca
# Total Rooms: 3 chambres, 92 m²
# Description: Vente appart Maarif ex
# Price: 105 000 000 DH
#
#
# Location: Maârif à
#    					Casablanca
# Total Rooms: 2 chambres, 80 m²
# Description: Appartement a vendre quarthier gautier
# Price: 100 000 000 DH
#
#
# Location: à
#    					Nouaceur
# Total Rooms: 3 chambres, 101 m²
# Description: Appartement à vendre à Nouaceur. Superfic...
# Price: 98 000 000 DH
#
#
# Location: Bourgogne Ouest à
#    					Casablanca
# Total Rooms: 1 chambre, 63 m²
# Description: Appartement à vendre à Bourgogne Ouest. S...
# Price: 95 000 000 DH
#
#
# Location: Quartier Industriel à
#    					Bouznika
# Total Rooms: 2 chambres, 115 m²
# Description: Appartement a vendre
# Price: 72 000 000 DH
#
#
# Location: Sidi Othmane à
#    					Casablanca
# Total Rooms: 2 chambres, 75 m²
# Description: Appartement à vendre à rue Abdelkader sah...
# Price: 70 000 000 DH
#
#
# Location: Oasis à
#    					Casablanca
# Total Rooms: 78 chambres, 4264 m²
# Description: Appartement à vendre à Oasis. 78 pièces...
# Price: 60 000 000 DH
#
#
# Location: Anfa à
#    					Casablanca
# Total Rooms: 5 chambres, 290 m²
# Description: Appartement 290 m / 5 chambres / double s...
# Price: 43 000 000 DH
#
#
# Location: Anassi à
#    					Casablanca
# Total Rooms: 2 chambres, 52 m²
# Description: Anassi ahlam sakan
# Price: 36 000 000 DH
#
#
# Location: Al Qods à
#    					Casablanca
# Total Rooms: 3 chambres, 62 m²
# Description: Appartement a vendre Azhar bernoussi
# Price: 34 000 000 DH
#
#
# Location: à
#    					Dar Bouazza
# Total Rooms: 3 chambres, 200 m²
# Description: Superbe appartement à vendre à Dar Bouazz...
# Price: 20 000 000 DH
#
#
# Location: Maârif à
#    					Casablanca
# Total Rooms: 10 chambres, 972 m²
# Description: Ancien Immeuble à vendre Casablanca Maari...
# Price: 20 000 000 DH
#
#
# Location: Maârif à
#    					Casablanca
# Total Rooms: 14 chambres, 1350 m²
# Description: Immeuble neuf 6 locaux et 14 appartements...
# Price: 20 000 000 DH
#
#
# Location: Gauthier à
#    					Casablanca
# Total Rooms: 5 chambres, 897 m²
# Description: Immeuble Moderne R4 Penthouse Et 2 Appart...
# Price: 16 500 000 DH
#
#
# Location: Californie à
#    					Casablanca
# Total Rooms: 5 chambres, 914 m²
# Description: Villa luxuieuse quartier qualifornie
# Price: 16 250 000 DH
#
#
# Location: Al Kodia à
#    					El Jadida
# Total Rooms: 4 chambres, 187 m²
# Description: Haut villa standig 187m2 a yakout badis 3...
# Price: 16 200 000 DH
#
#
# Location: Bourgogne Ouest à
#    					Casablanca
# Total Rooms: 2 chambres, 110 m²
# Description: Bel appartement à vendre à Bourgogne Oues...
# Price: 15 000 000 DH
#
#
# Location: CIL (Hay Salam) à
#    					Casablanca
# Total Rooms: 4 chambres, 700 m²
# Description: Villa moderne 4 chambres piscine au cil
# Price: 15 000 000 DH
#
#
# Location: Plateau (Al Batha) à
#    					Casablanca
# Total Rooms: 4 chambres, 423 m²
# Description: Bel appartement à vendre à Plateau (Al Ba...
# Price: 14 805 000 DH
#
#
# Location: Racine à
#    					Casablanca
# Total Rooms: 5 chambres, 509 m²
# Description: Vente Penthouse Casablanca Racine
# Price: 13 000 000 DH

# %%
# for price in prices:
#   print(price)
len(prices)
# Out:
# 33

# %% [markdown]
# *scrape the data of all the pages*

# %%
base_url = "https://www.mubawab.ma/fr/scr/casablanca-settat/appartements-a-vendre:o:d:p"
housing = soup.select(".listingH3 , #mainListing .floatR , .listingTit a , .hardShadow")
number_of_pages = 18
for i in range(2,number_of_pages+1):
    url = f"{base_url}:{i}" # URL Manupilation for each page
    res = requests.get(url)
    soup = BeautifulSoup(res.text)
    for j in range(0, len(housing), 5):
      prices.append(housing[j + 1].get_text(strip=True))
      description.append(housing[j + 2].get_text(strip=True))
      total_rooms.append(housing[j + 3].get_text(strip=True))
      location.append(housing[j+4].get_text(strip=True))
# Out:
# /usr/local/lib/python3.10/dist-packages/bs4/builder/__init__.py:545: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   warnings.warn(

# %%
# for i in range(len(location)):
#     print(f"Location: {location[i]}")
#     print(f"Total Rooms: {total_rooms[i]}")
#     print(f"Description: {description[i]}")
#     print(f"Price: {prices[i]}")
#     print("\n")

len(prices)
# Out:
# 1155

# %%
# Function to convert a price string to an integer
def convert_price(price_str):
    try:
        # Remove non-breaking space characters and other non-numeric characters
        cleaned_price_str = ''.join(filter(str.isdigit, price_str))
        return int(cleaned_price_str)
    except ValueError:
        return float('inf')  # Handle cases where the price is not a valid number

# Convert prices to a list of tuples (original index, price) for sorting
prices_with_indices = list(enumerate(prices))

# Sort the list of tuples based on the price
sorted_prices_with_indices = sorted(prices_with_indices, key=lambda x: convert_price(x[1]))

# Display the sorted prices
for index, price in sorted_prices_with_indices:
    print(f"{index + 1}. {price}")
# Out:
# 614. 3 300 000 DH
# 615. 3 300 000 DH
# 616. 3 300 000 DH
# 617. 3 300 000 DH
# 618. 3 300 000 DH
# 619. 3 300 000 DH
# 620. 3 300 000 DH
# 621. 3 300 000 DH
# 622. 3 300 000 DH
# 623. 3 300 000 DH
# 624. 3 300 000 DH
# 625. 3 300 000 DH
# 626. 3 300 000 DH
# 627. 3 300 000 DH
# 647. 3 300 000 DH
# 648. 3 300 000 DH
# 649. 3 300 000 DH
# 650. 3 300 000 DH
# 651. 3 300 000 DH
# 652. 3 300 000 DH
# 653. 3 300 000 DH
# 654. 3 300 000 DH
# 655. 3 300 000 DH
# 656. 3 300 000 DH
# 657. 3 300 000 DH
# 658. 3 300 000 DH
# 659. 3 300 000 DH
# 660. 3 300 000 DH
# 680. 3 300 000 DH
# 681. 3 300 000 DH
# 682. 3 300 000 DH
# 683. 3 300 000 DH
# 684. 3 300 000 DH
# 685. 3 300 000 DH
# 686. 3 300 000 DH
# 687. 3 300 000 DH
# 688. 3 300 000 DH
# 689. 3 300 000 DH
# 690. 3 300 000 DH
# 691. 3 300 000 DH
# 692. 3 300 000 DH
# 693. 3 300 000 DH
# 713. 3 300 000 DH
# 714. 3 300 000 DH
# 715. 3 300 000 DH
# 716. 3 300 000 DH
# 717. 3 300 000 DH
# 718. 3 300 000 DH
# 719. 3 300 000 DH
# 720. 3 300 000 DH
# 721. 3 300 000 DH
# 722. 3 300 000 DH
# 723. 3 300 000 DH
# 724. 3 300 000 DH
# 725. 3 300 000 DH
# 726. 3 300 000 DH
# 746. 3 300 000 DH
# 747. 3 300 000 DH
# 748. 3 300 000 DH
# 749. 3 300 000 DH
# 750. 3 300 000 DH
# 751. 3 300 000 DH
# 752. 3 300 000 DH
# 753. 3 300 000 DH
# 754. 3 300 000 DH
# 755. 3 300 000 DH
# 756. 3 300 000 DH
# 757. 3 300 000 DH
# 758. 3 300 000 DH
# 759. 3 300 000 DH
# 779. 3 300 000 DH
# 780. 3 300 000 DH
# 781. 3 300 000 DH
# 782. 3 300 000 DH
# 783. 3 300 000 DH
# 784. 3 300 000 DH
# 785. 3 300 000 DH
# 786. 3 300 000 DH
# 787. 3 300 000 DH
# 788. 3 300 000 DH
# 789. 3 300 000 DH
# 790. 3 300 000 DH
# 791. 3 300 000 DH
# 792. 3 300 000 DH
# 812. 3 300 000 DH
# 813. 3 300 000 DH
# 814. 3 300 000 DH
# 815. 3 300 000 DH
# 816. 3 300 000 DH
# 817. 3 300 000 DH
# 818. 3 300 000 DH
# 819. 3 300 000 DH
# 820. 3 300 000 DH
# 821. 3 300 000 DH
# 822. 3 300 000 DH
# 823. 3 300 000 DH
# 824. 3 300 000 DH
# 825. 3 300 000 DH
# 845. 3 300 000 DH
# 846. 3 300 000 DH
# 847. 3 300 000 DH
# 848. 3 300 000 DH
# 849. 3 300 000 DH
# 850. 3 300 000 DH
# 851. 3 300 000 DH
# 852. 3 300 000 DH
# 853. 3 300 000 DH
# 854. 3 300 000 DH
# 855. 3 300 000 DH
# 856. 3 300 000 DH
# 857. 3 300 000 DH
# 858. 3 300 000 DH
# 878. 3 300 000 DH
# 879. 3 300 000 DH
# 880. 3 300 000 DH
# 881. 3 300 000 DH
# 882. 3 300 000 DH
# 883. 3 300 000 DH
# 884. 3 300 000 DH
# 885. 3 300 000 DH
# 886. 3 300 000 DH
# 887. 3 300 000 DH
# 888. 3 300 000 DH
# 889. 3 300 000 DH
# 890. 3 300 000 DH
# 891. 3 300 000 DH
# 911. 3 300 000 DH
# 912. 3 300 000 DH
# 913. 3 300 000 DH
# 914. 3 300 000 DH
# 915. 3 300 000 DH
# 916. 3 300 000 DH
# 917. 3 300 000 DH
# 918. 3 300 000 DH
# 919. 3 300 000 DH
# 920. 3 300 000 DH
# 921. 3 300 000 DH
# 922. 3 300 000 DH
# 923. 3 300 000 DH
# 924. 3 300 000 DH
# 944. 3 300 000 DH
# 945. 3 300 000 DH
# 946. 3 300 000 DH
# 947. 3 300 000 DH
# 948. 3 300 000 DH
# 949. 3 300 000 DH
# 950. 3 300 000 DH
# 951. 3 300 000 DH
# 952. 3 300 000 DH
# 953. 3 300 000 DH
# 954. 3 300 000 DH
# 955. 3 300 000 DH
# 956. 3 300 000 DH
# 957. 3 300 000 DH
# 977. 3 300 000 DH
# 978. 3 300 000 DH
# 979. 3 300 000 DH
# 980. 3 300 000 DH
# 981. 3 300 000 DH
# 982. 3 300 000 DH
# 983. 3 300 000 DH
# 984. 3 300 000 DH
# 985. 3 300 000 DH
# 986. 3 300 000 DH
# 987. 3 300 000 DH
# 988. 3 300 000 DH
# 989. 3 300 000 DH
# 990. 3 300 000 DH
# 1010. 3 300 000 DH
# 1011. 3 300 000 DH
# 1012. 3 300 000 DH
# 1013. 3 300 000 DH
# 1014. 3 300 000 DH
# 1015. 3 300 000 DH
# 1016. 3 300 000 DH
# 1017. 3 300 000 DH
# 1018. 3 300 000 DH
# 1019. 3 300 000 DH
# 1020. 3 300 000 DH
# 1021. 3 300 000 DH
# 1022. 3 300 000 DH
# 1023. 3 300 000 DH
# 1043. 3 300 000 DH
# 1044. 3 300 000 DH
# 1045. 3 300 000 DH
# 1046. 3 300 000 DH
# 1047. 3 300 000 DH
# 1048. 3 300 000 DH
# 1049. 3 300 000 DH
# 1050. 3 300 000 DH
# 1051. 3 300 000 DH
# 1052. 3 300 000 DH
# 1053. 3 300 000 DH
# 1054. 3 300 000 DH
# 1055. 3 300 000 DH
# 1056. 3 300 000 DH
# 1076. 3 300 000 DH
# 1077. 3 300 000 DH
# 1078. 3 300 000 DH
# 1079. 3 300 000 DH
# 1080. 3 300 000 DH
# 1081. 3 300 000 DH
# 1082. 3 300 000 DH
# 1083. 3 300 000 DH
# 1084. 3 300 000 DH
# 1085. 3 300 000 DH
# 1086. 3 300 000 DH
# 1087. 3 300 000 DH
# 1088. 3 300 000 DH
# 1089. 3 300 000 DH
# 1109. 3 300 000 DH
# 1110. 3 300 000 DH
# 1111. 3 300 000 DH
# 1112. 3 300 000 DH
# 1113. 3 300 000 DH
# 1114. 3 300 000 DH
# 1115. 3 300 000 DH
# 1116. 3 300 000 DH
# 1117. 3 300 000 DH
# 1118. 3 300 000 DH
# 1119. 3 300 000 DH
# 1120. 3 300 000 DH
# 1121. 3 300 000 DH
# 1122. 3 300 000 DH
# 1142. 3 300 000 DH
# 1143. 3 300 000 DH
# 1144. 3 300 000 DH
# 1145. 3 300 000 DH
# 1146. 3 300 000 DH
# 1147. 3 300 000 DH
# 1148. 3 300 000 DH
# 1149. 3 300 000 DH
# 1150. 3 300 000 DH
# 1151. 3 300 000 DH
# 1152. 3 300 000 DH
# 1153. 3 300 000 DH
# 1154. 3 300 000 DH
# 1155. 3 300 000 DH
# 613. 3 300 050 DH
# 646. 3 300 050 DH
# 679. 3 300 050 DH
# 712. 3 300 050 DH
# 745. 3 300 050 DH
# 778. 3 300 050 DH
# 811. 3 300 050 DH
# 844. 3 300 050 DH
# 877. 3 300 050 DH
# 910. 3 300 050 DH
# 943. 3 300 050 DH
# 976. 3 300 050 DH
# 1009. 3 300 050 DH
# 1042. 3 300 050 DH
# 1075. 3 300 050 DH
# 1108. 3 300 050 DH
# 1141. 3 300 050 DH
# 612. 3 315 000 DH
# 645. 3 315 000 DH
# 678. 3 315 000 DH
# 711. 3 315 000 DH
# 744. 3 315 000 DH
# 777. 3 315 000 DH
# 810. 3 315 000 DH
# 843. 3 315 000 DH
# 876. 3 315 000 DH
# 909. 3 315 000 DH
# 942. 3 315 000 DH
# 975. 3 315 000 DH
# 1008. 3 315 000 DH
# 1041. 3 315 000 DH
# 1074. 3 315 000 DH
# 1107. 3 315 000 DH
# 1140. 3 315 000 DH
# 611. 3 330 000 DH
# 644. 3 330 000 DH
# 677. 3 330 000 DH
# 710. 3 330 000 DH
# 743. 3 330 000 DH
# 776. 3 330 000 DH
# 809. 3 330 000 DH
# 842. 3 330 000 DH
# 875. 3 330 000 DH
# 908. 3 330 000 DH
# 941. 3 330 000 DH
# 974. 3 330 000 DH
# 1007. 3 330 000 DH
# 1040. 3 330 000 DH
# 1073. 3 330 000 DH
# 1106. 3 330 000 DH
# 1139. 3 330 000 DH
# 609. 3 340 000 DH
# 610. 3 340 000 DH
# 642. 3 340 000 DH
# 643. 3 340 000 DH
# 675. 3 340 000 DH
# 676. 3 340 000 DH
# 708. 3 340 000 DH
# 709. 3 340 000 DH
# 741. 3 340 000 DH
# 742. 3 340 000 DH
# 774. 3 340 000 DH
# 775. 3 340 000 DH
# 807. 3 340 000 DH
# 808. 3 340 000 DH
# 840. 3 340 000 DH
# 841. 3 340 000 DH
# 873. 3 340 000 DH
# 874. 3 340 000 DH
# 906. 3 340 000 DH
# 907. 3 340 000 DH
# 939. 3 340 000 DH
# 940. 3 340 000 DH
# 972. 3 340 000 DH
# 973. 3 340 000 DH
# 1005. 3 340 000 DH
# 1006. 3 340 000 DH
# 1038. 3 340 000 DH
# 1039. 3 340 000 DH
# 1071. 3 340 000 DH
# 1072. 3 340 000 DH
# 1104. 3 340 000 DH
# 1105. 3 340 000 DH
# 1137. 3 340 000 DH
# 1138. 3 340 000 DH
# 608. 3 349 000 DH
# 641. 3 349 000 DH
# 674. 3 349 000 DH
# 707. 3 349 000 DH
# 740. 3 349 000 DH
# 773. 3 349 000 DH
# 806. 3 349 000 DH
# 839. 3 349 000 DH
# 872. 3 349 000 DH
# 905. 3 349 000 DH
# 938. 3 349 000 DH
# 971. 3 349 000 DH
# 1004. 3 349 000 DH
# 1037. 3 349 000 DH
# 1070. 3 349 000 DH
# 1103. 3 349 000 DH
# 1136. 3 349 000 DH
# 603. 3 350 000 DH
# 604. 3 350 000 DH
# 605. 3 350 000 DH
# 606. 3 350 000 DH
# 607. 3 350 000 DH
# 636. 3 350 000 DH
# 637. 3 350 000 DH
# 638. 3 350 000 DH
# 639. 3 350 000 DH
# 640. 3 350 000 DH
# 669. 3 350 000 DH
# 670. 3 350 000 DH
# 671. 3 350 000 DH
# 672. 3 350 000 DH
# 673. 3 350 000 DH
# 702. 3 350 000 DH
# 703. 3 350 000 DH
# 704. 3 350 000 DH
# 705. 3 350 000 DH
# 706. 3 350 000 DH
# 735. 3 350 000 DH
# 736. 3 350 000 DH
# 737. 3 350 000 DH
# 738. 3 350 000 DH
# 739. 3 350 000 DH
# 768. 3 350 000 DH
# 769. 3 350 000 DH
# 770. 3 350 000 DH
# 771. 3 350 000 DH
# 772. 3 350 000 DH
# 801. 3 350 000 DH
# 802. 3 350 000 DH
# 803. 3 350 000 DH
# 804. 3 350 000 DH
# 805. 3 350 000 DH
# 834. 3 350 000 DH
# 835. 3 350 000 DH
# 836. 3 350 000 DH
# 837. 3 350 000 DH
# 838. 3 350 000 DH
# 867. 3 350 000 DH
# 868. 3 350 000 DH
# 869. 3 350 000 DH
# 870. 3 350 000 DH
# 871. 3 350 000 DH
# 900. 3 350 000 DH
# 901. 3 350 000 DH
# 902. 3 350 000 DH
# 903. 3 350 000 DH
# 904. 3 350 000 DH
# 933. 3 350 000 DH
# 934. 3 350 000 DH
# 935. 3 350 000 DH
# 936. 3 350 000 DH
# 937. 3 350 000 DH
# 966. 3 350 000 DH
# 967. 3 350 000 DH
# 968. 3 350 000 DH
# 969. 3 350 000 DH
# 970. 3 350 000 DH
# 999. 3 350 000 DH
# 1000. 3 350 000 DH
# 1001. 3 350 000 DH
# 1002. 3 350 000 DH
# 1003. 3 350 000 DH
# 1032. 3 350 000 DH
# 1033. 3 350 000 DH
# 1034. 3 350 000 DH
# 1035. 3 350 000 DH
# 1036. 3 350 000 DH
# 1065. 3 350 000 DH
# 1066. 3 350 000 DH
# 1067. 3 350 000 DH
# 1068. 3 350 000 DH
# 1069. 3 350 000 DH
# 1098. 3 350 000 DH
# 1099. 3 350 000 DH
# 1100. 3 350 000 DH
# 1101. 3 350 000 DH
# 1102. 3 350 000 DH
# 1131. 3 350 000 DH
# 1132. 3 350 000 DH
# 1133. 3 350 000 DH
# 1134. 3 350 000 DH
# 1135. 3 350 000 DH
# 601. 3 380 000 DH
# 602. 3 380 000 DH
# 634. 3 380 000 DH
# 635. 3 380 000 DH
# 667. 3 380 000 DH
# 668. 3 380 000 DH
# 700. 3 380 000 DH
# 701. 3 380 000 DH
# 733. 3 380 000 DH
# 734. 3 380 000 DH
# 766. 3 380 000 DH
# 767. 3 380 000 DH
# 799. 3 380 000 DH
# 800. 3 380 000 DH
# 832. 3 380 000 DH
# 833. 3 380 000 DH
# 865. 3 380 000 DH
# 866. 3 380 000 DH
# 898. 3 380 000 DH
# 899. 3 380 000 DH
# 931. 3 380 000 DH
# 932. 3 380 000 DH
# 964. 3 380 000 DH
# 965. 3 380 000 DH
# 997. 3 380 000 DH
# 998. 3 380 000 DH
# 1030. 3 380 000 DH
# 1031. 3 380 000 DH
# 1063. 3 380 000 DH
# 1064. 3 380 000 DH
# 1096. 3 380 000 DH
# 1097. 3 380 000 DH
# 1129. 3 380 000 DH
# 1130. 3 380 000 DH
# 600. 3 390 000 DH
# 633. 3 390 000 DH
# 666. 3 390 000 DH
# 699. 3 390 000 DH
# 732. 3 390 000 DH
# 765. 3 390 000 DH
# 798. 3 390 000 DH
# 831. 3 390 000 DH
# 864. 3 390 000 DH
# 897. 3 390 000 DH
# 930. 3 390 000 DH
# 963. 3 390 000 DH
# 996. 3 390 000 DH
# 1029. 3 390 000 DH
# 1062. 3 390 000 DH
# 1095. 3 390 000 DH
# 1128. 3 390 000 DH
# 599. 3 399 000 DH
# 632. 3 399 000 DH
# 665. 3 399 000 DH
# 698. 3 399 000 DH
# 731. 3 399 000 DH
# 764. 3 399 000 DH
# 797. 3 399 000 DH
# 830. 3 399 000 DH
# 863. 3 399 000 DH
# 896. 3 399 000 DH
# 929. 3 399 000 DH
# 962. 3 399 000 DH
# 995. 3 399 000 DH
# 1028. 3 399 000 DH
# 1061. 3 399 000 DH
# 1094. 3 399 000 DH
# 1127. 3 399 000 DH
# 595. 3 400 000 DH
# 596. 3 400 000 DH
# 597. 3 400 000 DH
# 598. 3 400 000 DH
# 628. 3 400 000 DH
# 629. 3 400 000 DH
# 630. 3 400 000 DH
# 631. 3 400 000 DH
# 661. 3 400 000 DH
# 662. 3 400 000 DH
# 663. 3 400 000 DH
# 664. 3 400 000 DH
# 694. 3 400 000 DH
# 695. 3 400 000 DH
# 696. 3 400 000 DH
# 697. 3 400 000 DH
# 727. 3 400 000 DH
# 728. 3 400 000 DH
# 729. 3 400 000 DH
# 730. 3 400 000 DH
# 760. 3 400 000 DH
# 761. 3 400 000 DH
# 762. 3 400 000 DH
# 763. 3 400 000 DH
# 793. 3 400 000 DH
# 794. 3 400 000 DH
# 795. 3 400 000 DH
# 796. 3 400 000 DH
# 826. 3 400 000 DH
# 827. 3 400 000 DH
# 828. 3 400 000 DH
# 829. 3 400 000 DH
# 859. 3 400 000 DH
# 860. 3 400 000 DH
# 861. 3 400 000 DH
# 862. 3 400 000 DH
# 892. 3 400 000 DH
# 893. 3 400 000 DH
# 894. 3 400 000 DH
# 895. 3 400 000 DH
# 925. 3 400 000 DH
# 926. 3 400 000 DH
# 927. 3 400 000 DH
# 928. 3 400 000 DH
# 958. 3 400 000 DH
# 959. 3 400 000 DH
# 960. 3 400 000 DH
# 961. 3 400 000 DH
# 991. 3 400 000 DH
# 992. 3 400 000 DH
# 993. 3 400 000 DH
# 994. 3 400 000 DH
# 1024. 3 400 000 DH
# 1025. 3 400 000 DH
# 1026. 3 400 000 DH
# 1027. 3 400 000 DH
# 1057. 3 400 000 DH
# 1058. 3 400 000 DH
# 1059. 3 400 000 DH
# 1060. 3 400 000 DH
# 1090. 3 400 000 DH
# 1091. 3 400 000 DH
# 1092. 3 400 000 DH
# 1093. 3 400 000 DH
# 1123. 3 400 000 DH
# 1124. 3 400 000 DH
# 1125. 3 400 000 DH
# 1126. 3 400 000 DH
# 33. 13 000 000 DH
# 66. 13 000 000 DH
# 99. 13 000 000 DH
# 132. 13 000 000 DH
# 165. 13 000 000 DH
# 198. 13 000 000 DH
# 231. 13 000 000 DH
# 264. 13 000 000 DH
# 297. 13 000 000 DH
# 330. 13 000 000 DH
# 363. 13 000 000 DH
# 396. 13 000 000 DH
# 429. 13 000 000 DH
# 462. 13 000 000 DH
# 495. 13 000 000 DH
# 528. 13 000 000 DH
# 561. 13 000 000 DH
# 594. 13 000 000 DH
# 32. 14 805 000 DH
# 65. 14 805 000 DH
# 98. 14 805 000 DH
# 131. 14 805 000 DH
# 164. 14 805 000 DH
# 197. 14 805 000 DH
# 230. 14 805 000 DH
# 263. 14 805 000 DH
# 296. 14 805 000 DH
# 329. 14 805 000 DH
# 362. 14 805 000 DH
# 395. 14 805 000 DH
# 428. 14 805 000 DH
# 461. 14 805 000 DH
# 494. 14 805 000 DH
# 527. 14 805 000 DH
# 560. 14 805 000 DH
# 593. 14 805 000 DH
# 30. 15 000 000 DH
# 31. 15 000 000 DH
# 63. 15 000 000 DH
# 64. 15 000 000 DH
# 96. 15 000 000 DH
# 97. 15 000 000 DH
# 129. 15 000 000 DH
# 130. 15 000 000 DH
# 162. 15 000 000 DH
# 163. 15 000 000 DH
# 195. 15 000 000 DH
# 196. 15 000 000 DH
# 228. 15 000 000 DH
# 229. 15 000 000 DH
# 261. 15 000 000 DH
# 262. 15 000 000 DH
# 294. 15 000 000 DH
# 295. 15 000 000 DH
# 327. 15 000 000 DH
# 328. 15 000 000 DH
# 360. 15 000 000 DH
# 361. 15 000 000 DH
# 393. 15 000 000 DH
# 394. 15 000 000 DH
# 426. 15 000 000 DH
# 427. 15 000 000 DH
# 459. 15 000 000 DH
# 460. 15 000 000 DH
# 492. 15 000 000 DH
# 493. 15 000 000 DH
# 525. 15 000 000 DH
# 526. 15 000 000 DH
# 558. 15 000 000 DH
# 559. 15 000 000 DH
# 591. 15 000 000 DH
# 592. 15 000 000 DH
# 29. 16 200 000 DH
# 62. 16 200 000 DH
# 95. 16 200 000 DH
# 128. 16 200 000 DH
# 161. 16 200 000 DH
# 194. 16 200 000 DH
# 227. 16 200 000 DH
# 260. 16 200 000 DH
# 293. 16 200 000 DH
# 326. 16 200 000 DH
# 359. 16 200 000 DH
# 392. 16 200 000 DH
# 425. 16 200 000 DH
# 458. 16 200 000 DH
# 491. 16 200 000 DH
# 524. 16 200 000 DH
# 557. 16 200 000 DH
# 590. 16 200 000 DH
# 28. 16 250 000 DH
# 61. 16 250 000 DH
# 94. 16 250 000 DH
# 127. 16 250 000 DH
# 160. 16 250 000 DH
# 193. 16 250 000 DH
# 226. 16 250 000 DH
# 259. 16 250 000 DH
# 292. 16 250 000 DH
# 325. 16 250 000 DH
# 358. 16 250 000 DH
# 391. 16 250 000 DH
# 424. 16 250 000 DH
# 457. 16 250 000 DH
# 490. 16 250 000 DH
# 523. 16 250 000 DH
# 556. 16 250 000 DH
# 589. 16 250 000 DH
# 27. 16 500 000 DH
# 60. 16 500 000 DH
# 93. 16 500 000 DH
# 126. 16 500 000 DH
# 159. 16 500 000 DH
# 192. 16 500 000 DH
# 225. 16 500 000 DH
# 258. 16 500 000 DH
# 291. 16 500 000 DH
# 324. 16 500 000 DH
# 357. 16 500 000 DH
# 390. 16 500 000 DH
# 423. 16 500 000 DH
# 456. 16 500 000 DH
# 489. 16 500 000 DH
# 522. 16 500 000 DH
# 555. 16 500 000 DH
# 588. 16 500 000 DH
# 24. 20 000 000 DH
# 25. 20 000 000 DH
# 26. 20 000 000 DH
# 57. 20 000 000 DH
# 58. 20 000 000 DH
# 59. 20 000 000 DH
# 90. 20 000 000 DH
# 91. 20 000 000 DH
# 92. 20 000 000 DH
# 123. 20 000 000 DH
# 124. 20 000 000 DH
# 125. 20 000 000 DH
# 156. 20 000 000 DH
# 157. 20 000 000 DH
# 158. 20 000 000 DH
# 189. 20 000 000 DH
# 190. 20 000 000 DH
# 191. 20 000 000 DH
# 222. 20 000 000 DH
# 223. 20 000 000 DH
# 224. 20 000 000 DH
# 255. 20 000 000 DH
# 256. 20 000 000 DH
# 257. 20 000 000 DH
# 288. 20 000 000 DH
# 289. 20 000 000 DH
# 290. 20 000 000 DH
# 321. 20 000 000 DH
# 322. 20 000 000 DH
# 323. 20 000 000 DH
# 354. 20 000 000 DH
# 355. 20 000 000 DH
# 356. 20 000 000 DH
# 387. 20 000 000 DH
# 388. 20 000 000 DH
# 389. 20 000 000 DH
# 420. 20 000 000 DH
# 421. 20 000 000 DH
# 422. 20 000 000 DH
# 453. 20 000 000 DH
# 454. 20 000 000 DH
# 455. 20 000 000 DH
# 486. 20 000 000 DH
# 487. 20 000 000 DH
# 488. 20 000 000 DH
# 519. 20 000 000 DH
# 520. 20 000 000 DH
# 521. 20 000 000 DH
# 552. 20 000 000 DH
# 553. 20 000 000 DH
# 554. 20 000 000 DH
# 585. 20 000 000 DH
# 586. 20 000 000 DH
# 587. 20 000 000 DH
# 23. 34 000 000 DH
# 56. 34 000 000 DH
# 89. 34 000 000 DH
# 122. 34 000 000 DH
# 155. 34 000 000 DH
# 188. 34 000 000 DH
# 221. 34 000 000 DH
# 254. 34 000 000 DH
# 287. 34 000 000 DH
# 320. 34 000 000 DH
# 353. 34 000 000 DH
# 386. 34 000 000 DH
# 419. 34 000 000 DH
# 452. 34 000 000 DH
# 485. 34 000 000 DH
# 518. 34 000 000 DH
# 551. 34 000 000 DH
# 584. 34 000 000 DH
# 22. 36 000 000 DH
# 55. 36 000 000 DH
# 88. 36 000 000 DH
# 121. 36 000 000 DH
# 154. 36 000 000 DH
# 187. 36 000 000 DH
# 220. 36 000 000 DH
# 253. 36 000 000 DH
# 286. 36 000 000 DH
# 319. 36 000 000 DH
# 352. 36 000 000 DH
# 385. 36 000 000 DH
# 418. 36 000 000 DH
# 451. 36 000 000 DH
# 484. 36 000 000 DH
# 517. 36 000 000 DH
# 550. 36 000 000 DH
# 583. 36 000 000 DH
# 21. 43 000 000 DH
# 54. 43 000 000 DH
# 87. 43 000 000 DH
# 120. 43 000 000 DH
# 153. 43 000 000 DH
# 186. 43 000 000 DH
# 219. 43 000 000 DH
# 252. 43 000 000 DH
# 285. 43 000 000 DH
# 318. 43 000 000 DH
# 351. 43 000 000 DH
# 384. 43 000 000 DH
# 417. 43 000 000 DH
# 450. 43 000 000 DH
# 483. 43 000 000 DH
# 516. 43 000 000 DH
# 549. 43 000 000 DH
# 582. 43 000 000 DH
# 20. 60 000 000 DH
# 53. 60 000 000 DH
# 86. 60 000 000 DH
# 119. 60 000 000 DH
# 152. 60 000 000 DH
# 185. 60 000 000 DH
# 218. 60 000 000 DH
# 251. 60 000 000 DH
# 284. 60 000 000 DH
# 317. 60 000 000 DH
# 350. 60 000 000 DH
# 383. 60 000 000 DH
# 416. 60 000 000 DH
# 449. 60 000 000 DH
# 482. 60 000 000 DH
# 515. 60 000 000 DH
# 548. 60 000 000 DH
# 581. 60 000 000 DH
# 19. 70 000 000 DH
# 52. 70 000 000 DH
# 85. 70 000 000 DH
# 118. 70 000 000 DH
# 151. 70 000 000 DH
# 184. 70 000 000 DH
# 217. 70 000 000 DH
# 250. 70 000 000 DH
# 283. 70 000 000 DH
# 316. 70 000 000 DH
# 349. 70 000 000 DH
# 382. 70 000 000 DH
# 415. 70 000 000 DH
# 448. 70 000 000 DH
# 481. 70 000 000 DH
# 514. 70 000 000 DH
# 547. 70 000 000 DH
# 580. 70 000 000 DH
# 18. 72 000 000 DH
# 51. 72 000 000 DH
# 84. 72 000 000 DH
# 117. 72 000 000 DH
# 150. 72 000 000 DH
# 183. 72 000 000 DH
# 216. 72 000 000 DH
# 249. 72 000 000 DH
# 282. 72 000 000 DH
# 315. 72 000 000 DH
# 348. 72 000 000 DH
# 381. 72 000 000 DH
# 414. 72 000 000 DH
# 447. 72 000 000 DH
# 480. 72 000 000 DH
# 513. 72 000 000 DH
# 546. 72 000 000 DH
# 579. 72 000 000 DH
# 17. 95 000 000 DH
# 50. 95 000 000 DH
# 83. 95 000 000 DH
# 116. 95 000 000 DH
# 149. 95 000 000 DH
# 182. 95 000 000 DH
# 215. 95 000 000 DH
# 248. 95 000 000 DH
# 281. 95 000 000 DH
# 314. 95 000 000 DH
# 347. 95 000 000 DH
# 380. 95 000 000 DH
# 413. 95 000 000 DH
# 446. 95 000 000 DH
# 479. 95 000 000 DH
# 512. 95 000 000 DH
# 545. 95 000 000 DH
# 578. 95 000 000 DH
# 16. 98 000 000 DH
# 49. 98 000 000 DH
# 82. 98 000 000 DH
# 115. 98 000 000 DH
# 148. 98 000 000 DH
# 181. 98 000 000 DH
# 214. 98 000 000 DH
# 247. 98 000 000 DH
# 280. 98 000 000 DH
# 313. 98 000 000 DH
# 346. 98 000 000 DH
# 379. 98 000 000 DH
# 412. 98 000 000 DH
# 445. 98 000 000 DH
# 478. 98 000 000 DH
# 511. 98 000 000 DH
# 544. 98 000 000 DH
# 577. 98 000 000 DH
# 15. 100 000 000 DH
# 48. 100 000 000 DH
# 81. 100 000 000 DH
# 114. 100 000 000 DH
# 147. 100 000 000 DH
# 180. 100 000 000 DH
# 213. 100 000 000 DH
# 246. 100 000 000 DH
# 279. 100 000 000 DH
# 312. 100 000 000 DH
# 345. 100 000 000 DH
# 378. 100 000 000 DH
# 411. 100 000 000 DH
# 444. 100 000 000 DH
# 477. 100 000 000 DH
# 510. 100 000 000 DH
# 543. 100 000 000 DH
# 576. 100 000 000 DH
# 14. 105 000 000 DH
# 47. 105 000 000 DH
# 80. 105 000 000 DH
# 113. 105 000 000 DH
# 146. 105 000 000 DH
# 179. 105 000 000 DH
# 212. 105 000 000 DH
# 245. 105 000 000 DH
# 278. 105 000 000 DH
# 311. 105 000 000 DH
# 344. 105 000 000 DH
# 377. 105 000 000 DH
# 410. 105 000 000 DH
# 443. 105 000 000 DH
# 476. 105 000 000 DH
# 509. 105 000 000 DH
# 542. 105 000 000 DH
# 575. 105 000 000 DH
# 12. 109 000 000 DH
# 13. 109 000 000 DH
# 45. 109 000 000 DH
# 46. 109 000 000 DH
# 78. 109 000 000 DH
# 79. 109 000 000 DH
# 111. 109 000 000 DH
# 112. 109 000 000 DH
# 144. 109 000 000 DH
# 145. 109 000 000 DH
# 177. 109 000 000 DH
# 178. 109 000 000 DH
# 210. 109 000 000 DH
# 211. 109 000 000 DH
# 243. 109 000 000 DH
# 244. 109 000 000 DH
# 276. 109 000 000 DH
# 277. 109 000 000 DH
# 309. 109 000 000 DH
# 310. 109 000 000 DH
# 342. 109 000 000 DH
# 343. 109 000 000 DH
# 375. 109 000 000 DH
# 376. 109 000 000 DH
# 408. 109 000 000 DH
# 409. 109 000 000 DH
# 441. 109 000 000 DH
# 442. 109 000 000 DH
# 474. 109 000 000 DH
# 475. 109 000 000 DH
# 507. 109 000 000 DH
# 508. 109 000 000 DH
# 540. 109 000 000 DH
# 541. 109 000 000 DH
# 573. 109 000 000 DH
# 574. 109 000 000 DH
# 11. 110 000 000 DH
# 44. 110 000 000 DH
# 77. 110 000 000 DH
# 110. 110 000 000 DH
# 143. 110 000 000 DH
# 176. 110 000 000 DH
# 209. 110 000 000 DH
# 242. 110 000 000 DH
# 275. 110 000 000 DH
# 308. 110 000 000 DH
# 341. 110 000 000 DH
# 374. 110 000 000 DH
# 407. 110 000 000 DH
# 440. 110 000 000 DH
# 473. 110 000 000 DH
# 506. 110 000 000 DH
# 539. 110 000 000 DH
# 572. 110 000 000 DH
# 10. 115 440 000 DH
# 43. 115 440 000 DH
# 76. 115 440 000 DH
# 109. 115 440 000 DH
# 142. 115 440 000 DH
# 175. 115 440 000 DH
# 208. 115 440 000 DH
# 241. 115 440 000 DH
# 274. 115 440 000 DH
# 307. 115 440 000 DH
# 340. 115 440 000 DH
# 373. 115 440 000 DH
# 406. 115 440 000 DH
# 439. 115 440 000 DH
# 472. 115 440 000 DH
# 505. 115 440 000 DH
# 538. 115 440 000 DH
# 571. 115 440 000 DH
# 9. 116 500 000 DH
# 42. 116 500 000 DH
# 75. 116 500 000 DH
# 108. 116 500 000 DH
# 141. 116 500 000 DH
# 174. 116 500 000 DH
# 207. 116 500 000 DH
# 240. 116 500 000 DH
# 273. 116 500 000 DH
# 306. 116 500 000 DH
# 339. 116 500 000 DH
# 372. 116 500 000 DH
# 405. 116 500 000 DH
# 438. 116 500 000 DH
# 471. 116 500 000 DH
# 504. 116 500 000 DH
# 537. 116 500 000 DH
# 570. 116 500 000 DH
# 8. 120 000 000 DH
# 41. 120 000 000 DH
# 74. 120 000 000 DH
# 107. 120 000 000 DH
# 140. 120 000 000 DH
# 173. 120 000 000 DH
# 206. 120 000 000 DH
# 239. 120 000 000 DH
# 272. 120 000 000 DH
# 305. 120 000 000 DH
# 338. 120 000 000 DH
# 371. 120 000 000 DH
# 404. 120 000 000 DH
# 437. 120 000 000 DH
# 470. 120 000 000 DH
# 503. 120 000 000 DH
# 536. 120 000 000 DH
# 569. 120 000 000 DH
# 7. 125 000 000 DH
# 40. 125 000 000 DH
# 73. 125 000 000 DH
# 106. 125 000 000 DH
# 139. 125 000 000 DH
# 172. 125 000 000 DH
# 205. 125 000 000 DH
# 238. 125 000 000 DH
# 271. 125 000 000 DH
# 304. 125 000 000 DH
# 337. 125 000 000 DH
# 370. 125 000 000 DH
# 403. 125 000 000 DH
# 436. 125 000 000 DH
# 469. 125 000 000 DH
# 502. 125 000 000 DH
# 535. 125 000 000 DH
# 568. 125 000 000 DH
# 6. 140 000 000 DH
# 39. 140 000 000 DH
# 72. 140 000 000 DH
# 105. 140 000 000 DH
# 138. 140 000 000 DH
# 171. 140 000 000 DH
# 204. 140 000 000 DH
# 237. 140 000 000 DH
# 270. 140 000 000 DH
# 303. 140 000 000 DH
# 336. 140 000 000 DH
# 369. 140 000 000 DH
# 402. 140 000 000 DH
# 435. 140 000 000 DH
# 468. 140 000 000 DH
# 501. 140 000 000 DH
# 534. 140 000 000 DH
# 567. 140 000 000 DH
# 5. 156 000 000 DH
# 38. 156 000 000 DH
# 71. 156 000 000 DH
# 104. 156 000 000 DH
# 137. 156 000 000 DH
# 170. 156 000 000 DH
# 203. 156 000 000 DH
# 236. 156 000 000 DH
# 269. 156 000 000 DH
# 302. 156 000 000 DH
# 335. 156 000 000 DH
# 368. 156 000 000 DH
# 401. 156 000 000 DH
# 434. 156 000 000 DH
# 467. 156 000 000 DH
# 500. 156 000 000 DH
# 533. 156 000 000 DH
# 566. 156 000 000 DH
# 4. 165 000 000 DH
# 37. 165 000 000 DH
# 70. 165 000 000 DH
# 103. 165 000 000 DH
# 136. 165 000 000 DH
# 169. 165 000 000 DH
# 202. 165 000 000 DH
# 235. 165 000 000 DH
# 268. 165 000 000 DH
# 301. 165 000 000 DH
# 334. 165 000 000 DH
# 367. 165 000 000 DH
# 400. 165 000 000 DH
# 433. 165 000 000 DH
# 466. 165 000 000 DH
# 499. 165 000 000 DH
# 532. 165 000 000 DH
# 565. 165 000 000 DH
# 3. 450 000 000 DH
# 36. 450 000 000 DH
# 69. 450 000 000 DH
# 102. 450 000 000 DH
# 135. 450 000 000 DH
# 168. 450 000 000 DH
# 201. 450 000 000 DH
# 234. 450 000 000 DH
# 267. 450 000 000 DH
# 300. 450 000 000 DH
# 333. 450 000 000 DH
# 366. 450 000 000 DH
# 399. 450 000 000 DH
# 432. 450 000 000 DH
# 465. 450 000 000 DH
# 498. 450 000 000 DH
# 531. 450 000 000 DH
# 564. 450 000 000 DH
# 2. 530 000 000 DH
# 35. 530 000 000 DH
# 68. 530 000 000 DH
# 101. 530 000 000 DH
# 134. 530 000 000 DH
# 167. 530 000 000 DH
# 200. 530 000 000 DH
# 233. 530 000 000 DH
# 266. 530 000 000 DH
# 299. 530 000 000 DH
# 332. 530 000 000 DH
# 365. 530 000 000 DH
# 398. 530 000 000 DH
# 431. 530 000 000 DH
# 464. 530 000 000 DH
# 497. 530 000 000 DH
# 530. 530 000 000 DH
# 563. 530 000 000 DH
# 1. 980 000 000 DH
# 34. 980 000 000 DH
# 67. 980 000 000 DH
# 100. 980 000 000 DH
# 133. 980 000 000 DH
# 166. 980 000 000 DH
# 199. 980 000 000 DH
# 232. 980 000 000 DH
# 265. 980 000 000 DH
# 298. 980 000 000 DH
# 331. 980 000 000 DH
# 364. 980 000 000 DH
# 397. 980 000 000 DH
# 430. 980 000 000 DH
# 463. 980 000 000 DH
# 496. 980 000 000 DH
# 529. 980 000 000 DH
# 562. 980 000 000 DH

# %%
for total_room in total_rooms:
  print(total_room)
# Out:
# 3 chambres, 116 m²
# 2 chambres, 142 m²
# 3 chambres, 280 m²
# 3 chambres, 110 m²
# 2 chambres, 113 m²
# 2 chambres, 109 m²
# 1 chambre, 55 m²
# 3 chambres, 120 m²
# 3 chambres, 173 m²
# 3 chambres, 222 m²
# 2 chambres, 79 m²
# 2 chambres, 128 m²
# 2 chambres, 128 m²
# 3 chambres, 92 m²
# 2 chambres, 80 m²
# 3 chambres, 101 m²
# 1 chambre, 63 m²
# 2 chambres, 115 m²
# 2 chambres, 75 m²
# 78 chambres, 4264 m²
# 5 chambres, 290 m²
# 2 chambres, 52 m²
# 3 chambres, 62 m²
# 3 chambres, 200 m²
# 10 chambres, 972 m²
# 14 chambres, 1350 m²
# 5 chambres, 897 m²
# 5 chambres, 914 m²
# 4 chambres, 187 m²
# 2 chambres, 110 m²
# 4 chambres, 700 m²
# 4 chambres, 423 m²
# 5 chambres, 509 m²
# 3 chambres, 116 m²
# 2 chambres, 142 m²
# 3 chambres, 280 m²
# 3 chambres, 110 m²
# 2 chambres, 113 m²
# 2 chambres, 109 m²
# 1 chambre, 55 m²
# 3 chambres, 120 m²
# 3 chambres, 173 m²
# 3 chambres, 222 m²
# 2 chambres, 79 m²
# 2 chambres, 128 m²
# 2 chambres, 128 m²
# 3 chambres, 92 m²
# 2 chambres, 80 m²
# 3 chambres, 101 m²
# 1 chambre, 63 m²
# 2 chambres, 115 m²
# 2 chambres, 75 m²
# 78 chambres, 4264 m²
# 5 chambres, 290 m²
# 2 chambres, 52 m²
# 3 chambres, 62 m²
# 3 chambres, 200 m²
# 10 chambres, 972 m²
# 14 chambres, 1350 m²
# 5 chambres, 897 m²
# 5 chambres, 914 m²
# 4 chambres, 187 m²
# 2 chambres, 110 m²
# 4 chambres, 700 m²
# 4 chambres, 423 m²
# 5 chambres, 509 m²
# 3 chambres, 116 m²
# 2 chambres, 142 m²
# 3 chambres, 280 m²
# 3 chambres, 110 m²
# 2 chambres, 113 m²
# 2 chambres, 109 m²
# 1 chambre, 55 m²
# 3 chambres, 120 m²
# 3 chambres, 173 m²
# 3 chambres, 222 m²
# 2 chambres, 79 m²
# 2 chambres, 128 m²
# 2 chambres, 128 m²
# 3 chambres, 92 m²
# 2 chambres, 80 m²
# 3 chambres, 101 m²
# 1 chambre, 63 m²
# 2 chambres, 115 m²
# 2 chambres, 75 m²
# 78 chambres, 4264 m²
# 5 chambres, 290 m²
# 2 chambres, 52 m²
# 3 chambres, 62 m²
# 3 chambres, 200 m²
# 10 chambres, 972 m²
# 14 chambres, 1350 m²
# 5 chambres, 897 m²
# 5 chambres, 914 m²
# 4 chambres, 187 m²
# 2 chambres, 110 m²
# 4 chambres, 700 m²
# 4 chambres, 423 m²
# 5 chambres, 509 m²
# 3 chambres, 116 m²
# 2 chambres, 142 m²
# 3 chambres, 280 m²
# 3 chambres, 110 m²
# 2 chambres, 113 m²
# 2 chambres, 109 m²
# 1 chambre, 55 m²
# 3 chambres, 120 m²
# 3 chambres, 173 m²
# 3 chambres, 222 m²
# 2 chambres, 79 m²
# 2 chambres, 128 m²
# 2 chambres, 128 m²
# 3 chambres, 92 m²
# 2 chambres, 80 m²
# 3 chambres, 101 m²
# 1 chambre, 63 m²
# 2 chambres, 115 m²
# 2 chambres, 75 m²
# 78 chambres, 4264 m²
# 5 chambres, 290 m²
# 2 chambres, 52 m²
# 3 chambres, 62 m²
# 3 chambres, 200 m²
# 10 chambres, 972 m²
# 14 chambres, 1350 m²
# 5 chambres, 897 m²
# 5 chambres, 914 m²
# 4 chambres, 187 m²
# 2 chambres, 110 m²
# 4 chambres, 700 m²
# 4 chambres, 423 m²
# 5 chambres, 509 m²
# 3 chambres, 116 m²
# 2 chambres, 142 m²
# 3 chambres, 280 m²
# 3 chambres, 110 m²
# 2 chambres, 113 m²
# 2 chambres, 109 m²
# 1 chambre, 55 m²
# 3 chambres, 120 m²
# 3 chambres, 173 m²
# 3 chambres, 222 m²
# 2 chambres, 79 m²
# 2 chambres, 128 m²
# 2 chambres, 128 m²
# 3 chambres, 92 m²
# 2 chambres, 80 m²
# 3 chambres, 101 m²
# 1 chambre, 63 m²
# 2 chambres, 115 m²
# 2 chambres, 75 m²
# 78 chambres, 4264 m²
# 5 chambres, 290 m²
# 2 chambres, 52 m²
# 3 chambres, 62 m²
# 3 chambres, 200 m²
# 10 chambres, 972 m²
# 14 chambres, 1350 m²
# 5 chambres, 897 m²
# 5 chambres, 914 m²
# 4 chambres, 187 m²
# 2 chambres, 110 m²
# 4 chambres, 700 m²
# 4 chambres, 423 m²
# 5 chambres, 509 m²
# 3 chambres, 116 m²
# 2 chambres, 142 m²
# 3 chambres, 280 m²
# 3 chambres, 110 m²
# 2 chambres, 113 m²
# 2 chambres, 109 m²
# 1 chambre, 55 m²
# 3 chambres, 120 m²
# 3 chambres, 173 m²
# 3 chambres, 222 m²
# 2 chambres, 79 m²
# 2 chambres, 128 m²
# 2 chambres, 128 m²
# 3 chambres, 92 m²
# 2 chambres, 80 m²
# 3 chambres, 101 m²
# 1 chambre, 63 m²
# 2 chambres, 115 m²
# 2 chambres, 75 m²
# 78 chambres, 4264 m²
# 5 chambres, 290 m²
# 2 chambres, 52 m²
# 3 chambres, 62 m²
# 3 chambres, 200 m²
# 10 chambres, 972 m²
# 14 chambres, 1350 m²
# 5 chambres, 897 m²
# 5 chambres, 914 m²
# 4 chambres, 187 m²
# 2 chambres, 110 m²
# 4 chambres, 700 m²
# 4 chambres, 423 m²
# 5 chambres, 509 m²
# 3 chambres, 116 m²
# 2 chambres, 142 m²
# 3 chambres, 280 m²
# 3 chambres, 110 m²
# 2 chambres, 113 m²
# 2 chambres, 109 m²
# 1 chambre, 55 m²
# 3 chambres, 120 m²
# 3 chambres, 173 m²
# 3 chambres, 222 m²
# 2 chambres, 79 m²
# 2 chambres, 128 m²
# 2 chambres, 128 m²
# 3 chambres, 92 m²
# 2 chambres, 80 m²
# 3 chambres, 101 m²
# 1 chambre, 63 m²
# 2 chambres, 115 m²
# 2 chambres, 75 m²
# 78 chambres, 4264 m²
# 5 chambres, 290 m²
# 2 chambres, 52 m²
# 3 chambres, 62 m²
# 3 chambres, 200 m²
# 10 chambres, 972 m²
# 14 chambres, 1350 m²
# 5 chambres, 897 m²
# 5 chambres, 914 m²
# 4 chambres, 187 m²
# 2 chambres, 110 m²
# 4 chambres, 700 m²
# 4 chambres, 423 m²
# 5 chambres, 509 m²
# 3 chambres, 116 m²
# 2 chambres, 142 m²
# 3 chambres, 280 m²
# 3 chambres, 110 m²
# 2 chambres, 113 m²
# 2 chambres, 109 m²
# 1 chambre, 55 m²
# 3 chambres, 120 m²
# 3 chambres, 173 m²
# 3 chambres, 222 m²
# 2 chambres, 79 m²
# 2 chambres, 128 m²
# 2 chambres, 128 m²
# 3 chambres, 92 m²
# 2 chambres, 80 m²
# 3 chambres, 101 m²
# 1 chambre, 63 m²
# 2 chambres, 115 m²
# 2 chambres, 75 m²
# 78 chambres, 4264 m²
# 5 chambres, 290 m²
# 2 chambres, 52 m²
# 3 chambres, 62 m²
# 3 chambres, 200 m²
# 10 chambres, 972 m²
# 14 chambres, 1350 m²
# 5 chambres, 897 m²
# 5 chambres, 914 m²
# 4 chambres, 187 m²
# 2 chambres, 110 m²
# 4 chambres, 700 m²
# 4 chambres, 423 m²
# 5 chambres, 509 m²
# 3 chambres, 116 m²
# 2 chambres, 142 m²
# 3 chambres, 280 m²
# 3 chambres, 110 m²
# 2 chambres, 113 m²
# 2 chambres, 109 m²
# 1 chambre, 55 m²
# 3 chambres, 120 m²
# 3 chambres, 173 m²
# 3 chambres, 222 m²
# 2 chambres, 79 m²
# 2 chambres, 128 m²
# 2 chambres, 128 m²
# 3 chambres, 92 m²
# 2 chambres, 80 m²
# 3 chambres, 101 m²
# 1 chambre, 63 m²
# 2 chambres, 115 m²
# 2 chambres, 75 m²
# 78 chambres, 4264 m²
# 5 chambres, 290 m²
# 2 chambres, 52 m²
# 3 chambres, 62 m²
# 3 chambres, 200 m²
# 10 chambres, 972 m²
# 14 chambres, 1350 m²
# 5 chambres, 897 m²
# 5 chambres, 914 m²
# 4 chambres, 187 m²
# 2 chambres, 110 m²
# 4 chambres, 700 m²
# 4 chambres, 423 m²
# 5 chambres, 509 m²
# 3 chambres, 116 m²
# 2 chambres, 142 m²
# 3 chambres, 280 m²
# 3 chambres, 110 m²
# 2 chambres, 113 m²
# 2 chambres, 109 m²
# 1 chambre, 55 m²
# 3 chambres, 120 m²
# 3 chambres, 173 m²
# 3 chambres, 222 m²
# 2 chambres, 79 m²
# 2 chambres, 128 m²
# 2 chambres, 128 m²
# 3 chambres, 92 m²
# 2 chambres, 80 m²
# 3 chambres, 101 m²
# 1 chambre, 63 m²
# 2 chambres, 115 m²
# 2 chambres, 75 m²
# 78 chambres, 4264 m²
# 5 chambres, 290 m²
# 2 chambres, 52 m²
# 3 chambres, 62 m²
# 3 chambres, 200 m²
# 10 chambres, 972 m²
# 14 chambres, 1350 m²
# 5 chambres, 897 m²
# 5 chambres, 914 m²
# 4 chambres, 187 m²
# 2 chambres, 110 m²
# 4 chambres, 700 m²
# 4 chambres, 423 m²
# 5 chambres, 509 m²
# 3 chambres, 116 m²
# 2 chambres, 142 m²
# 3 chambres, 280 m²
# 3 chambres, 110 m²
# 2 chambres, 113 m²
# 2 chambres, 109 m²
# 1 chambre, 55 m²
# 3 chambres, 120 m²
# 3 chambres, 173 m²
# 3 chambres, 222 m²
# 2 chambres, 79 m²
# 2 chambres, 128 m²
# 2 chambres, 128 m²
# 3 chambres, 92 m²
# 2 chambres, 80 m²
# 3 chambres, 101 m²
# 1 chambre, 63 m²
# 2 chambres, 115 m²
# 2 chambres, 75 m²
# 78 chambres, 4264 m²
# 5 chambres, 290 m²
# 2 chambres, 52 m²
# 3 chambres, 62 m²
# 3 chambres, 200 m²
# 10 chambres, 972 m²
# 14 chambres, 1350 m²
# 5 chambres, 897 m²
# 5 chambres, 914 m²
# 4 chambres, 187 m²
# 2 chambres, 110 m²
# 4 chambres, 700 m²
# 4 chambres, 423 m²
# 5 chambres, 509 m²
# 3 chambres, 116 m²
# 2 chambres, 142 m²
# 3 chambres, 280 m²
# 3 chambres, 110 m²
# 2 chambres, 113 m²
# 2 chambres, 109 m²
# 1 chambre, 55 m²
# 3 chambres, 120 m²
# 3 chambres, 173 m²
# 3 chambres, 222 m²
# 2 chambres, 79 m²
# 2 chambres, 128 m²
# 2 chambres, 128 m²
# 3 chambres, 92 m²
# 2 chambres, 80 m²
# 3 chambres, 101 m²
# 1 chambre, 63 m²
# 2 chambres, 115 m²
# 2 chambres, 75 m²
# 78 chambres, 4264 m²
# 5 chambres, 290 m²
# 2 chambres, 52 m²
# 3 chambres, 62 m²
# 3 chambres, 200 m²
# 10 chambres, 972 m²
# 14 chambres, 1350 m²
# 5 chambres, 897 m²
# 5 chambres, 914 m²
# 4 chambres, 187 m²
# 2 chambres, 110 m²
# 4 chambres, 700 m²
# 4 chambres, 423 m²
# 5 chambres, 509 m²
# 3 chambres, 116 m²
# 2 chambres, 142 m²
# 3 chambres, 280 m²
# 3 chambres, 110 m²
# 2 chambres, 113 m²
# 2 chambres, 109 m²
# 1 chambre, 55 m²
# 3 chambres, 120 m²
# 3 chambres, 173 m²
# 3 chambres, 222 m²
# 2 chambres, 79 m²
# 2 chambres, 128 m²
# 2 chambres, 128 m²
# 3 chambres, 92 m²
# 2 chambres, 80 m²
# 3 chambres, 101 m²
# 1 chambre, 63 m²
# 2 chambres, 115 m²
# 2 chambres, 75 m²
# 78 chambres, 4264 m²
# 5 chambres, 290 m²
# 2 chambres, 52 m²
# 3 chambres, 62 m²
# 3 chambres, 200 m²
# 10 chambres, 972 m²
# 14 chambres, 1350 m²
# 5 chambres, 897 m²
# 5 chambres, 914 m²
# 4 chambres, 187 m²
# 2 chambres, 110 m²
# 4 chambres, 700 m²
# 4 chambres, 423 m²
# 5 chambres, 509 m²
# 3 chambres, 116 m²
# 2 chambres, 142 m²
# 3 chambres, 280 m²
# 3 chambres, 110 m²
# 2 chambres, 113 m²
# 2 chambres, 109 m²
# 1 chambre, 55 m²
# 3 chambres, 120 m²
# 3 chambres, 173 m²
# 3 chambres, 222 m²
# 2 chambres, 79 m²
# 2 chambres, 128 m²
# 2 chambres, 128 m²
# 3 chambres, 92 m²
# 2 chambres, 80 m²
# 3 chambres, 101 m²
# 1 chambre, 63 m²
# 2 chambres, 115 m²
# 2 chambres, 75 m²
# 78 chambres, 4264 m²
# 5 chambres, 290 m²
# 2 chambres, 52 m²
# 3 chambres, 62 m²
# 3 chambres, 200 m²
# 10 chambres, 972 m²
# 14 chambres, 1350 m²
# 5 chambres, 897 m²
# 5 chambres, 914 m²
# 4 chambres, 187 m²
# 2 chambres, 110 m²
# 4 chambres, 700 m²
# 4 chambres, 423 m²
# 5 chambres, 509 m²
# 3 chambres, 116 m²
# 2 chambres, 142 m²
# 3 chambres, 280 m²
# 3 chambres, 110 m²
# 2 chambres, 113 m²
# 2 chambres, 109 m²
# 1 chambre, 55 m²
# 3 chambres, 120 m²
# 3 chambres, 173 m²
# 3 chambres, 222 m²
# 2 chambres, 79 m²
# 2 chambres, 128 m²
# 2 chambres, 128 m²
# 3 chambres, 92 m²
# 2 chambres, 80 m²
# 3 chambres, 101 m²
# 1 chambre, 63 m²
# 2 chambres, 115 m²
# 2 chambres, 75 m²
# 78 chambres, 4264 m²
# 5 chambres, 290 m²
# 2 chambres, 52 m²
# 3 chambres, 62 m²
# 3 chambres, 200 m²
# 10 chambres, 972 m²
# 14 chambres, 1350 m²
# 5 chambres, 897 m²
# 5 chambres, 914 m²
# 4 chambres, 187 m²
# 2 chambres, 110 m²
# 4 chambres, 700 m²
# 4 chambres, 423 m²
# 5 chambres, 509 m²
# 3 chambres, 116 m²
# 2 chambres, 142 m²
# 3 chambres, 280 m²
# 3 chambres, 110 m²
# 2 chambres, 113 m²
# 2 chambres, 109 m²
# 1 chambre, 55 m²
# 3 chambres, 120 m²
# 3 chambres, 173 m²
# 3 chambres, 222 m²
# 2 chambres, 79 m²
# 2 chambres, 128 m²
# 2 chambres, 128 m²
# 3 chambres, 92 m²
# 2 chambres, 80 m²
# 3 chambres, 101 m²
# 1 chambre, 63 m²
# 2 chambres, 115 m²
# 2 chambres, 75 m²
# 78 chambres, 4264 m²
# 5 chambres, 290 m²
# 2 chambres, 52 m²
# 3 chambres, 62 m²
# 3 chambres, 200 m²
# 10 chambres, 972 m²
# 14 chambres, 1350 m²
# 5 chambres, 897 m²
# 5 chambres, 914 m²
# 4 chambres, 187 m²
# 2 chambres, 110 m²
# 4 chambres, 700 m²
# 4 chambres, 423 m²
# 5 chambres, 509 m²
# 3 chambres, 116 m²
# 2 chambres, 142 m²
# 3 chambres, 280 m²
# 3 chambres, 110 m²
# 2 chambres, 113 m²
# 2 chambres, 109 m²
# 1 chambre, 55 m²
# 3 chambres, 120 m²
# 3 chambres, 173 m²
# 3 chambres, 222 m²
# 2 chambres, 79 m²
# 2 chambres, 128 m²
# 2 chambres, 128 m²
# 3 chambres, 92 m²
# 2 chambres, 80 m²
# 3 chambres, 101 m²
# 1 chambre, 63 m²
# 2 chambres, 115 m²
# 2 chambres, 75 m²
# 78 chambres, 4264 m²
# 5 chambres, 290 m²
# 2 chambres, 52 m²
# 3 chambres, 62 m²
# 3 chambres, 200 m²
# 10 chambres, 972 m²
# 14 chambres, 1350 m²
# 5 chambres, 897 m²
# 5 chambres, 914 m²
# 4 chambres, 187 m²
# 2 chambres, 110 m²
# 4 chambres, 700 m²
# 4 chambres, 423 m²
# 5 chambres, 509 m²
# 3 chambres, 116 m²
# 2 chambres, 142 m²
# 3 chambres, 280 m²
# 3 chambres, 110 m²
# 2 chambres, 113 m²
# 2 chambres, 109 m²
# 1 chambre, 55 m²
# 3 chambres, 120 m²
# 3 chambres, 173 m²
# 3 chambres, 222 m²
# 2 chambres, 79 m²
# 2 chambres, 128 m²
# 2 chambres, 128 m²
# 3 chambres, 92 m²
# 2 chambres, 80 m²
# 3 chambres, 101 m²
# 1 chambre, 63 m²
# 2 chambres, 115 m²
# 2 chambres, 75 m²
# 78 chambres, 4264 m²
# 5 chambres, 290 m²
# 2 chambres, 52 m²
# 3 chambres, 62 m²
# 3 chambres, 200 m²
# 10 chambres, 972 m²
# 14 chambres, 1350 m²
# 5 chambres, 897 m²
# 5 chambres, 914 m²
# 4 chambres, 187 m²
# 2 chambres, 110 m²
# 4 chambres, 700 m²
# 4 chambres, 423 m²
# 5 chambres, 509 m²
# 3 chambres, 188 m²
# 3 chambres, 200 m²
# 3 chambres, 156 m²
# 3 chambres, 163 m²
# 3 chambres, 138 m²
# 3 chambres, 174 m²
# 245 m²
# 247 m²
# 3 chambres, 358 m²
# 3 chambres, 180 m²
# 3 chambres, 267 m²
# 3 chambres, 173 m²
# 3 chambres, 358 m²
# 3 chambres, 318 m²
# 2 chambres, 126 m²
# 3 chambres, 173 m²
# 3 chambres, 171 m²
# 4 chambres, 221 m²
# 2 chambres, 147 m²
# 3 chambres, 150 m²
# 3 chambres, 143 m²
# 4 chambres, 399 m²
# 4 chambres, 167 m²
# 4 chambres, 460 m²
# 4 chambres, 181 m²
# 3 chambres, 238 m²
# 4 chambres, 181 m²
# 3 chambres, 180 m²
# 3 chambres, 237 m²
# 3 chambres
# 3 chambres, 167 m²
# 3 chambres, 153 m²
# 4 chambres, 217 m²
# 3 chambres, 188 m²
# 3 chambres, 200 m²
# 3 chambres, 156 m²
# 3 chambres, 163 m²
# 3 chambres, 138 m²
# 3 chambres, 174 m²
# 245 m²
# 247 m²
# 3 chambres, 358 m²
# 3 chambres, 180 m²
# 3 chambres, 267 m²
# 3 chambres, 173 m²
# 3 chambres, 358 m²
# 3 chambres, 318 m²
# 2 chambres, 126 m²
# 3 chambres, 173 m²
# 3 chambres, 171 m²
# 4 chambres, 221 m²
# 2 chambres, 147 m²
# 3 chambres, 150 m²
# 3 chambres, 143 m²
# 4 chambres, 399 m²
# 4 chambres, 167 m²
# 4 chambres, 460 m²
# 4 chambres, 181 m²
# 3 chambres, 238 m²
# 4 chambres, 181 m²
# 3 chambres, 180 m²
# 3 chambres, 237 m²
# 3 chambres
# 3 chambres, 167 m²
# 3 chambres, 153 m²
# 4 chambres, 217 m²
# 3 chambres, 188 m²
# 3 chambres, 200 m²
# 3 chambres, 156 m²
# 3 chambres, 163 m²
# 3 chambres, 138 m²
# 3 chambres, 174 m²
# 245 m²
# 247 m²
# 3 chambres, 358 m²
# 3 chambres, 180 m²
# 3 chambres, 267 m²
# 3 chambres, 173 m²
# 3 chambres, 358 m²
# 3 chambres, 318 m²
# 2 chambres, 126 m²
# 3 chambres, 173 m²
# 3 chambres, 171 m²
# 4 chambres, 221 m²
# 2 chambres, 147 m²
# 3 chambres, 150 m²
# 3 chambres, 143 m²
# 4 chambres, 399 m²
# 4 chambres, 167 m²
# 4 chambres, 460 m²
# 4 chambres, 181 m²
# 3 chambres, 238 m²
# 4 chambres, 181 m²
# 3 chambres, 180 m²
# 3 chambres, 237 m²
# 3 chambres
# 3 chambres, 167 m²
# 3 chambres, 153 m²
# 4 chambres, 217 m²
# 3 chambres, 188 m²
# 3 chambres, 200 m²
# 3 chambres, 156 m²
# 3 chambres, 163 m²
# 3 chambres, 138 m²
# 3 chambres, 174 m²
# 245 m²
# 247 m²
# 3 chambres, 358 m²
# 3 chambres, 180 m²
# 3 chambres, 267 m²
# 3 chambres, 173 m²
# 3 chambres, 358 m²
# 3 chambres, 318 m²
# 2 chambres, 126 m²
# 3 chambres, 173 m²
# 3 chambres, 171 m²
# 4 chambres, 221 m²
# 2 chambres, 147 m²
# 3 chambres, 150 m²
# 3 chambres, 143 m²
# 4 chambres, 399 m²
# 4 chambres, 167 m²
# 4 chambres, 460 m²
# 4 chambres, 181 m²
# 3 chambres, 238 m²
# 4 chambres, 181 m²
# 3 chambres, 180 m²
# 3 chambres, 237 m²
# 3 chambres
# 3 chambres, 167 m²
# 3 chambres, 153 m²
# 4 chambres, 217 m²
# 3 chambres, 188 m²
# 3 chambres, 200 m²
# 3 chambres, 156 m²
# 3 chambres, 163 m²
# 3 chambres, 138 m²
# 3 chambres, 174 m²
# 245 m²
# 247 m²
# 3 chambres, 358 m²
# 3 chambres, 180 m²
# 3 chambres, 267 m²
# 3 chambres, 173 m²
# 3 chambres, 358 m²
# 3 chambres, 318 m²
# 2 chambres, 126 m²
# 3 chambres, 173 m²
# 3 chambres, 171 m²
# 4 chambres, 221 m²
# 2 chambres, 147 m²
# 3 chambres, 150 m²
# 3 chambres, 143 m²
# 4 chambres, 399 m²
# 4 chambres, 167 m²
# 4 chambres, 460 m²
# 4 chambres, 181 m²
# 3 chambres, 238 m²
# 4 chambres, 181 m²
# 3 chambres, 180 m²
# 3 chambres, 237 m²
# 3 chambres
# 3 chambres, 167 m²
# 3 chambres, 153 m²
# 4 chambres, 217 m²
# 3 chambres, 188 m²
# 3 chambres, 200 m²
# 3 chambres, 156 m²
# 3 chambres, 163 m²
# 3 chambres, 138 m²
# 3 chambres, 174 m²
# 245 m²
# 247 m²
# 3 chambres, 358 m²
# 3 chambres, 180 m²
# 3 chambres, 267 m²
# 3 chambres, 173 m²
# 3 chambres, 358 m²
# 3 chambres, 318 m²
# 2 chambres, 126 m²
# 3 chambres, 173 m²
# 3 chambres, 171 m²
# 4 chambres, 221 m²
# 2 chambres, 147 m²
# 3 chambres, 150 m²
# 3 chambres, 143 m²
# 4 chambres, 399 m²
# 4 chambres, 167 m²
# 4 chambres, 460 m²
# 4 chambres, 181 m²
# 3 chambres, 238 m²
# 4 chambres, 181 m²
# 3 chambres, 180 m²
# 3 chambres, 237 m²
# 3 chambres
# 3 chambres, 167 m²
# 3 chambres, 153 m²
# 4 chambres, 217 m²
# 3 chambres, 188 m²
# 3 chambres, 200 m²
# 3 chambres, 156 m²
# 3 chambres, 163 m²
# 3 chambres, 138 m²
# 3 chambres, 174 m²
# 245 m²
# 247 m²
# 3 chambres, 358 m²
# 3 chambres, 180 m²
# 3 chambres, 267 m²
# 3 chambres, 173 m²
# 3 chambres, 358 m²
# 3 chambres, 318 m²
# 2 chambres, 126 m²
# 3 chambres, 173 m²
# 3 chambres, 171 m²
# 4 chambres, 221 m²
# 2 chambres, 147 m²
# 3 chambres, 150 m²
# 3 chambres, 143 m²
# 4 chambres, 399 m²
# 4 chambres, 167 m²
# 4 chambres, 460 m²
# 4 chambres, 181 m²
# 3 chambres, 238 m²
# 4 chambres, 181 m²
# 3 chambres, 180 m²
# 3 chambres, 237 m²
# 3 chambres
# 3 chambres, 167 m²
# 3 chambres, 153 m²
# 4 chambres, 217 m²
# 3 chambres, 188 m²
# 3 chambres, 200 m²
# 3 chambres, 156 m²
# 3 chambres, 163 m²
# 3 chambres, 138 m²
# 3 chambres, 174 m²
# 245 m²
# 247 m²
# 3 chambres, 358 m²
# 3 chambres, 180 m²
# 3 chambres, 267 m²
# 3 chambres, 173 m²
# 3 chambres, 358 m²
# 3 chambres, 318 m²
# 2 chambres, 126 m²
# 3 chambres, 173 m²
# 3 chambres, 171 m²
# 4 chambres, 221 m²
# 2 chambres, 147 m²
# 3 chambres, 150 m²
# 3 chambres, 143 m²
# 4 chambres, 399 m²
# 4 chambres, 167 m²
# 4 chambres, 460 m²
# 4 chambres, 181 m²
# 3 chambres, 238 m²
# 4 chambres, 181 m²
# 3 chambres, 180 m²
# 3 chambres, 237 m²
# 3 chambres
# 3 chambres, 167 m²
# 3 chambres, 153 m²
# 4 chambres, 217 m²
# 3 chambres, 188 m²
# 3 chambres, 200 m²
# 3 chambres, 156 m²
# 3 chambres, 163 m²
# 3 chambres, 138 m²
# 3 chambres, 174 m²
# 245 m²
# 247 m²
# 3 chambres, 358 m²
# 3 chambres, 180 m²
# 3 chambres, 267 m²
# 3 chambres, 173 m²
# 3 chambres, 358 m²
# 3 chambres, 318 m²
# 2 chambres, 126 m²
# 3 chambres, 173 m²
# 3 chambres, 171 m²
# 4 chambres, 221 m²
# 2 chambres, 147 m²
# 3 chambres, 150 m²
# 3 chambres, 143 m²
# 4 chambres, 399 m²
# 4 chambres, 167 m²
# 4 chambres, 460 m²
# 4 chambres, 181 m²
# 3 chambres, 238 m²
# 4 chambres, 181 m²
# 3 chambres, 180 m²
# 3 chambres, 237 m²
# 3 chambres
# 3 chambres, 167 m²
# 3 chambres, 153 m²
# 4 chambres, 217 m²
# 3 chambres, 188 m²
# 3 chambres, 200 m²
# 3 chambres, 156 m²
# 3 chambres, 163 m²
# 3 chambres, 138 m²
# 3 chambres, 174 m²
# 245 m²
# 247 m²
# 3 chambres, 358 m²
# 3 chambres, 180 m²
# 3 chambres, 267 m²
# 3 chambres, 173 m²
# 3 chambres, 358 m²
# 3 chambres, 318 m²
# 2 chambres, 126 m²
# 3 chambres, 173 m²
# 3 chambres, 171 m²
# 4 chambres, 221 m²
# 2 chambres, 147 m²
# 3 chambres, 150 m²
# 3 chambres, 143 m²
# 4 chambres, 399 m²
# 4 chambres, 167 m²
# 4 chambres, 460 m²
# 4 chambres, 181 m²
# 3 chambres, 238 m²
# 4 chambres, 181 m²
# 3 chambres, 180 m²
# 3 chambres, 237 m²
# 3 chambres
# 3 chambres, 167 m²
# 3 chambres, 153 m²
# 4 chambres, 217 m²
# 3 chambres, 188 m²
# 3 chambres, 200 m²
# 3 chambres, 156 m²
# 3 chambres, 163 m²
# 3 chambres, 138 m²
# 3 chambres, 174 m²
# 245 m²
# 247 m²
# 3 chambres, 358 m²
# 3 chambres, 180 m²
# 3 chambres, 267 m²
# 3 chambres, 173 m²
# 3 chambres, 358 m²
# 3 chambres, 318 m²
# 2 chambres, 126 m²
# 3 chambres, 173 m²
# 3 chambres, 171 m²
# 4 chambres, 221 m²
# 2 chambres, 147 m²
# 3 chambres, 150 m²
# 3 chambres, 143 m²
# 4 chambres, 399 m²
# 4 chambres, 167 m²
# 4 chambres, 460 m²
# 4 chambres, 181 m²
# 3 chambres, 238 m²
# 4 chambres, 181 m²
# 3 chambres, 180 m²
# 3 chambres, 237 m²
# 3 chambres
# 3 chambres, 167 m²
# 3 chambres, 153 m²
# 4 chambres, 217 m²
# 3 chambres, 188 m²
# 3 chambres, 200 m²
# 3 chambres, 156 m²
# 3 chambres, 163 m²
# 3 chambres, 138 m²
# 3 chambres, 174 m²
# 245 m²
# 247 m²
# 3 chambres, 358 m²
# 3 chambres, 180 m²
# 3 chambres, 267 m²
# 3 chambres, 173 m²
# 3 chambres, 358 m²
# 3 chambres, 318 m²
# 2 chambres, 126 m²
# 3 chambres, 173 m²
# 3 chambres, 171 m²
# 4 chambres, 221 m²
# 2 chambres, 147 m²
# 3 chambres, 150 m²
# 3 chambres, 143 m²
# 4 chambres, 399 m²
# 4 chambres, 167 m²
# 4 chambres, 460 m²
# 4 chambres, 181 m²
# 3 chambres, 238 m²
# 4 chambres, 181 m²
# 3 chambres, 180 m²
# 3 chambres, 237 m²
# 3 chambres
# 3 chambres, 167 m²
# 3 chambres, 153 m²
# 4 chambres, 217 m²
# 3 chambres, 188 m²
# 3 chambres, 200 m²
# 3 chambres, 156 m²
# 3 chambres, 163 m²
# 3 chambres, 138 m²
# 3 chambres, 174 m²
# 245 m²
# 247 m²
# 3 chambres, 358 m²
# 3 chambres, 180 m²
# 3 chambres, 267 m²
# 3 chambres, 173 m²
# 3 chambres, 358 m²
# 3 chambres, 318 m²
# 2 chambres, 126 m²
# 3 chambres, 173 m²
# 3 chambres, 171 m²
# 4 chambres, 221 m²
# 2 chambres, 147 m²
# 3 chambres, 150 m²
# 3 chambres, 143 m²
# 4 chambres, 399 m²
# 4 chambres, 167 m²
# 4 chambres, 460 m²
# 4 chambres, 181 m²
# 3 chambres, 238 m²
# 4 chambres, 181 m²
# 3 chambres, 180 m²
# 3 chambres, 237 m²
# 3 chambres
# 3 chambres, 167 m²
# 3 chambres, 153 m²
# 4 chambres, 217 m²
# 3 chambres, 188 m²
# 3 chambres, 200 m²
# 3 chambres, 156 m²
# 3 chambres, 163 m²
# 3 chambres, 138 m²
# 3 chambres, 174 m²
# 245 m²
# 247 m²
# 3 chambres, 358 m²
# 3 chambres, 180 m²
# 3 chambres, 267 m²
# 3 chambres, 173 m²
# 3 chambres, 358 m²
# 3 chambres, 318 m²
# 2 chambres, 126 m²
# 3 chambres, 173 m²
# 3 chambres, 171 m²
# 4 chambres, 221 m²
# 2 chambres, 147 m²
# 3 chambres, 150 m²
# 3 chambres, 143 m²
# 4 chambres, 399 m²
# 4 chambres, 167 m²
# 4 chambres, 460 m²
# 4 chambres, 181 m²
# 3 chambres, 238 m²
# 4 chambres, 181 m²
# 3 chambres, 180 m²
# 3 chambres, 237 m²
# 3 chambres
# 3 chambres, 167 m²
# 3 chambres, 153 m²
# 4 chambres, 217 m²
# 3 chambres, 188 m²
# 3 chambres, 200 m²
# 3 chambres, 156 m²
# 3 chambres, 163 m²
# 3 chambres, 138 m²
# 3 chambres, 174 m²
# 245 m²
# 247 m²
# 3 chambres, 358 m²
# 3 chambres, 180 m²
# 3 chambres, 267 m²
# 3 chambres, 173 m²
# 3 chambres, 358 m²
# 3 chambres, 318 m²
# 2 chambres, 126 m²
# 3 chambres, 173 m²
# 3 chambres, 171 m²
# 4 chambres, 221 m²
# 2 chambres, 147 m²
# 3 chambres, 150 m²
# 3 chambres, 143 m²
# 4 chambres, 399 m²
# 4 chambres, 167 m²
# 4 chambres, 460 m²
# 4 chambres, 181 m²
# 3 chambres, 238 m²
# 4 chambres, 181 m²
# 3 chambres, 180 m²
# 3 chambres, 237 m²
# 3 chambres
# 3 chambres, 167 m²
# 3 chambres, 153 m²
# 4 chambres, 217 m²
# 3 chambres, 188 m²
# 3 chambres, 200 m²
# 3 chambres, 156 m²
# 3 chambres, 163 m²
# 3 chambres, 138 m²
# 3 chambres, 174 m²
# 245 m²
# 247 m²
# 3 chambres, 358 m²
# 3 chambres, 180 m²
# 3 chambres, 267 m²
# 3 chambres, 173 m²
# 3 chambres, 358 m²
# 3 chambres, 318 m²
# 2 chambres, 126 m²
# 3 chambres, 173 m²
# 3 chambres, 171 m²
# 4 chambres, 221 m²
# 2 chambres, 147 m²
# 3 chambres, 150 m²
# 3 chambres, 143 m²
# 4 chambres, 399 m²
# 4 chambres, 167 m²
# 4 chambres, 460 m²
# 4 chambres, 181 m²
# 3 chambres, 238 m²
# 4 chambres, 181 m²
# 3 chambres, 180 m²
# 3 chambres, 237 m²
# 3 chambres
# 3 chambres, 167 m²
# 3 chambres, 153 m²
# 4 chambres, 217 m²
# 3 chambres, 188 m²
# 3 chambres, 200 m²
# 3 chambres, 156 m²
# 3 chambres, 163 m²
# 3 chambres, 138 m²
# 3 chambres, 174 m²
# 245 m²
# 247 m²
# 3 chambres, 358 m²
# 3 chambres, 180 m²
# 3 chambres, 267 m²
# 3 chambres, 173 m²
# 3 chambres, 358 m²
# 3 chambres, 318 m²
# 2 chambres, 126 m²
# 3 chambres, 173 m²
# 3 chambres, 171 m²
# 4 chambres, 221 m²
# 2 chambres, 147 m²
# 3 chambres, 150 m²
# 3 chambres, 143 m²
# 4 chambres, 399 m²
# 4 chambres, 167 m²
# 4 chambres, 460 m²
# 4 chambres, 181 m²
# 3 chambres, 238 m²
# 4 chambres, 181 m²
# 3 chambres, 180 m²
# 3 chambres, 237 m²
# 3 chambres
# 3 chambres, 167 m²
# 3 chambres, 153 m²
# 4 chambres, 217 m²

# %%
def extract_bedrooms_area(info_str):
    # Use regular expression to extract the number of bedrooms and area
    match = re.search(r'(\d+)?\s*chambres,\s*(\d+)?\s*m²', info_str)

    # Extract bedrooms and area or return None for missing values
    bedrooms = match.group(1) if match and match.group(1) else None
    area = match.group(2) if match and match.group(2) else None

    return bedrooms, area
bedrooms_list, area_list = zip(*[extract_bedrooms_area(info) for info in total_rooms])

# %%
area_list
# Out:
# ('116',
#  '142',
#  '280',
#  '110',
#  '113',
#  '109',
#  None,
#  '120',
#  '173',
#  '222',
#  '79',
#  '128',
#  '128',
#  '92',
#  '80',
#  '101',
#  None,
#  '115',
#  '75',
#  '4264',
#  '290',
#  '52',
#  '62',
#  '200',
#  '972',
#  '1350',
#  '897',
#  '914',
#  '187',
#  '110',
#  '700',
#  '423',
#  '509',
#  '116',
#  '142',
#  '280',
#  '110',
#  '113',
#  '109',
#  None,
#  '120',
#  '173',
#  '222',
#  '79',
#  '128',
#  '128',
#  '92',
#  '80',
#  '101',
#  None,
#  '115',
#  '75',
#  '4264',
#  '290',
#  '52',
#  '62',
#  '200',
#  '972',
#  '1350',
#  '897',
#  '914',
#  '187',
#  '110',
#  '700',
#  '423',
#  '509',
#  '116',
#  '142',
#  '280',
#  '110',
#  '113',
#  '109',
#  None,
#  '120',
#  '173',
#  '222',
#  '79',
#  '128',
#  '128',
#  '92',
#  '80',
#  '101',
#  None,
#  '115',
#  '75',
#  '4264',
#  '290',
#  '52',
#  '62',
#  '200',
#  '972',
#  '1350',
#  '897',
#  '914',
#  '187',
#  '110',
#  '700',
#  '423',
#  '509',
#  '116',
#  '142',
#  '280',
#  '110',
#  '113',
#  '109',
#  None,
#  '120',
#  '173',
#  '222',
#  '79',
#  '128',
#  '128',
#  '92',
#  '80',
#  '101',
#  None,
#  '115',
#  '75',
#  '4264',
#  '290',
#  '52',
#  '62',
#  '200',
#  '972',
#  '1350',
#  '897',
#  '914',
#  '187',
#  '110',
#  '700',
#  '423',
#  '509',
#  '116',
#  '142',
#  '280',
#  '110',
#  '113',
#  '109',
#  None,
#  '120',
#  '173',
#  '222',
#  '79',
#  '128',
#  '128',
#  '92',
#  '80',
#  '101',
#  None,
#  '115',
#  '75',
#  '4264',
#  '290',
#  '52',
#  '62',
#  '200',
#  '972',
#  '1350',
#  '897',
#  '914',
#  '187',
#  '110',
#  '700',
#  '423',
#  '509',
#  '116',
#  '142',
#  '280',
#  '110',
#  '113',
#  '109',
#  None,
#  '120',
#  '173',
#  '222',
#  '79',
#  '128',
#  '128',
#  '92',
#  '80',
#  '101',
#  None,
#  '115',
#  '75',
#  '4264',
#  '290',
#  '52',
#  '62',
#  '200',
#  '972',
#  '1350',
#  '897',
#  '914',
#  '187',
#  '110',
#  '700',
#  '423',
#  '509',
#  '116',
#  '142',
#  '280',
#  '110',
#  '113',
#  '109',
#  None,
#  '120',
#  '173',
#  '222',
#  '79',
#  '128',
#  '128',
#  '92',
#  '80',
#  '101',
#  None,
#  '115',
#  '75',
#  '4264',
#  '290',
#  '52',
#  '62',
#  '200',
#  '972',
#  '1350',
#  '897',
#  '914',
#  '187',
#  '110',
#  '700',
#  '423',
#  '509',
#  '116',
#  '142',
#  '280',
#  '110',
#  '113',
#  '109',
#  None,
#  '120',
#  '173',
#  '222',
#  '79',
#  '128',
#  '128',
#  '92',
#  '80',
#  '101',
#  None,
#  '115',
#  '75',
#  '4264',
#  '290',
#  '52',
#  '62',
#  '200',
#  '972',
#  '1350',
#  '897',
#  '914',
#  '187',
#  '110',
#  '700',
#  '423',
#  '509',
#  '116',
#  '142',
#  '280',
#  '110',
#  '113',
#  '109',
#  None,
#  '120',
#  '173',
#  '222',
#  '79',
#  '128',
#  '128',
#  '92',
#  '80',
#  '101',
#  None,
#  '115',
#  '75',
#  '4264',
#  '290',
#  '52',
#  '62',
#  '200',
#  '972',
#  '1350',
#  '897',
#  '914',
#  '187',
#  '110',
#  '700',
#  '423',
#  '509',
#  '116',
#  '142',
#  '280',
#  '110',
#  '113',
#  '109',
#  None,
#  '120',
#  '173',
#  '222',
#  '79',
#  '128',
#  '128',
#  '92',
#  '80',
#  '101',
#  None,
#  '115',
#  '75',
#  '4264',
#  '290',
#  '52',
#  '62',
#  '200',
#  '972',
#  '1350',
#  '897',
#  '914',
#  '187',
#  '110',
#  '700',
#  '423',
#  '509',
#  '116',
#  '142',
#  '280',
#  '110',
#  '113',
#  '109',
#  None,
#  '120',
#  '173',
#  '222',
#  '79',
#  '128',
#  '128',
#  '92',
#  '80',
#  '101',
#  None,
#  '115',
#  '75',
#  '4264',
#  '290',
#  '52',
#  '62',
#  '200',
#  '972',
#  '1350',
#  '897',
#  '914',
#  '187',
#  '110',
#  '700',
#  '423',
#  '509',
#  '116',
#  '142',
#  '280',
#  '110',
#  '113',
#  '109',
#  None,
#  '120',
#  '173',
#  '222',
#  '79',
#  '128',
#  '128',
#  '92',
#  '80',
#  '101',
#  None,
#  '115',
#  '75',
#  '4264',
#  '290',
#  '52',
#  '62',
#  '200',
#  '972',
#  '1350',
#  '897',
#  '914',
#  '187',
#  '110',
#  '700',
#  '423',
#  '509',
#  '116',
#  '142',
#  '280',
#  '110',
#  '113',
#  '109',
#  None,
#  '120',
#  '173',
#  '222',
#  '79',
#  '128',
#  '128',
#  '92',
#  '80',
#  '101',
#  None,
#  '115',
#  '75',
#  '4264',
#  '290',
#  '52',
#  '62',
#  '200',
#  '972',
#  '1350',
#  '897',
#  '914',
#  '187',
#  '110',
#  '700',
#  '423',
#  '509',
#  '116',
#  '142',
#  '280',
#  '110',
#  '113',
#  '109',
#  None,
#  '120',
#  '173',
#  '222',
#  '79',
#  '128',
#  '128',
#  '92',
#  '80',
#  '101',
#  None,
#  '115',
#  '75',
#  '4264',
#  '290',
#  '52',
#  '62',
#  '200',
#  '972',
#  '1350',
#  '897',
#  '914',
#  '187',
#  '110',
#  '700',
#  '423',
#  '509',
#  '116',
#  '142',
#  '280',
#  '110',
#  '113',
#  '109',
#  None,
#  '120',
#  '173',
#  '222',
#  '79',
#  '128',
#  '128',
#  '92',
#  '80',
#  '101',
#  None,
#  '115',
#  '75',
#  '4264',
#  '290',
#  '52',
#  '62',
#  '200',
#  '972',
#  '1350',
#  '897',
#  '914',
#  '187',
#  '110',
#  '700',
#  '423',
#  '509',
#  '116',
#  '142',
#  '280',
#  '110',
#  '113',
#  '109',
#  None,
#  '120',
#  '173',
#  '222',
#  '79',
#  '128',
#  '128',
#  '92',
#  '80',
#  '101',
#  None,
#  '115',
#  '75',
#  '4264',
#  '290',
#  '52',
#  '62',
#  '200',
#  '972',
#  '1350',
#  '897',
#  '914',
#  '187',
#  '110',
#  '700',
#  '423',
#  '509',
#  '116',
#  '142',
#  '280',
#  '110',
#  '113',
#  '109',
#  None,
#  '120',
#  '173',
#  '222',
#  '79',
#  '128',
#  '128',
#  '92',
#  '80',
#  '101',
#  None,
#  '115',
#  '75',
#  '4264',
#  '290',
#  '52',
#  '62',
#  '200',
#  '972',
#  '1350',
#  '897',
#  '914',
#  '187',
#  '110',
#  '700',
#  '423',
#  '509',
#  '116',
#  '142',
#  '280',
#  '110',
#  '113',
#  '109',
#  None,
#  '120',
#  '173',
#  '222',
#  '79',
#  '128',
#  '128',
#  '92',
#  '80',
#  '101',
#  None,
#  '115',
#  '75',
#  '4264',
#  '290',
#  '52',
#  '62',
#  '200',
#  '972',
#  '1350',
#  '897',
#  '914',
#  '187',
#  '110',
#  '700',
#  '423',
#  '509',
#  '188',
#  '200',
#  '156',
#  '163',
#  '138',
#  '174',
#  None,
#  None,
#  '358',
#  '180',
#  '267',
#  '173',
#  '358',
#  '318',
#  '126',
#  '173',
#  '171',
#  '221',
#  '147',
#  '150',
#  '143',
#  '399',
#  '167',
#  '460',
#  '181',
#  '238',
#  '181',
#  '180',
#  '237',
#  None,
#  '167',
#  '153',
#  '217',
#  '188',
#  '200',
#  '156',
#  '163',
#  '138',
#  '174',
#  None,
#  None,
#  '358',
#  '180',
#  '267',
#  '173',
#  '358',
#  '318',
#  '126',
#  '173',
#  '171',
#  '221',
#  '147',
#  '150',
#  '143',
#  '399',
#  '167',
#  '460',
#  '181',
#  '238',
#  '181',
#  '180',
#  '237',
#  None,
#  '167',
#  '153',
#  '217',
#  '188',
#  '200',
#  '156',
#  '163',
#  '138',
#  '174',
#  None,
#  None,
#  '358',
#  '180',
#  '267',
#  '173',
#  '358',
#  '318',
#  '126',
#  '173',
#  '171',
#  '221',
#  '147',
#  '150',
#  '143',
#  '399',
#  '167',
#  '460',
#  '181',
#  '238',
#  '181',
#  '180',
#  '237',
#  None,
#  '167',
#  '153',
#  '217',
#  '188',
#  '200',
#  '156',
#  '163',
#  '138',
#  '174',
#  None,
#  None,
#  '358',
#  '180',
#  '267',
#  '173',
#  '358',
#  '318',
#  '126',
#  '173',
#  '171',
#  '221',
#  '147',
#  '150',
#  '143',
#  '399',
#  '167',
#  '460',
#  '181',
#  '238',
#  '181',
#  '180',
#  '237',
#  None,
#  '167',
#  '153',
#  '217',
#  '188',
#  '200',
#  '156',
#  '163',
#  '138',
#  '174',
#  None,
#  None,
#  '358',
#  '180',
#  '267',
#  '173',
#  '358',
#  '318',
#  '126',
#  '173',
#  '171',
#  '221',
#  '147',
#  '150',
#  '143',
#  '399',
#  '167',
#  '460',
#  '181',
#  '238',
#  '181',
#  '180',
#  '237',
#  None,
#  '167',
#  '153',
#  '217',
#  '188',
#  '200',
#  '156',
#  '163',
#  '138',
#  '174',
#  None,
#  None,
#  '358',
#  '180',
#  '267',
#  '173',
#  '358',
#  '318',
#  '126',
#  '173',
#  '171',
#  '221',
#  '147',
#  '150',
#  '143',
#  '399',
#  '167',
#  '460',
#  '181',
#  '238',
#  '181',
#  '180',
#  '237',
#  None,
#  '167',
#  '153',
#  '217',
#  '188',
#  '200',
#  '156',
#  '163',
#  '138',
#  '174',
#  None,
#  None,
#  '358',
#  '180',
#  '267',
#  '173',
#  '358',
#  '318',
#  '126',
#  '173',
#  '171',
#  '221',
#  '147',
#  '150',
#  '143',
#  '399',
#  '167',
#  '460',
#  '181',
#  '238',
#  '181',
#  '180',
#  '237',
#  None,
#  '167',
#  '153',
#  '217',
#  '188',
#  '200',
#  '156',
#  '163',
#  '138',
#  '174',
#  None,
#  None,
#  '358',
#  '180',
#  '267',
#  '173',
#  '358',
#  '318',
#  '126',
#  '173',
#  '171',
#  '221',
#  '147',
#  '150',
#  '143',
#  '399',
#  '167',
#  '460',
#  '181',
#  '238',
#  '181',
#  '180',
#  '237',
#  None,
#  '167',
#  '153',
#  '217',
#  '188',
#  '200',
#  '156',
#  '163',
#  '138',
#  '174',
#  None,
#  None,
#  '358',
#  '180',
#  '267',
#  '173',
#  '358',
#  '318',
#  '126',
#  '173',
#  '171',
#  '221',
#  '147',
#  '150',
#  '143',
#  '399',
#  '167',
#  '460',
#  '181',
#  '238',
#  '181',
#  '180',
#  '237',
#  None,
#  '167',
#  '153',
#  '217',
#  '188',
#  '200',
#  '156',
#  '163',
#  '138',
#  '174',
#  None,
#  None,
#  '358',
#  '180',
#  '267',
#  '173',
#  '358',
#  '318',
#  '126',
#  '173',
#  '171',
#  '221',
#  '147',
#  '150',
#  '143',
#  '399',
#  '167',
#  '460',
#  '181',
#  '238',
#  '181',
#  '180',
#  '237',
#  None,
#  '167',
#  '153',
#  '217',
#  '188',
#  '200',
#  '156',
#  '163',
#  '138',
#  '174',
#  None,
#  None,
#  '358',
#  '180',
#  '267',
#  '173',
#  '358',
#  '318',
#  '126',
#  '173',
#  '171',
#  '221',
#  '147',
#  '150',
#  '143',
#  '399',
#  '167',
#  '460',
#  '181',
#  '238',
#  '181',
#  '180',
#  '237',
#  None,
#  '167',
#  '153',
#  '217',
#  '188',
#  '200',
#  '156',
#  '163',
#  '138',
#  '174',
#  None,
#  None,
#  '358',
#  '180',
#  '267',
#  '173',
#  '358',
#  '318',
#  '126',
#  '173',
#  '171',
#  '221',
#  '147',
#  '150',
#  '143',
#  '399',
#  '167',
#  '460',
#  '181',
#  '238',
#  '181',
#  '180',
#  '237',
#  None,
#  '167',
#  '153',
#  '217',
#  '188',
#  '200',
#  '156',
#  '163',
#  '138',
#  '174',
#  None,
#  None,
#  '358',
#  '180',
#  ...)

# %%
import re
# Function to extract numerical values from the price string
def extract_numerical_value(price_str):
    # Use regular expression to extract digits and convert to an integer
    match = re.search(r'\d+', price_str)
    return int(match.group()) if match else None

# Extract numerical values from prices
numeric_prices = [extract_numerical_value(price) for price in prices]

# %%
# Function to extract numeric values from the num_rooms string
def extract_numeric_rooms(num_rooms_str):
    if isinstance(num_rooms_str, str):
        # Use regular expression to extract digits and convert to an integer
        match = re.search(r'\d+', num_rooms_str)
        return int(match.group()) if match else None
    else:
        return None


# Extract numeric values from num_rooms
numeric_rooms = [extract_numeric_rooms(room) for room in bedrooms_list]

# %%
# Function to extract numeric values from the area string
def extract_numeric_area(area_str):
    if isinstance(area_str, str):
        # Use regular expression to extract digits and convert to an integer
        match = re.search(r'\d+', area_str)
        return int(match.group()) if match else None
    else:
        return None

# Extract numeric values from area
numeric_area = [extract_numeric_area(a) for a in area_list]

# %%
print(numeric_area[98])
print(len(location))
print(len(numeric_rooms))
print(len(numeric_area))
print(len(numeric_prices))
# Out:
# 509
# 1155
# 1155
# 1155
# 1155

# %%
import pandas as pd
data = {
    'Location' : location,
    'Num_rooms' : numeric_rooms,
    'House_area(m²)' : numeric_area,
    'Price(DH)' : numeric_prices,
}
housing = pd.DataFrame(data)

# %%
sorted_housing = housing.sort_values(by='Price(DH)', ascending = False)
sorted_housing
# Out:
#                                  Location  Num_rooms  House_area(m²)  \
# 0        Oulfa à\n   \t\t\t\t\tCasablanca        3.0           116.0
# 396      Oulfa à\n   \t\t\t\t\tCasablanca        3.0           116.0
# 528      Oulfa à\n   \t\t\t\t\tCasablanca        3.0           116.0
# 66       Oulfa à\n   \t\t\t\t\tCasablanca        3.0           116.0
# 495      Oulfa à\n   \t\t\t\t\tCasablanca        3.0           116.0
# ...                                   ...        ...             ...
# 774     Maârif à\n   \t\t\t\t\tCasablanca        3.0           173.0
# 773       Anfa à\n   \t\t\t\t\tCasablanca        2.0           126.0
# 772           à\n   \t\t\t\t\tDar Bouazza        3.0           318.0
# 771           à\n   \t\t\t\t\tDar Bouazza        3.0           358.0
# 1154  Gauthier à\n   \t\t\t\t\tCasablanca        4.0           217.0
#
#       Price(DH)
# 0           980
# 396         980
# 528         980
# 66          980
# 495         980
# ...         ...
# 774           3
# 773           3
# 772           3
# 771           3
# 1154          3
#
# [1155 rows x 4 columns]

# %%
housing[housing['Location'] == "."]
# Out:
# Empty DataFrame
# Columns: [Location, Num_rooms, House_area(m²), Price(DH)]
# Index: []

# %%
housing['Location']  = housing['Location'].str.split('\n', expand=True)[0].str.strip()
housing['Location']  = housing['Location'].str.replace('à','\n').str.strip()

housing.head()
# Out:
#             Location  Num_rooms  House_area(m²)  Price(DH)
# 0              Oulfa        3.0           116.0        980
# 1  Casablanca Marina        2.0           142.0        530
# 2           Ain Diab        3.0           280.0        450
# 3     Anfa Supérieur        3.0           110.0        165
# 4       Les Hôpitaux        2.0           113.0        156

# %%
housing.shape
# Out:
# (1155, 4)

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1155 entries, 0 to 1154
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Location        1155 non-null   object
#  1   Num_rooms       1068 non-null   float64
#  2   House_area(m²)  1068 non-null   float64
#  3   Price(DH)       1155 non-null   int64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 36.2+ KB

# %%
casablanca_housing = housing.to_csv('housing_data.csv', index=False)
